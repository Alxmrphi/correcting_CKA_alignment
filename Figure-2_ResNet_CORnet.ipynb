# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np 
import scipy
import scipy.stats


from pathlib import Path
data_dir = Path('../data')
plt.rcParams["svg.fonttype"] = "none"

def mean_confidence_interval(data, confidence=0.95):
    a = 1.0 * np.array(data)
    n = len(a)
    m, se = np.mean(a), scipy.stats.sem(a)
    h = se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)
    return m, m-h, m+h

layer_names_resnet18 = [ 'conv1', 'maxpool',
                        'layer1.0.conv1', 'layer1.0.conv2', 'layer1.1.conv1', 'layer1.1.conv2',
                        'layer2.0.conv1', 'layer2.0.conv2', 'layer2.1.conv1', 'layer2.1.conv2',
                        'layer3.0.conv1', 'layer3.0.conv2', 'layer3.1.conv1', 'layer3.1.conv2',
                        'layer4.0.conv1', 'layer4.0.conv2', 'layer4.1.conv1', 'layer4.1.conv2',
                        'avgpool', 'fc']

layer_names_cornet_s = ['V1.conv1', 'V1.conv2', 'V2.conv1', 'V2.conv2', 'V2.conv3',
                        'V4.conv1', 'V4.conv2', 'V4.conv3', 'IT.conv1', 'IT.conv2', 'IT.conv3',
                        'decoder.avgpool', 'decoder.linear']

# %%
import pickle

r2 = pickle.load(open('MEG_100-150_cornet_results.pkl', 'rb'))
r1 = pickle.load(open('MEG_100-150_resnet_results.pkl', 'rb'))

# %%
sub1_fMRI_v1_resnet_orig = np.load(data_dir / 'fMRI_results' / 'resnet18_sub01_V1_alignments_original_order.npy')
sub1_fMRI_v1_resnet_rand = np.load(data_dir / 'fMRI_results' / 'resnet18_sub01_V1_alignments_random_data.npy')
sub1_fMRI_v1_resnet_shuf = np.load(data_dir / 'fMRI_results' / 'resnet18_sub01_V1_alignments_shuffled_order.npy')

sub2_fMRI_v1_resnet_orig = np.load(data_dir / 'fMRI_results' / 'resnet18_sub02_V1_alignments_original_order.npy')
sub2_fMRI_v1_resnet_rand = np.load(data_dir / 'fMRI_results' / 'resnet18_sub02_V1_alignments_random_data.npy')
sub2_fMRI_v1_resnet_shuf = np.load(data_dir / 'fMRI_results' / 'resnet18_sub02_V1_alignments_shuffled_order.npy')

sub3_fMRI_v1_resnet_orig = np.load(data_dir / 'fMRI_results' / 'resnet18_sub03_V1_alignments_original_order.npy')
sub3_fMRI_v1_resnet_rand = np.load(data_dir / 'fMRI_results' / 'resnet18_sub03_V1_alignments_random_data.npy')
sub3_fMRI_v1_resnet_shuf = np.load(data_dir / 'fMRI_results' / 'resnet18_sub03_V1_alignments_shuffled_order.npy')

sub1_MEG_cornet_orig = np.load(data_dir / 'meg_results' / 'cornet_s_sub1_100_150_alignments_original_order_occipital.npy')
sub1_MEG_cornet_rand = np.load(data_dir / 'meg_results' / 'cornet_s_sub1_100_150_alignments_random_data_occipital.npy')
sub1_MEG_cornet_shuf = np.load(data_dir / 'meg_results' / 'cornet_s_sub1_100_150_alignments_shuffled_order_occipital.npy')

sub3_MEG_cornet_orig = np.load(data_dir / 'meg_results' / 'cornet_s_sub3_100_150_alignments_original_order_occipital.npy')
sub3_MEG_cornet_rand = np.load(data_dir / 'meg_results' / 'cornet_s_sub3_100_150_alignments_random_data_occipital.npy')
sub3_MEG_cornet_shuf = np.load(data_dir / 'meg_results' / 'cornet_s_sub3_100_150_alignments_shuffled_order_occipital.npy')

sub4_MEG_cornet_orig = np.load(data_dir / 'meg_results' / 'cornet_s_sub4_100_150_alignments_original_order_occipital.npy')
sub4_MEG_cornet_rand = np.load(data_dir / 'meg_results' / 'cornet_s_sub4_100_150_alignments_random_data_occipital.npy')
sub4_MEG_cornet_shuf = np.load(data_dir / 'meg_results' / 'cornet_s_sub4_100_150_alignments_shuffled_order_occipital.npy')

begin = 100
end = 150
model_name = 'resnet18'
sub1_MEG_100_150_orig = np.load(data_dir / 'meg_results' / f'{model_name}_sub1_{begin}_{end}_alignments_original_order_occipital.npy')
sub1_MEG_100_150_rand = np.load(data_dir / 'meg_results' / f'{model_name}_sub1_{begin}_{end}_alignments_random_data_occipital.npy')
sub1_MEG_100_1501_shuf = np.load(data_dir / 'meg_results' / f'{model_name}_sub1_{begin}_{end}_alignments_shuffled_order_occipital.npy')

sub3_MEG_100_150_orig = np.load(data_dir / 'meg_results' / f'{model_name}_sub3_{begin}_{end}_alignments_original_order_occipital.npy')
sub3_MEG_100_150_rand = np.load(data_dir / 'meg_results' / f'{model_name}_sub3_{begin}_{end}_alignments_random_data_occipital.npy')
sub3_MEG_100_1501_shuf = np.load(data_dir / 'meg_results' / f'{model_name}_sub3_{begin}_{end}_alignments_shuffled_order_occipital.npy')

sub4_MEG_100_150_orig = np.load(data_dir / 'meg_results' / f'{model_name}_sub4_{begin}_{end}_alignments_original_order_occipital.npy')
sub4_MEG_100_150_rand = np.load(data_dir / 'meg_results' / f'{model_name}_sub4_{begin}_{end}_alignments_random_data_occipital.npy')
sub4_MEG_100_1501_shuf = np.load(data_dir / 'meg_results' / f'{model_name}_sub4_{begin}_{end}_alignments_shuffled_order_occipital.npy')

# %% [markdown]
# # Resnet18

# %%
# RESNET18

model_name = 'resnet18'
model_layers = eval(f'layer_names_{model_name}')
n_layers = len(model_layers)

# CKA biased 

fMRI_CKA_biased_orig_resnet = np.zeros((15, n_layers))
fMRI_CKA_biased_orig_resnet[:5, :]   = sub1_fMRI_v1_resnet_orig[:, 0, :]
fMRI_CKA_biased_orig_resnet[5:10,:]  = sub2_fMRI_v1_resnet_orig[:, 0, :]
fMRI_CKA_biased_orig_resnet[10:, :]  = sub3_fMRI_v1_resnet_orig[:, 0, :]

fMRI_CKA_biased_rand_resnet = np.zeros((15, n_layers))
fMRI_CKA_biased_rand_resnet[:5, :]   = sub1_fMRI_v1_resnet_rand[:, 0, :]
fMRI_CKA_biased_rand_resnet[5:10,:]  = sub2_fMRI_v1_resnet_rand[:, 0, :]
fMRI_CKA_biased_rand_resnet[10:, :]  = sub3_fMRI_v1_resnet_rand[:, 0, :]

fMRI_CKA_biased_shuf_resnet = np.zeros((15, n_layers))
fMRI_CKA_biased_shuf_resnet[:5, :]   = sub1_fMRI_v1_resnet_shuf[:, 0, :]
fMRI_CKA_biased_shuf_resnet[5:10,:]  = sub2_fMRI_v1_resnet_shuf[:, 0, :]
fMRI_CKA_biased_shuf_resnet[10:, :]  = sub3_fMRI_v1_resnet_shuf[:, 0, :]

# CKA debiased

fMRI_CKA_debiased_orig_resnet = np.zeros((15, n_layers))
fMRI_CKA_debiased_orig_resnet[:5, :]   = sub1_fMRI_v1_resnet_orig[:, 1, :]
fMRI_CKA_debiased_orig_resnet[5:10,:]  = sub2_fMRI_v1_resnet_orig[:, 1, :]
fMRI_CKA_debiased_orig_resnet[10:, :]  = sub3_fMRI_v1_resnet_orig[:, 1, :]

fMRI_CKA_debiased_rand_resnet = np.zeros((15, n_layers))
fMRI_CKA_debiased_rand_resnet[:5, :]   = sub1_fMRI_v1_resnet_rand[:, 1, :]
fMRI_CKA_debiased_rand_resnet[5:10,:]  = sub2_fMRI_v1_resnet_rand[:, 1, :]
fMRI_CKA_debiased_rand_resnet[10:, :]  = sub3_fMRI_v1_resnet_rand[:, 1, :]

fMRI_CKA_debiased_shuf_resnet = np.zeros((15, n_layers))
fMRI_CKA_debiased_shuf_resnet[:5, :]   = sub1_fMRI_v1_resnet_shuf[:, 1, :]
fMRI_CKA_debiased_shuf_resnet[5:10,:]  = sub2_fMRI_v1_resnet_shuf[:, 1, :]
fMRI_CKA_debiased_shuf_resnet[10:, :]  = sub3_fMRI_v1_resnet_shuf[:, 1, :]

# ResNet-18 

# CKA biased 

MEG_CKA_biased_orig_resnet = np.zeros((15, n_layers))
MEG_CKA_biased_orig_resnet[:5, :]   = sub1_MEG_100_150_orig[:, 0, :]
MEG_CKA_biased_orig_resnet[5:10,:]  = sub3_MEG_100_150_orig[:, 0, :]
MEG_CKA_biased_orig_resnet[10:, :]  = sub4_MEG_100_150_orig[:, 0, :]

MEG_CKA_biased_rand_resnet = np.zeros((15, n_layers))
MEG_CKA_biased_rand_resnet[:5, :]   = sub1_MEG_100_150_rand[:, 0, :]
MEG_CKA_biased_rand_resnet[5:10,:]  = sub3_MEG_100_150_rand[:, 0, :]
MEG_CKA_biased_rand_resnet[10:, :]  = sub4_MEG_100_150_rand[:, 0, :]

MEG_CKA_biased_shuf_resnet = np.zeros((15, n_layers))
MEG_CKA_biased_shuf_resnet[:5, :]   = sub1_MEG_100_1501_shuf[:, 0, :]
MEG_CKA_biased_shuf_resnet[5:10,:]  = sub3_MEG_100_1501_shuf[:, 0, :]
MEG_CKA_biased_shuf_resnet[10:, :]  = sub4_MEG_100_1501_shuf[:, 0, :]

# CKA debiased

MEG_CKA_debiased_orig_resnet = np.zeros((15, n_layers))
MEG_CKA_debiased_orig_resnet[:5, :]   = sub1_MEG_100_150_orig[:, 1, :]
MEG_CKA_debiased_orig_resnet[5:10,:]  = sub3_MEG_100_150_orig[:, 1, :]
MEG_CKA_debiased_orig_resnet[10:, :]  = sub4_MEG_100_150_orig[:, 1, :]

MEG_CKA_debiased_rand_resnet = np.zeros((15, n_layers))
MEG_CKA_debiased_rand_resnet[:5, :]   = sub1_MEG_100_150_rand[:, 1, :]
MEG_CKA_debiased_rand_resnet[5:10,:]  = sub3_MEG_100_150_rand[:, 1, :]
MEG_CKA_debiased_rand_resnet[10:, :]  = sub4_MEG_100_150_rand[:, 1, :]

MEG_CKA_debiased_shuf_resnet = np.zeros((15, n_layers))
MEG_CKA_debiased_shuf_resnet[:5, :]   = sub1_MEG_100_1501_shuf[:, 1, :]
MEG_CKA_debiased_shuf_resnet[5:10,:]  = sub3_MEG_100_1501_shuf[:, 1, :]
MEG_CKA_debiased_shuf_resnet[10:, :]  = sub4_MEG_100_1501_shuf[:, 1, :]

confidence = 0.95
n = fMRI_CKA_biased_orig_resnet.shape[0]

m, se = np.mean(fMRI_CKA_biased_orig_resnet[:,:], axis=0), scipy.stats.sem(fMRI_CKA_biased_orig_resnet[:,:], axis=0)
h = se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# CKA biased
fMRI_CKA_biased_orig_m, fMRI_CKA_biased_orig_se = np.mean(fMRI_CKA_biased_orig_resnet[:,:], axis=0), scipy.stats.sem(fMRI_CKA_biased_orig_resnet[:,:], axis=0)
fMRI_CKA_biased_orig_h = fMRI_CKA_biased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

fMRI_CKA_biased_rand_m, fMRI_CKA_biased_rand_se = np.mean(fMRI_CKA_biased_rand_resnet[:,:], axis=0), scipy.stats.sem(fMRI_CKA_biased_rand_resnet[:,:], axis=0)
fMRI_CKA_biased_rand_h = fMRI_CKA_biased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

fMRI_CKA_biased_shuf_m, fMRI_CKA_biased_shuf_se = np.mean(fMRI_CKA_biased_shuf_resnet[:,:], axis=0), scipy.stats.sem(fMRI_CKA_biased_shuf_resnet[:,:], axis=0)
fMRI_CKA_biased_shuf_h = fMRI_CKA_biased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# CKA debiased
fMRI_CKA_debiased_orig_m, fMRI_CKA_debiased_orig_se = np.mean(fMRI_CKA_debiased_orig_resnet[:,:], axis=0), scipy.stats.sem(fMRI_CKA_debiased_orig_resnet[:,:], axis=0)
fMRI_CKA_debiased_orig_h = fMRI_CKA_debiased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

fMRI_CKA_debiased_rand_m, fMRI_CKA_debiased_rand_se = np.mean(fMRI_CKA_debiased_rand_resnet[:,:], axis=0), scipy.stats.sem(fMRI_CKA_debiased_rand_resnet[:,:], axis=0)
fMRI_CKA_debiased_rand_h = fMRI_CKA_debiased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

fMRI_CKA_debiased_shuf_m, fMRI_CKA_debiased_shuf_se = np.mean(fMRI_CKA_debiased_shuf_resnet[:,:], axis=0), scipy.stats.sem(fMRI_CKA_debiased_shuf_resnet[:,:], axis=0)
fMRI_CKA_debiased_shuf_h = fMRI_CKA_debiased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)


confidence = 0.95
n = MEG_CKA_biased_orig_resnet.shape[0]

# CKA biased
MEG_CKA_biased_orig_m, MEG_CKA_biased_orig_se = np.mean(MEG_CKA_biased_orig_resnet[:,:], axis=0), scipy.stats.sem(MEG_CKA_biased_orig_resnet[:,:], axis=0)
MEG_CKA_biased_orig_h = MEG_CKA_biased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

MEG_CKA_biased_rand_m, MEG_CKA_biased_rand_se = np.mean(MEG_CKA_biased_rand_resnet[:,:], axis=0), scipy.stats.sem(MEG_CKA_biased_rand_resnet[:,:], axis=0)
MEG_CKA_biased_rand_h = MEG_CKA_biased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

MEG_CKA_biased_shuf_m, MEG_CKA_biased_shuf_se = np.mean(MEG_CKA_biased_shuf_resnet[:,:], axis=0), scipy.stats.sem(MEG_CKA_biased_shuf_resnet[:,:], axis=0)
MEG_CKA_biased_shuf_h = MEG_CKA_biased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# CKA debiased
MEG_CKA_debiased_orig_m, MEG_CKA_debiased_orig_se = np.mean(MEG_CKA_debiased_orig_resnet[:,:], axis=0), scipy.stats.sem(MEG_CKA_debiased_orig_resnet[:,:], axis=0)
MEG_CKA_debiased_orig_h = MEG_CKA_debiased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

MEG_CKA_debiased_rand_m, MEG_CKA_debiased_rand_se = np.mean(MEG_CKA_debiased_rand_resnet[:,:], axis=0), scipy.stats.sem(MEG_CKA_debiased_rand_resnet[:,:], axis=0)
MEG_CKA_debiased_rand_h = MEG_CKA_debiased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

MEG_CKA_debiased_shuf_m, MEG_CKA_debiased_shuf_se = np.mean(MEG_CKA_debiased_shuf_resnet[:,:], axis=0), scipy.stats.sem(MEG_CKA_debiased_shuf_resnet[:,:], axis=0)
MEG_CKA_debiased_shuf_h = MEG_CKA_debiased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

fig, axes = plt.subplots(2,1, sharex=True, figsize=(8,8)) 
axes = np.ravel(axes)
model_name = 'resnet18'
model_layers = eval(f'layer_names_{model_name}')

xs = list(range(len(model_layers)))

# CKA biased
tmp = np.vstack([r1['MEG_sub1_100-150_orig'][:,0,:], r1['MEG_sub2_100-150_orig'][:,0,:], r1['MEG_sub4_100-150_orig'][:,0,:]])
MEG_CKA_biased_orig_m, MEG_CKA_biased_orig_se = m, std = np.mean(tmp, axis=0), scipy.stats.sem(tmp, axis=0)
MEG_CKA_biased_orig_h = MEG_CKA_biased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.vstack([r1['MEG_sub1_100-150_rand'][:,0,:], r1['MEG_sub2_100-150_rand'][:,0,:], r1['MEG_sub4_100-150_rand'][:,0,:]])
MEG_CKA_biased_rand_m, MEG_CKA_biased_rand_se = m, std = np.mean(tmp, axis=0), scipy.stats.sem(tmp, axis=0)
MEG_CKA_biased_rand_h = MEG_CKA_biased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.vstack([r1['MEG_sub1_100-150_shuf'][:,0,:], r1['MEG_sub2_100-150_shuf'][:,0,:], r1['MEG_sub4_100-150_shuf'][:,0,:]])
MEG_CKA_biased_shuf_m, MEG_CKA_biased_shuf_se = m, std = np.mean(tmp, axis=0), scipy.stats.sem(tmp, axis=0)
MEG_CKA_biased_shuf_h = MEG_CKA_biased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# CKA debiased
tmp = np.vstack([r1['MEG_sub1_100-150_orig'][:,1,:], r1['MEG_sub2_100-150_orig'][:,1,:], r1['MEG_sub4_100-150_orig'][:,1,:]])
MEG_CKA_debiased_orig_m, MEG_CKA_debiased_orig_se = m, std = np.mean(tmp, axis=0), scipy.stats.sem(tmp, axis=0)
MEG_CKA_debiased_orig_h = MEG_CKA_debiased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.vstack([r1['MEG_sub1_100-150_rand'][:,1,:], r1['MEG_sub2_100-150_rand'][:,1,:], r1['MEG_sub4_100-150_rand'][:,1,:]])
MEG_CKA_debiased_rand_m, MEG_CKA_debiased_rand_se = m, std = np.mean(tmp, axis=0), scipy.stats.sem(tmp, axis=0)
MEG_CKA_debiased_rand_h = MEG_CKA_debiased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.vstack([r1['MEG_sub1_100-150_shuf'][:,1,:], r1['MEG_sub2_100-150_shuf'][:,1,:], r1['MEG_sub4_100-150_shuf'][:,1,:]])
MEG_CKA_debiased_shuf_m, MEG_CKA_debiased_shuf_se = m, std = np.mean(tmp, axis=0), scipy.stats.sem(tmp, axis=0)
MEG_CKA_debiased_shuf_h = MEG_CKA_debiased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# CKA biased
axes[0].plot(model_layers, fMRI_CKA_biased_orig_m, color='blue', label='Original')
axes[0].fill_between(model_layers, fMRI_CKA_biased_orig_m-fMRI_CKA_biased_orig_h, fMRI_CKA_biased_orig_m+fMRI_CKA_biased_orig_h, color='blue', alpha=0.3)

axes[0].plot(model_layers, fMRI_CKA_biased_rand_m, color='red', label='Random')
axes[0].fill_between(model_layers, fMRI_CKA_biased_rand_m-fMRI_CKA_biased_rand_h, fMRI_CKA_biased_rand_m+fMRI_CKA_biased_rand_h, color='red', alpha=0.3)

axes[0].plot(model_layers, fMRI_CKA_biased_shuf_m, color='green', label='Shuffled')
axes[0].fill_between(model_layers, fMRI_CKA_biased_shuf_m-fMRI_CKA_biased_shuf_h, fMRI_CKA_biased_shuf_m+fMRI_CKA_biased_shuf_h, color='green', alpha=0.3)

# CKA debiased
axes[0].plot(model_layers, fMRI_CKA_debiased_orig_m, color='blue', label='Original', linestyle='--')
axes[0].fill_between(model_layers, fMRI_CKA_debiased_orig_m-fMRI_CKA_debiased_orig_h, fMRI_CKA_debiased_orig_m+fMRI_CKA_debiased_orig_h, color='blue', alpha=0.3)

axes[0].plot(model_layers, fMRI_CKA_biased_rand_m, color='red', label='Random', linestyle='--')
axes[0].fill_between(model_layers, fMRI_CKA_debiased_rand_m-fMRI_CKA_debiased_rand_h, fMRI_CKA_debiased_rand_m+fMRI_CKA_debiased_rand_h, color='red', alpha=0.3)

axes[0].plot(model_layers, fMRI_CKA_debiased_shuf_m, color='green', label='Shuffled', linestyle='--')
axes[0].fill_between(model_layers, fMRI_CKA_debiased_shuf_m-fMRI_CKA_debiased_shuf_h, fMRI_CKA_debiased_shuf_m+fMRI_CKA_debiased_shuf_h, color='green', alpha=0.3)

# CKA biased
axes[1].plot(model_layers, MEG_CKA_biased_orig_m, color='blue', label='Original')
axes[1].fill_between(model_layers, MEG_CKA_biased_orig_m-MEG_CKA_biased_orig_h, MEG_CKA_biased_orig_m+MEG_CKA_biased_orig_h, color='blue', alpha=0.3)

axes[1].plot(model_layers, MEG_CKA_biased_rand_m, color='red', label='Random')
axes[1].fill_between(model_layers, MEG_CKA_biased_rand_m-MEG_CKA_biased_rand_h, MEG_CKA_biased_rand_m+MEG_CKA_biased_rand_h, color='red', alpha=0.3)

axes[1].plot(model_layers, MEG_CKA_biased_shuf_m, color='green', label='Shuffled')
axes[1].fill_between(model_layers, MEG_CKA_biased_shuf_m-MEG_CKA_biased_shuf_h, MEG_CKA_biased_shuf_m+MEG_CKA_biased_shuf_h, color='green', alpha=0.3)

# CKA debiased
axes[1].plot(model_layers, MEG_CKA_debiased_orig_m, color='blue', label='Original', linestyle='--')
axes[1].fill_between(model_layers, MEG_CKA_debiased_orig_m-MEG_CKA_debiased_orig_h, MEG_CKA_debiased_orig_m+MEG_CKA_debiased_orig_h, color='blue', alpha=0.3)

axes[1].plot(model_layers, MEG_CKA_debiased_rand_m, color='red', label='Random', linestyle='--')
axes[1].fill_between(model_layers, MEG_CKA_debiased_rand_m-MEG_CKA_debiased_rand_h, MEG_CKA_debiased_rand_m+MEG_CKA_debiased_rand_h, color='red', alpha=0.3)

axes[1].plot(model_layers, MEG_CKA_debiased_shuf_m, color='green', label='Shuffled', linestyle='--')
axes[1].fill_between(model_layers, MEG_CKA_debiased_shuf_m-MEG_CKA_debiased_shuf_h, MEG_CKA_debiased_shuf_m+MEG_CKA_debiased_shuf_h, color='green', alpha=0.3)


plt.xticks(rotation=65);
plt.legend()
plt.tight_layout()
#plt.title(f'fMRI (V1) CKA biased vs debiased over {model_name} Conv Layers')
plt.savefig('fMRI_V1_MEG_100_150_resnet_fixed.svg', format='svg')

# %% [markdown]
# # CORnet-S

# %%
begin = 100
end = 150
confidence = 0.95
fig, axes = plt.subplots(2,1, sharex=True, figsize=(6,8)) 
axes = np.ravel(axes)


model_name = 'cornet-s'
sub1_fMRI_v1_cornet_orig = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub01_V1_alignments_original_order.npy')
sub1_fMRI_v1_cornet_rand = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub01_V1_alignments_random_data.npy')
sub1_fMRI_v1_cornet_shuf = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub01_V1_alignments_shuffled_order.npy')

sub2_fMRI_v1_cornet_orig = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub02_V1_alignments_original_order.npy')
sub2_fMRI_v1_cornet_rand = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub02_V1_alignments_random_data.npy')
sub2_fMRI_v1_cornet_shuf = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub02_V1_alignments_shuffled_order.npy')

sub3_fMRI_v1_cornet_orig = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub03_V1_alignments_original_order.npy')
sub3_fMRI_v1_cornet_rand = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub03_V1_alignments_random_data.npy')
sub3_fMRI_v1_cornet_shuf = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub03_V1_alignments_shuffled_order.npy')

sub1_MEG_100_150_orig = np.load(data_dir / 'meg_results' / f'cornet_s_sub1_{begin}_{end}_alignments_original_order_occipital.npy')
sub1_MEG_100_150_rand = np.load(data_dir / 'meg_results' / f'cornet_s_sub1_{begin}_{end}_alignments_random_data_occipital.npy')
sub1_MEG_100_1501_shuf = np.load(data_dir / 'meg_results' / f'cornet_s_sub1_{begin}_{end}_alignments_shuffled_order_occipital.npy')

sub3_MEG_100_150_orig = np.load(data_dir / 'meg_results' / f'cornet_s_sub3_{begin}_{end}_alignments_original_order_occipital.npy')
sub3_MEG_100_150_rand = np.load(data_dir / 'meg_results' / f'cornet_s_sub3_{begin}_{end}_alignments_random_data_occipital.npy')
sub3_MEG_100_1501_shuf = np.load(data_dir / 'meg_results' / f'cornet_s_sub3_{begin}_{end}_alignments_shuffled_order_occipital.npy')

sub4_MEG_100_150_orig = np.load(data_dir / 'meg_results' / f'cornet_s_sub4_{begin}_{end}_alignments_original_order_occipital.npy')
sub4_MEG_100_150_rand = np.load(data_dir / 'meg_results' / f'cornet_s_sub4_{begin}_{end}_alignments_random_data_occipital.npy')
sub4_MEG_100_1501_shuf = np.load(data_dir / 'meg_results' / f'cornet_s_sub4_{begin}_{end}_alignments_shuffled_order_occipital.npy')

# CORNET-S
n_layers = len(layer_names_cornet_s)

# CKA biased 
fMRI_CKA_biased_orig_cornet = np.zeros((15, n_layers))
fMRI_CKA_biased_orig_cornet[:5, :]   = sub1_fMRI_v1_cornet_orig[:, 0, :]
fMRI_CKA_biased_orig_cornet[5:10,:]  = sub2_fMRI_v1_cornet_orig[:, 0, :]
fMRI_CKA_biased_orig_cornet[10:, :]  = sub3_fMRI_v1_cornet_orig[:, 0, :]

fMRI_CKA_biased_rand_cornet = np.zeros((15, n_layers))
fMRI_CKA_biased_rand_cornet[:5, :]   = sub1_fMRI_v1_cornet_rand[:, 0, :]
fMRI_CKA_biased_rand_cornet[5:10,:]  = sub2_fMRI_v1_cornet_rand[:, 0, :]
fMRI_CKA_biased_rand_cornet[10:, :]  = sub3_fMRI_v1_cornet_rand[:, 0, :]

fMRI_CKA_biased_shuf_cornet = np.zeros((15, n_layers))
fMRI_CKA_biased_shuf_cornet[:5, :]   = sub1_fMRI_v1_cornet_shuf[:, 0, :]
fMRI_CKA_biased_shuf_cornet[5:10,:]  = sub2_fMRI_v1_cornet_shuf[:, 0, :]
fMRI_CKA_biased_shuf_cornet[10:, :]  = sub3_fMRI_v1_cornet_shuf[:, 0, :]

# CKA debiased
fMRI_CKA_debiased_orig_cornet = np.zeros((15, n_layers))
fMRI_CKA_debiased_orig_cornet[:5, :]   = sub1_fMRI_v1_cornet_orig[:, 1, :]
fMRI_CKA_debiased_orig_cornet[5:10,:]  = sub2_fMRI_v1_cornet_orig[:, 1, :]
fMRI_CKA_debiased_orig_cornet[10:, :]  = sub3_fMRI_v1_cornet_orig[:, 1, :]

fMRI_CKA_debiased_rand_cornet = np.zeros((15, n_layers))
fMRI_CKA_debiased_rand_cornet[:5, :]   = sub1_fMRI_v1_cornet_rand[:, 1, :]
fMRI_CKA_debiased_rand_cornet[5:10,:]  = sub2_fMRI_v1_cornet_rand[:, 1, :]
fMRI_CKA_debiased_rand_cornet[10:, :]  = sub3_fMRI_v1_cornet_rand[:, 1, :]

fMRI_CKA_debiased_shuf_cornet = np.zeros((15, n_layers))
fMRI_CKA_debiased_shuf_cornet[:5, :]   = sub1_fMRI_v1_cornet_shuf[:, 1, :]
fMRI_CKA_debiased_shuf_cornet[5:10,:]  = sub2_fMRI_v1_cornet_shuf[:, 1, :]
fMRI_CKA_debiased_shuf_cornet[10:, :]  = sub3_fMRI_v1_cornet_shuf[:, 1, :]

# RESNET18
n_layers = len(layer_names_cornet_s)

# CKA biased 

MEG_CKA_biased_orig_cornet = np.zeros((15, n_layers))
MEG_CKA_biased_orig_cornet[:5, :]   = sub1_MEG_100_150_orig[:, 0, :]
MEG_CKA_biased_orig_cornet[5:10,:]  = sub3_MEG_100_150_orig[:, 0, :]
MEG_CKA_biased_orig_cornet[10:, :]  = sub4_MEG_100_150_orig[:, 0, :]

MEG_CKA_biased_rand_cornet = np.zeros((15, n_layers))
MEG_CKA_biased_rand_cornet[:5, :]   = sub1_MEG_100_150_rand[:, 0, :]
MEG_CKA_biased_rand_cornet[5:10,:]  = sub3_MEG_100_150_rand[:, 0, :]
MEG_CKA_biased_rand_cornet[10:, :]  = sub4_MEG_100_150_rand[:, 0, :]

MEG_CKA_biased_shuf_cornet = np.zeros((15, n_layers))
MEG_CKA_biased_shuf_cornet[:5, :]   = sub1_MEG_100_1501_shuf[:, 0, :]
MEG_CKA_biased_shuf_cornet[5:10,:]  = sub3_MEG_100_1501_shuf[:, 0, :]
MEG_CKA_biased_shuf_cornet[10:, :]  = sub4_MEG_100_1501_shuf[:, 0, :]

# CKA debiased

MEG_CKA_debiased_orig_cornet = np.zeros((15, n_layers))
MEG_CKA_debiased_orig_cornet[:5, :]   = sub1_MEG_100_150_orig[:, 1, :]
MEG_CKA_debiased_orig_cornet[5:10,:]  = sub3_MEG_100_150_orig[:, 1, :]
MEG_CKA_debiased_orig_cornet[10:, :]  = sub4_MEG_100_150_orig[:, 1, :]

MEG_CKA_debiased_rand_cornet = np.zeros((15, n_layers))
MEG_CKA_debiased_rand_cornet[:5, :]   = sub1_MEG_100_150_rand[:, 1, :]
MEG_CKA_debiased_rand_cornet[5:10,:]  = sub3_MEG_100_150_rand[:, 1, :]
MEG_CKA_debiased_rand_cornet[10:, :]  = sub4_MEG_100_150_rand[:, 1, :]

MEG_CKA_debiased_shuf_cornet = np.zeros((15, n_layers))
MEG_CKA_debiased_shuf_cornet[:5, :]   = sub1_MEG_100_1501_shuf[:, 1, :]
MEG_CKA_debiased_shuf_cornet[5:10,:]  = sub3_MEG_100_1501_shuf[:, 1, :]
MEG_CKA_debiased_shuf_cornet[10:, :]  = sub4_MEG_100_1501_shuf[:, 1, :]

n = fMRI_CKA_biased_orig_cornet.shape[0]

# CKA biased
fMRI_CKA_biased_orig_m, fMRI_CKA_biased_orig_se = np.mean(fMRI_CKA_biased_orig_cornet[:,:], axis=0), scipy.stats.sem(fMRI_CKA_biased_orig_cornet[:,:], axis=0)
fMRI_CKA_biased_orig_h = fMRI_CKA_biased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

fMRI_CKA_biased_rand_m, fMRI_CKA_biased_rand_se = np.mean(fMRI_CKA_biased_rand_cornet[:,:], axis=0), scipy.stats.sem(fMRI_CKA_biased_rand_cornet[:,:], axis=0)
fMRI_CKA_biased_rand_h = fMRI_CKA_biased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

fMRI_CKA_biased_shuf_m, fMRI_CKA_biased_shuf_se = np.mean(fMRI_CKA_biased_shuf_cornet[:,:], axis=0), scipy.stats.sem(fMRI_CKA_biased_shuf_cornet[:,:], axis=0)
fMRI_CKA_biased_shuf_h = fMRI_CKA_biased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# CKA debiased
fMRI_CKA_debiased_orig_m, fMRI_CKA_debiased_orig_se = np.mean(fMRI_CKA_debiased_orig_cornet[:,:], axis=0), scipy.stats.sem(fMRI_CKA_debiased_orig_cornet[:,:], axis=0)
fMRI_CKA_debiased_orig_h = fMRI_CKA_debiased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

fMRI_CKA_debiased_rand_m, fMRI_CKA_debiased_rand_se = np.mean(fMRI_CKA_debiased_rand_cornet[:,:], axis=0), scipy.stats.sem(fMRI_CKA_debiased_rand_cornet[:,:], axis=0)
fMRI_CKA_debiased_rand_h = fMRI_CKA_debiased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

fMRI_CKA_debiased_shuf_m, fMRI_CKA_debiased_shuf_se = np.mean(fMRI_CKA_debiased_shuf_cornet[:,:], axis=0), scipy.stats.sem(fMRI_CKA_debiased_shuf_cornet[:,:], axis=0)
fMRI_CKA_debiased_shuf_h = fMRI_CKA_debiased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

n = MEG_CKA_biased_orig_cornet.shape[0]

# CKA biased
tmp = np.vstack([r2['MEG_sub1_100-150_orig'][:,0,:], r2['MEG_sub2_100-150_orig'][:,0,:], r2['MEG_sub4_100-150_orig'][:,0,:]])
MEG_CKA_biased_orig_m, MEG_CKA_biased_orig_se = m, std = np.mean(tmp, axis=0), scipy.stats.sem(tmp, axis=0)
MEG_CKA_biased_orig_h = MEG_CKA_biased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.vstack([r2['MEG_sub1_100-150_rand'][:,0,:], r2['MEG_sub2_100-150_rand'][:,0,:], r2['MEG_sub4_100-150_rand'][:,0,:]])
MEG_CKA_biased_rand_m, MEG_CKA_biased_rand_se = m, std = np.mean(tmp, axis=0), scipy.stats.sem(tmp, axis=0)
MEG_CKA_biased_rand_h = MEG_CKA_biased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.vstack([r2['MEG_sub1_100-150_shuf'][:,0,:], r2['MEG_sub2_100-150_shuf'][:,0,:], r2['MEG_sub4_100-150_shuf'][:,0,:]])
MEG_CKA_biased_shuf_m, MEG_CKA_biased_shuf_se = m, std = np.mean(tmp, axis=0), scipy.stats.sem(tmp, axis=0)
MEG_CKA_biased_shuf_h = MEG_CKA_biased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# CKA debiased
tmp = np.vstack([r2['MEG_sub1_100-150_orig'][:,1,:], r2['MEG_sub2_100-150_orig'][:,1,:], r2['MEG_sub4_100-150_orig'][:,1,:]])
MEG_CKA_debiased_orig_m, MEG_CKA_debiased_orig_se = m, std = np.mean(tmp, axis=0), scipy.stats.sem(tmp, axis=0)
MEG_CKA_debiased_orig_h = MEG_CKA_debiased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.vstack([r2['MEG_sub1_100-150_rand'][:,1,:], r2['MEG_sub2_100-150_rand'][:,1,:], r2['MEG_sub4_100-150_rand'][:,1,:]])
MEG_CKA_debiased_rand_m, MEG_CKA_debiased_rand_se = m, std = np.mean(tmp, axis=0), scipy.stats.sem(tmp, axis=0)
MEG_CKA_debiased_rand_h = MEG_CKA_debiased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.vstack([r2['MEG_sub1_100-150_shuf'][:,1,:], r2['MEG_sub2_100-150_shuf'][:,1,:], r2['MEG_sub4_100-150_shuf'][:,1,:]])
MEG_CKA_debiased_shuf_m, MEG_CKA_debiased_shuf_se = m, std = np.mean(tmp, axis=0), scipy.stats.sem(tmp, axis=0)
MEG_CKA_debiased_shuf_h = MEG_CKA_debiased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

model_name = 'cornet_s'
model_layers = eval(f'layer_names_{model_name}')

xs = list(range(len(model_layers)))

# CKA biased
axes[0].plot(model_layers, fMRI_CKA_biased_orig_m, color='blue', label='Original')
axes[0].fill_between(model_layers, fMRI_CKA_biased_orig_m-fMRI_CKA_biased_orig_h, fMRI_CKA_biased_orig_m+fMRI_CKA_biased_orig_h, color='blue', alpha=0.3)

axes[0].plot(model_layers, fMRI_CKA_biased_rand_m, color='red', label='Random')
axes[0].fill_between(model_layers, fMRI_CKA_biased_rand_m-fMRI_CKA_biased_rand_h, fMRI_CKA_biased_rand_m+fMRI_CKA_biased_rand_h, color='red', alpha=0.3)

axes[0].plot(model_layers, fMRI_CKA_biased_shuf_m, color='green', label='Shuffled')
axes[0].fill_between(model_layers, fMRI_CKA_biased_shuf_m-fMRI_CKA_biased_shuf_h, fMRI_CKA_biased_shuf_m+fMRI_CKA_biased_shuf_h, color='green', alpha=0.3)

# CKA debiased
axes[0].plot(model_layers, fMRI_CKA_debiased_orig_m, color='blue', label='Original', linestyle='--')
axes[0].fill_between(model_layers, fMRI_CKA_debiased_orig_m-fMRI_CKA_debiased_orig_h, fMRI_CKA_debiased_orig_m+fMRI_CKA_debiased_orig_h, color='blue', alpha=0.3)

axes[0].plot(model_layers, fMRI_CKA_biased_rand_m, color='red', label='Random', linestyle='--')
axes[0].fill_between(model_layers, fMRI_CKA_debiased_rand_m-fMRI_CKA_debiased_rand_h, fMRI_CKA_debiased_rand_m+fMRI_CKA_debiased_rand_h, color='red', alpha=0.3)

axes[0].plot(model_layers, fMRI_CKA_debiased_shuf_m, color='green', label='Shuffled', linestyle='--')
axes[0].fill_between(model_layers, fMRI_CKA_debiased_shuf_m-fMRI_CKA_debiased_shuf_h, fMRI_CKA_debiased_shuf_m+fMRI_CKA_debiased_shuf_h, color='green', alpha=0.3)

model_name = 'cornet_s'
model_layers = eval(f'layer_names_{model_name}')

# CKA biased
axes[1].plot(model_layers, MEG_CKA_biased_orig_m, color='blue', label='Original')
axes[1].fill_between(model_layers, MEG_CKA_biased_orig_m-MEG_CKA_biased_orig_h, MEG_CKA_biased_orig_m+MEG_CKA_biased_orig_h, color='blue', alpha=0.3)

axes[1].plot(model_layers, MEG_CKA_biased_rand_m, color='red', label='Random')
axes[1].fill_between(model_layers, MEG_CKA_biased_rand_m-MEG_CKA_biased_rand_h, MEG_CKA_biased_rand_m+MEG_CKA_biased_rand_h, color='red', alpha=0.3)

axes[1].plot(model_layers, MEG_CKA_biased_shuf_m, color='green', label='Shuffled')
axes[1].fill_between(model_layers, MEG_CKA_biased_shuf_m-MEG_CKA_biased_shuf_h, MEG_CKA_biased_shuf_m+MEG_CKA_biased_shuf_h, color='green', alpha=0.3)

# CKA debiased
axes[1].plot(model_layers, MEG_CKA_debiased_orig_m, color='blue', label='Original', linestyle='--')
axes[1].fill_between(model_layers, MEG_CKA_debiased_orig_m-MEG_CKA_debiased_orig_h, MEG_CKA_debiased_orig_m+MEG_CKA_debiased_orig_h, color='blue', alpha=0.3)

axes[1].plot(model_layers, MEG_CKA_debiased_rand_m, color='red', label='Random', linestyle='--')
axes[1].fill_between(model_layers, MEG_CKA_debiased_rand_m-MEG_CKA_debiased_rand_h, MEG_CKA_debiased_rand_m+MEG_CKA_debiased_rand_h, color='red', alpha=0.3)

axes[1].plot(model_layers, MEG_CKA_debiased_shuf_m, color='green', label='Shuffled', linestyle='--')
axes[1].fill_between(model_layers, MEG_CKA_debiased_shuf_m-MEG_CKA_debiased_shuf_h, MEG_CKA_debiased_shuf_m+MEG_CKA_debiased_shuf_h, color='green', alpha=0.3)


plt.xticks(rotation=65);
plt.legend()
plt.tight_layout()
#plt.title(f'fMRI (V1) CKA biased vs debiased over {model_name} Conv Layers')
plt.savefig('fMRI_V1_MEG_100_150_cornet_fixed.svg', format='svg')

# %%
scipy.stats.sem(MEG_CKA_biased_rand_cornet[:,:], axis=0)

# %%
MEG_CKA_biased_rand_cornet.min(), MEG_CKA_biased_rand_cornet.max()

# %%
MEG_CKA_biased_rand_resnet.min(), MEG_CKA_biased_rand_resnet.max()

# %%
scipy.stats.sem(MEG_CKA_biased_rand_resnet[:,:], axis=0)

# %% [markdown]
# ## Fixing Model, varying ROI / time window

# %% [markdown]
# ### ResNet18
#
# Same code as above but loop over different thing. 5th index of the layer names for resnet is `layer1.1.conv2` which is the one to compare to.
#
# The loaded results files are of the shape `(seeds, metric_type, layers)` so the final axis needs to be indexed to get only the results for specified layer above.

# %%
# V1
sub1_fMRI_V1_resnet_orig = np.load(data_dir / 'fMRI_results' / 'resnet18_sub01_V1_alignments_original_order.npy')
sub1_fMRI_V1_resnet_rand = np.load(data_dir / 'fMRI_results' / 'resnet18_sub01_V1_alignments_random_data.npy')
sub1_fMRI_V1_resnet_shuf = np.load(data_dir / 'fMRI_results' / 'resnet18_sub01_V1_alignments_shuffled_order.npy')

sub2_fMRI_V1_resnet_orig = np.load(data_dir / 'fMRI_results' / 'resnet18_sub02_V1_alignments_original_order.npy')
sub2_fMRI_V1_resnet_rand = np.load(data_dir / 'fMRI_results' / 'resnet18_sub02_V1_alignments_random_data.npy')
sub2_fMRI_V1_resnet_shuf = np.load(data_dir / 'fMRI_results' / 'resnet18_sub02_V1_alignments_shuffled_order.npy')

sub3_fMRI_V1_resnet_orig = np.load(data_dir / 'fMRI_results' / 'resnet18_sub03_V1_alignments_original_order.npy')
sub3_fMRI_V1_resnet_rand = np.load(data_dir / 'fMRI_results' / 'resnet18_sub03_V1_alignments_random_data.npy')
sub3_fMRI_V1_resnet_shuf = np.load(data_dir / 'fMRI_results' / 'resnet18_sub03_V1_alignments_shuffled_order.npy')

# V2
sub1_fMRI_V2_resnet_orig = np.load(data_dir / 'fMRI_results' / 'resnet18_sub01_V2_alignments_original_order.npy')
sub1_fMRI_V2_resnet_rand = np.load(data_dir / 'fMRI_results' / 'resnet18_sub01_V2_alignments_random_data.npy')
sub1_fMRI_V2_resnet_shuf = np.load(data_dir / 'fMRI_results' / 'resnet18_sub01_V2_alignments_shuffled_order.npy')

sub2_fMRI_V2_resnet_orig = np.load(data_dir / 'fMRI_results' / 'resnet18_sub02_V2_alignments_original_order.npy')
sub2_fMRI_V2_resnet_rand = np.load(data_dir / 'fMRI_results' / 'resnet18_sub02_V2_alignments_random_data.npy')
sub2_fMRI_V2_resnet_shuf = np.load(data_dir / 'fMRI_results' / 'resnet18_sub02_V2_alignments_shuffled_order.npy')

sub3_fMRI_V2_resnet_orig = np.load(data_dir / 'fMRI_results' / 'resnet18_sub03_V2_alignments_original_order.npy')
sub3_fMRI_V2_resnet_rand = np.load(data_dir / 'fMRI_results' / 'resnet18_sub03_V2_alignments_random_data.npy')
sub3_fMRI_V2_resnet_shuf = np.load(data_dir / 'fMRI_results' / 'resnet18_sub03_V2_alignments_shuffled_order.npy')

# V3
sub1_fMRI_V3_resnet_orig = np.load(data_dir / 'fMRI_results' / 'resnet18_sub01_V3_alignments_original_order.npy')
sub1_fMRI_V3_resnet_rand = np.load(data_dir / 'fMRI_results' / 'resnet18_sub01_V3_alignments_random_data.npy')
sub1_fMRI_V3_resnet_shuf = np.load(data_dir / 'fMRI_results' / 'resnet18_sub01_V3_alignments_shuffled_order.npy')

sub2_fMRI_V3_resnet_orig = np.load(data_dir / 'fMRI_results' / 'resnet18_sub02_V3_alignments_original_order.npy')
sub2_fMRI_V3_resnet_rand = np.load(data_dir / 'fMRI_results' / 'resnet18_sub02_V3_alignments_random_data.npy')
sub2_fMRI_V3_resnet_shuf = np.load(data_dir / 'fMRI_results' / 'resnet18_sub02_V3_alignments_shuffled_order.npy')

sub3_fMRI_V3_resnet_orig = np.load(data_dir / 'fMRI_results' / 'resnet18_sub03_V3_alignments_original_order.npy')
sub3_fMRI_V3_resnet_rand = np.load(data_dir / 'fMRI_results' / 'resnet18_sub03_V3_alignments_random_data.npy')
sub3_fMRI_V3_resnet_shuf = np.load(data_dir / 'fMRI_results' / 'resnet18_sub03_V3_alignments_shuffled_order.npy')

# hV4
sub1_fMRI_hV4_resnet_orig = np.load(data_dir / 'fMRI_results' / 'resnet18_sub01_hV4_alignments_original_order.npy')
sub1_fMRI_hV4_resnet_rand = np.load(data_dir / 'fMRI_results' / 'resnet18_sub01_hV4_alignments_random_data.npy')
sub1_fMRI_hV4_resnet_shuf = np.load(data_dir / 'fMRI_results' / 'resnet18_sub01_hV4_alignments_shuffled_order.npy')

sub2_fMRI_hV4_resnet_orig = np.load(data_dir / 'fMRI_results' / 'resnet18_sub02_hV4_alignments_original_order.npy')
sub2_fMRI_hV4_resnet_rand = np.load(data_dir / 'fMRI_results' / 'resnet18_sub02_hV4_alignments_random_data.npy')
sub2_fMRI_hV4_resnet_shuf = np.load(data_dir / 'fMRI_results' / 'resnet18_sub02_hV4_alignments_shuffled_order.npy')

sub3_fMRI_hV4_resnet_orig = np.load(data_dir / 'fMRI_results' / 'resnet18_sub03_hV4_alignments_original_order.npy')
sub3_fMRI_hV4_resnet_rand = np.load(data_dir / 'fMRI_results' / 'resnet18_sub03_hV4_alignments_random_data.npy')
sub3_fMRI_hV4_resnet_shuf = np.load(data_dir / 'fMRI_results' / 'resnet18_sub03_hV4_alignments_shuffled_order.npy')

# VO1
sub1_fMRI_VO1_resnet_orig = np.load(data_dir / 'fMRI_results' / 'resnet18_sub01_VO1_alignments_original_order.npy')
sub1_fMRI_VO1_resnet_rand = np.load(data_dir / 'fMRI_results' / 'resnet18_sub01_VO1_alignments_random_data.npy')
sub1_fMRI_VO1_resnet_shuf = np.load(data_dir / 'fMRI_results' / 'resnet18_sub01_VO1_alignments_shuffled_order.npy')

sub2_fMRI_VO1_resnet_orig = np.load(data_dir / 'fMRI_results' / 'resnet18_sub02_VO1_alignments_original_order.npy')
sub2_fMRI_VO1_resnet_rand = np.load(data_dir / 'fMRI_results' / 'resnet18_sub02_VO1_alignments_random_data.npy')
sub2_fMRI_VO1_resnet_shuf = np.load(data_dir / 'fMRI_results' / 'resnet18_sub02_VO1_alignments_shuffled_order.npy')

sub3_fMRI_VO1_resnet_orig = np.load(data_dir / 'fMRI_results' / 'resnet18_sub03_VO1_alignments_original_order.npy')
sub3_fMRI_VO1_resnet_rand = np.load(data_dir / 'fMRI_results' / 'resnet18_sub03_VO1_alignments_random_data.npy')
sub3_fMRI_VO1_resnet_shuf = np.load(data_dir / 'fMRI_results' / 'resnet18_sub03_VO1_alignments_shuffled_order.npy')

# TO1
sub1_fMRI_TO1_resnet_orig = np.load(data_dir / 'fMRI_results' / 'resnet18_sub01_TO1_alignments_original_order.npy')
sub1_fMRI_TO1_resnet_rand = np.load(data_dir / 'fMRI_results' / 'resnet18_sub01_TO1_alignments_random_data.npy')
sub1_fMRI_TO1_resnet_shuf = np.load(data_dir / 'fMRI_results' / 'resnet18_sub01_TO1_alignments_shuffled_order.npy')

sub2_fMRI_TO1_resnet_orig = np.load(data_dir / 'fMRI_results' / 'resnet18_sub02_TO1_alignments_original_order.npy')
sub2_fMRI_TO1_resnet_rand = np.load(data_dir / 'fMRI_results' / 'resnet18_sub02_TO1_alignments_random_data.npy')
sub2_fMRI_TO1_resnet_shuf = np.load(data_dir / 'fMRI_results' / 'resnet18_sub02_TO1_alignments_shuffled_order.npy')

sub3_fMRI_TO1_resnet_orig = np.load(data_dir / 'fMRI_results' / 'resnet18_sub03_TO1_alignments_original_order.npy')
sub3_fMRI_TO1_resnet_rand = np.load(data_dir / 'fMRI_results' / 'resnet18_sub03_TO1_alignments_random_data.npy')
sub3_fMRI_TO1_resnet_shuf = np.load(data_dir / 'fMRI_results' / 'resnet18_sub03_TO1_alignments_shuffled_order.npy')

# rFFA
sub1_fMRI_rFFA_resnet_orig = np.load(data_dir / 'fMRI_results' / 'resnet18_sub01_rFFA_alignments_original_order.npy')
sub1_fMRI_rFFA_resnet_rand = np.load(data_dir / 'fMRI_results' / 'resnet18_sub01_rFFA_alignments_random_data.npy')
sub1_fMRI_rFFA_resnet_shuf = np.load(data_dir / 'fMRI_results' / 'resnet18_sub01_rFFA_alignments_shuffled_order.npy')

sub2_fMRI_rFFA_resnet_orig = np.load(data_dir / 'fMRI_results' / 'resnet18_sub02_rFFA_alignments_original_order.npy')
sub2_fMRI_rFFA_resnet_rand = np.load(data_dir / 'fMRI_results' / 'resnet18_sub02_rFFA_alignments_random_data.npy')
sub2_fMRI_rFFA_resnet_shuf = np.load(data_dir / 'fMRI_results' / 'resnet18_sub02_rFFA_alignments_shuffled_order.npy')

sub3_fMRI_rFFA_resnet_orig = np.load(data_dir / 'fMRI_results' / 'resnet18_sub03_rFFA_alignments_original_order.npy')
sub3_fMRI_rFFA_resnet_rand = np.load(data_dir / 'fMRI_results' / 'resnet18_sub03_rFFA_alignments_random_data.npy')
sub3_fMRI_rFFA_resnet_shuf = np.load(data_dir / 'fMRI_results' / 'resnet18_sub03_rFFA_alignments_shuffled_order.npy')

# lFFA
sub1_fMRI_lFFA_resnet_orig = np.load(data_dir / 'fMRI_results' / 'resnet18_sub01_lFFA_alignments_original_order.npy')
sub1_fMRI_lFFA_resnet_rand = np.load(data_dir / 'fMRI_results' / 'resnet18_sub01_lFFA_alignments_random_data.npy')
sub1_fMRI_lFFA_resnet_shuf = np.load(data_dir / 'fMRI_results' / 'resnet18_sub01_lFFA_alignments_shuffled_order.npy')

sub2_fMRI_lFFA_resnet_orig = np.load(data_dir / 'fMRI_results' / 'resnet18_sub02_lFFA_alignments_original_order.npy')
sub2_fMRI_lFFA_resnet_rand = np.load(data_dir / 'fMRI_results' / 'resnet18_sub02_lFFA_alignments_random_data.npy')
sub2_fMRI_lFFA_resnet_shuf = np.load(data_dir / 'fMRI_results' / 'resnet18_sub02_lFFA_alignments_shuffled_order.npy')

sub3_fMRI_lFFA_resnet_orig = np.load(data_dir / 'fMRI_results' / 'resnet18_sub03_lFFA_alignments_original_order.npy')
sub3_fMRI_lFFA_resnet_rand = np.load(data_dir / 'fMRI_results' / 'resnet18_sub03_lFFA_alignments_random_data.npy')
sub3_fMRI_lFFA_resnet_shuf = np.load(data_dir / 'fMRI_results' / 'resnet18_sub03_lFFA_alignments_shuffled_order.npy')

# rEBA
sub1_fMRI_rEBA_resnet_orig = np.load(data_dir / 'fMRI_results' / 'resnet18_sub01_rEBA_alignments_original_order.npy')
sub1_fMRI_rEBA_resnet_rand = np.load(data_dir / 'fMRI_results' / 'resnet18_sub01_rEBA_alignments_random_data.npy')
sub1_fMRI_rEBA_resnet_shuf = np.load(data_dir / 'fMRI_results' / 'resnet18_sub01_rEBA_alignments_shuffled_order.npy')

sub2_fMRI_rEBA_resnet_orig = np.load(data_dir / 'fMRI_results' / 'resnet18_sub02_rEBA_alignments_original_order.npy')
sub2_fMRI_rEBA_resnet_rand = np.load(data_dir / 'fMRI_results' / 'resnet18_sub02_rEBA_alignments_random_data.npy')
sub2_fMRI_rEBA_resnet_shuf = np.load(data_dir / 'fMRI_results' / 'resnet18_sub02_rEBA_alignments_shuffled_order.npy')

sub3_fMRI_rEBA_resnet_orig = np.load(data_dir / 'fMRI_results' / 'resnet18_sub03_rEBA_alignments_original_order.npy')
sub3_fMRI_rEBA_resnet_rand = np.load(data_dir / 'fMRI_results' / 'resnet18_sub03_rEBA_alignments_random_data.npy')
sub3_fMRI_rEBA_resnet_shuf = np.load(data_dir / 'fMRI_results' / 'resnet18_sub03_rEBA_alignments_shuffled_order.npy')

# lEBA
sub1_fMRI_lEBA_resnet_orig = np.load(data_dir / 'fMRI_results' / 'resnet18_sub01_lEBA_alignments_original_order.npy')
sub1_fMRI_lEBA_resnet_rand = np.load(data_dir / 'fMRI_results' / 'resnet18_sub01_lEBA_alignments_random_data.npy')
sub1_fMRI_lEBA_resnet_shuf = np.load(data_dir / 'fMRI_results' / 'resnet18_sub01_lEBA_alignments_shuffled_order.npy')

sub2_fMRI_lEBA_resnet_orig = np.load(data_dir / 'fMRI_results' / 'resnet18_sub02_lEBA_alignments_original_order.npy')
sub2_fMRI_lEBA_resnet_rand = np.load(data_dir / 'fMRI_results' / 'resnet18_sub02_lEBA_alignments_random_data.npy')
sub2_fMRI_lEBA_resnet_shuf = np.load(data_dir / 'fMRI_results' / 'resnet18_sub02_lEBA_alignments_shuffled_order.npy')

sub3_fMRI_lEBA_resnet_orig = np.load(data_dir / 'fMRI_results' / 'resnet18_sub03_lEBA_alignments_original_order.npy')
sub3_fMRI_lEBA_resnet_rand = np.load(data_dir / 'fMRI_results' / 'resnet18_sub03_lEBA_alignments_random_data.npy')
sub3_fMRI_lEBA_resnet_shuf = np.load(data_dir / 'fMRI_results' / 'resnet18_sub03_lEBA_alignments_shuffled_order.npy')

# rPPA
sub1_fMRI_rPPA_resnet_orig = np.load(data_dir / 'fMRI_results' / 'resnet18_sub01_rPPA_alignments_original_order.npy')
sub1_fMRI_rPPA_resnet_rand = np.load(data_dir / 'fMRI_results' / 'resnet18_sub01_rPPA_alignments_random_data.npy')
sub1_fMRI_rPPA_resnet_shuf = np.load(data_dir / 'fMRI_results' / 'resnet18_sub01_rPPA_alignments_shuffled_order.npy')

sub2_fMRI_rPPA_resnet_orig = np.load(data_dir / 'fMRI_results' / 'resnet18_sub02_rPPA_alignments_original_order.npy')
sub2_fMRI_rPPA_resnet_rand = np.load(data_dir / 'fMRI_results' / 'resnet18_sub02_rPPA_alignments_random_data.npy')
sub2_fMRI_rPPA_resnet_shuf = np.load(data_dir / 'fMRI_results' / 'resnet18_sub02_rPPA_alignments_shuffled_order.npy')

sub3_fMRI_rPPA_resnet_orig = np.load(data_dir / 'fMRI_results' / 'resnet18_sub03_rPPA_alignments_original_order.npy')
sub3_fMRI_rPPA_resnet_rand = np.load(data_dir / 'fMRI_results' / 'resnet18_sub03_rPPA_alignments_random_data.npy')
sub3_fMRI_rPPA_resnet_shuf = np.load(data_dir / 'fMRI_results' / 'resnet18_sub03_rPPA_alignments_shuffled_order.npy')

# lPPA
sub1_fMRI_lPPA_resnet_orig = np.load(data_dir / 'fMRI_results' / 'resnet18_sub01_lPPA_alignments_original_order.npy')
sub1_fMRI_lPPA_resnet_rand = np.load(data_dir / 'fMRI_results' / 'resnet18_sub01_lPPA_alignments_random_data.npy')
sub1_fMRI_lPPA_resnet_shuf = np.load(data_dir / 'fMRI_results' / 'resnet18_sub01_lPPA_alignments_shuffled_order.npy')

sub2_fMRI_lPPA_resnet_orig = np.load(data_dir / 'fMRI_results' / 'resnet18_sub02_lPPA_alignments_original_order.npy')
sub2_fMRI_lPPA_resnet_rand = np.load(data_dir / 'fMRI_results' / 'resnet18_sub02_lPPA_alignments_random_data.npy')
sub2_fMRI_lPPA_resnet_shuf = np.load(data_dir / 'fMRI_results' / 'resnet18_sub02_lPPA_alignments_shuffled_order.npy')

sub3_fMRI_lPPA_resnet_orig = np.load(data_dir / 'fMRI_results' / 'resnet18_sub03_lPPA_alignments_original_order.npy')
sub3_fMRI_lPPA_resnet_rand = np.load(data_dir / 'fMRI_results' / 'resnet18_sub03_lPPA_alignments_random_data.npy')
sub3_fMRI_lPPA_resnet_shuf = np.load(data_dir / 'fMRI_results' / 'resnet18_sub03_lPPA_alignments_shuffled_order.npy')

# %%
n = 15
resnet_idx = 5

# V1 - CKA biased
cka_biased = 0 # selects correct index, ignore semantics
tmp = np.hstack([sub1_fMRI_v1_resnet_orig[0, cka_biased, resnet_idx], sub2_fMRI_v1_resnet_orig[0, cka_biased, resnet_idx], sub3_fMRI_v1_resnet_orig[0, cka_biased, resnet_idx]])
fMRI_V1_CKA_biased_orig_m, fMRI_V1_CKA_biased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_V1_CKA_biased_orig_h = fMRI_V1_CKA_biased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_v1_resnet_rand[:, cka_biased, resnet_idx], sub2_fMRI_v1_resnet_rand[:, cka_biased, resnet_idx], sub3_fMRI_v1_resnet_rand[:, cka_biased, resnet_idx]])
fMRI_V1_CKA_biased_rand_m, fMRI_V1_CKA_biased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_V1_CKA_biased_rand_h = fMRI_V1_CKA_biased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_v1_resnet_shuf[:, cka_biased, resnet_idx], sub2_fMRI_v1_resnet_shuf[:, cka_biased, resnet_idx], sub3_fMRI_v1_resnet_shuf[:, cka_biased, resnet_idx]])
fMRI_V1_CKA_biased_shuf_m, fMRI_V1_CKA_biased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_V1_CKA_biased_shuf_h = fMRI_V1_CKA_biased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# V1 - CKA debiased
cka_biased = 1 # selects correct index, ignore semantics
tmp = np.hstack([sub1_fMRI_v1_resnet_orig[0, cka_biased, resnet_idx], sub2_fMRI_v1_resnet_orig[0, cka_biased, resnet_idx], sub3_fMRI_v1_resnet_orig[0, cka_biased, resnet_idx]])
fMRI_V1_CKA_debiased_orig_m, fMRI_V1_CKA_debiased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_V1_CKA_debiased_orig_h = fMRI_V1_CKA_debiased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_v1_resnet_rand[:, cka_biased, resnet_idx], sub2_fMRI_v1_resnet_rand[:, cka_biased, resnet_idx], sub3_fMRI_v1_resnet_rand[:, cka_biased, resnet_idx]])
fMRI_V1_CKA_debiased_rand_m, fMRI_V1_CKA_debiased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_V1_CKA_debiased_rand_h = fMRI_V1_CKA_debiased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_v1_resnet_shuf[:, cka_biased, resnet_idx], sub2_fMRI_v1_resnet_shuf[:, cka_biased, resnet_idx], sub3_fMRI_v1_resnet_shuf[:, cka_biased, resnet_idx]])
fMRI_V1_CKA_debiased_shuf_m, fMRI_V1_CKA_debiased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_V1_CKA_debiased_shuf_h = fMRI_V1_CKA_debiased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# -----------------------

# V2-  CKA biased
cka_biased = 0 # selects correct index, ignore semantics
tmp = np.hstack([sub1_fMRI_V2_resnet_orig[0, cka_biased, resnet_idx], sub2_fMRI_V2_resnet_orig[0, cka_biased, resnet_idx], sub3_fMRI_V2_resnet_orig[0, cka_biased, resnet_idx]])
fMRI_V2_CKA_biased_orig_m, fMRI_V2_CKA_biased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_V2_CKA_biased_orig_h = fMRI_V2_CKA_biased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_V2_resnet_rand[:, cka_biased, resnet_idx], sub2_fMRI_V2_resnet_rand[:, cka_biased, resnet_idx], sub3_fMRI_V2_resnet_rand[:, cka_biased, resnet_idx]])
fMRI_V2_CKA_biased_rand_m, fMRI_V2_CKA_biased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_V2_CKA_biased_rand_h = fMRI_V2_CKA_biased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_V2_resnet_shuf[:, cka_biased, resnet_idx], sub2_fMRI_V2_resnet_shuf[:, cka_biased, resnet_idx], sub3_fMRI_V2_resnet_shuf[:, cka_biased, resnet_idx]])
fMRI_V2_CKA_biased_shuf_m, fMRI_V2_CKA_biased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_V2_CKA_biased_shuf_h = fMRI_V2_CKA_biased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# V2 - CKA debiased
cka_biased = 1 # selects correct index, ignore semantics
tmp = np.hstack([sub1_fMRI_V2_resnet_orig[0, cka_biased, resnet_idx], sub2_fMRI_V2_resnet_orig[0, cka_biased, resnet_idx], sub3_fMRI_V2_resnet_orig[0, cka_biased, resnet_idx]])
fMRI_V2_CKA_debiased_orig_m, fMRI_V2_CKA_debiased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_V2_CKA_debiased_orig_h = fMRI_V2_CKA_debiased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_V2_resnet_rand[:, cka_biased, resnet_idx], sub2_fMRI_V2_resnet_rand[:, cka_biased, resnet_idx], sub3_fMRI_V2_resnet_rand[:, cka_biased, resnet_idx]])
fMRI_V2_CKA_debiased_rand_m, fMRI_V2_CKA_debiased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_V2_CKA_debiased_rand_h = fMRI_V2_CKA_debiased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_V2_resnet_shuf[:, cka_biased, resnet_idx], sub2_fMRI_V2_resnet_shuf[:, cka_biased, resnet_idx], sub3_fMRI_V2_resnet_shuf[:, cka_biased, resnet_idx]])
fMRI_V2_CKA_debiased_shuf_m, fMRI_V2_CKA_debiased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_V2_CKA_debiased_shuf_h = fMRI_V2_CKA_debiased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1) 

# -----------------

# V3 -  CKA biased
cka_biased = 0 # selects correct index, ignore semantics
tmp = np.hstack([sub1_fMRI_V3_resnet_orig[0, cka_biased, resnet_idx], sub2_fMRI_V3_resnet_orig[0, cka_biased, resnet_idx], sub3_fMRI_V3_resnet_orig[0, cka_biased, resnet_idx]])
fMRI_V3_CKA_biased_orig_m, fMRI_V3_CKA_biased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_V3_CKA_biased_orig_h = fMRI_V3_CKA_biased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_V3_resnet_rand[:, cka_biased, resnet_idx], sub2_fMRI_V3_resnet_rand[:, cka_biased, resnet_idx], sub3_fMRI_V3_resnet_rand[:, cka_biased, resnet_idx]])
fMRI_V3_CKA_biased_rand_m, fMRI_V3_CKA_biased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_V3_CKA_biased_rand_h = fMRI_V3_CKA_biased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_V3_resnet_shuf[:, cka_biased, resnet_idx], sub2_fMRI_V3_resnet_shuf[:, cka_biased, resnet_idx], sub3_fMRI_V3_resnet_shuf[:, cka_biased, resnet_idx]])
fMRI_V3_CKA_biased_shuf_m, fMRI_V3_CKA_biased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_V3_CKA_biased_shuf_h = fMRI_V3_CKA_biased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# V3 - CKA debiased
cka_biased = 1 # selects correct index, ignore semantics
tmp = np.hstack([sub1_fMRI_V3_resnet_orig[0, cka_biased, resnet_idx], sub2_fMRI_V3_resnet_orig[0, cka_biased, resnet_idx], sub3_fMRI_V3_resnet_orig[0, cka_biased, resnet_idx]])
fMRI_V3_CKA_debiased_orig_m, fMRI_V3_CKA_debiased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_V3_CKA_debiased_orig_h = fMRI_V3_CKA_debiased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_V3_resnet_rand[:, cka_biased, resnet_idx], sub2_fMRI_V3_resnet_rand[:, cka_biased, resnet_idx], sub3_fMRI_V3_resnet_rand[:, cka_biased, resnet_idx]])
fMRI_V3_CKA_debiased_rand_m, fMRI_V3_CKA_debiased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_V3_CKA_debiased_rand_h = fMRI_V3_CKA_debiased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_V3_resnet_shuf[:, cka_biased, resnet_idx], sub2_fMRI_V3_resnet_shuf[:, cka_biased, resnet_idx], sub3_fMRI_V3_resnet_shuf[:, cka_biased, resnet_idx]])
fMRI_V3_CKA_debiased_shuf_m, fMRI_V3_CKA_debiased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_V3_CKA_debiased_shuf_h = fMRI_V3_CKA_debiased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1) 

# -------------

# hV4 -  CKA biased
cka_biased = 0 # selects correct index, ignore semantics
tmp = np.hstack([sub1_fMRI_hV4_resnet_orig[0, cka_biased, resnet_idx], sub2_fMRI_hV4_resnet_orig[0, cka_biased, resnet_idx], sub3_fMRI_hV4_resnet_orig[0, cka_biased, resnet_idx]])
fMRI_hV4_CKA_biased_orig_m, fMRI_hV4_CKA_biased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_hV4_CKA_biased_orig_h = fMRI_hV4_CKA_biased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_hV4_resnet_rand[:, cka_biased, resnet_idx], sub2_fMRI_hV4_resnet_rand[:, cka_biased, resnet_idx], sub3_fMRI_hV4_resnet_rand[:, cka_biased, resnet_idx]])
fMRI_hV4_CKA_biased_rand_m, fMRI_hV4_CKA_biased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_hV4_CKA_biased_rand_h = fMRI_hV4_CKA_biased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_hV4_resnet_shuf[:, cka_biased, resnet_idx], sub2_fMRI_hV4_resnet_shuf[:, cka_biased, resnet_idx], sub3_fMRI_hV4_resnet_shuf[:, cka_biased, resnet_idx]])
fMRI_hV4_CKA_biased_shuf_m, fMRI_hV4_CKA_biased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_hV4_CKA_biased_shuf_h = fMRI_hV4_CKA_biased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# hV4 - CKA debiased
cka_biased = 1 # selects correct index, ignore semantics
tmp = np.hstack([sub1_fMRI_hV4_resnet_orig[0, cka_biased, resnet_idx], sub2_fMRI_hV4_resnet_orig[0, cka_biased, resnet_idx], sub3_fMRI_hV4_resnet_orig[0, cka_biased, resnet_idx]])
fMRI_hV4_CKA_debiased_orig_m, fMRI_hV4_CKA_debiased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_hV4_CKA_debiased_orig_h = fMRI_hV4_CKA_debiased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_hV4_resnet_rand[:, cka_biased, resnet_idx], sub2_fMRI_hV4_resnet_rand[:, cka_biased, resnet_idx], sub3_fMRI_hV4_resnet_rand[:, cka_biased, resnet_idx]])
fMRI_hV4_CKA_debiased_rand_m, fMRI_hV4_CKA_debiased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_hV4_CKA_debiased_rand_h = fMRI_hV4_CKA_debiased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_hV4_resnet_shuf[:, cka_biased, resnet_idx], sub2_fMRI_hV4_resnet_shuf[:, cka_biased, resnet_idx], sub3_fMRI_hV4_resnet_shuf[:, cka_biased, resnet_idx]])
fMRI_hV4_CKA_debiased_shuf_m, fMRI_hV4_CKA_debiased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_hV4_CKA_debiased_shuf_h = fMRI_hV4_CKA_debiased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1) 

# ----------------

# VO1 -  CKA biased
cka_biased = 0 # selects correct index, ignore semantics
tmp = np.hstack([sub1_fMRI_VO1_resnet_orig[0, cka_biased, resnet_idx], sub2_fMRI_VO1_resnet_orig[0, cka_biased, resnet_idx], sub3_fMRI_VO1_resnet_orig[0, cka_biased, resnet_idx]])
fMRI_VO1_CKA_biased_orig_m, fMRI_VO1_CKA_biased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_VO1_CKA_biased_orig_h = fMRI_VO1_CKA_biased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_VO1_resnet_rand[:, cka_biased, resnet_idx], sub2_fMRI_VO1_resnet_rand[:, cka_biased, resnet_idx], sub3_fMRI_VO1_resnet_rand[:, cka_biased, resnet_idx]])
fMRI_VO1_CKA_biased_rand_m, fMRI_VO1_CKA_biased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_VO1_CKA_biased_rand_h = fMRI_VO1_CKA_biased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_VO1_resnet_shuf[:, cka_biased, resnet_idx], sub2_fMRI_VO1_resnet_shuf[:, cka_biased, resnet_idx], sub3_fMRI_VO1_resnet_shuf[:, cka_biased, resnet_idx]])
fMRI_VO1_CKA_biased_shuf_m, fMRI_VO1_CKA_biased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_VO1_CKA_biased_shuf_h = fMRI_VO1_CKA_biased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# VO1 - CKA debiased
cka_biased = 1 # selects correct index, ignore semantics
tmp = np.hstack([sub1_fMRI_VO1_resnet_orig[0, cka_biased, resnet_idx], sub2_fMRI_VO1_resnet_orig[0, cka_biased, resnet_idx], sub3_fMRI_VO1_resnet_orig[0, cka_biased, resnet_idx]])
fMRI_VO1_CKA_debiased_orig_m, fMRI_VO1_CKA_debiased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_VO1_CKA_debiased_orig_h = fMRI_VO1_CKA_debiased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_VO1_resnet_rand[:, cka_biased, resnet_idx], sub2_fMRI_VO1_resnet_rand[:, cka_biased, resnet_idx], sub3_fMRI_VO1_resnet_rand[:, cka_biased, resnet_idx]])
fMRI_VO1_CKA_debiased_rand_m, fMRI_VO1_CKA_debiased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_VO1_CKA_debiased_rand_h = fMRI_VO1_CKA_debiased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_VO1_resnet_shuf[:, cka_biased, resnet_idx], sub2_fMRI_VO1_resnet_shuf[:, cka_biased, resnet_idx], sub3_fMRI_VO1_resnet_shuf[:, cka_biased, resnet_idx]])
fMRI_VO1_CKA_debiased_shuf_m, fMRI_VO1_CKA_debiased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_VO1_CKA_debiased_shuf_h = fMRI_VO1_CKA_debiased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1) 

# --------------------


# TO1 -  CKA biased
cka_biased = 0 # selects correct index, ignore semantics
tmp = np.hstack([sub1_fMRI_TO1_resnet_orig[0, cka_biased, resnet_idx], sub2_fMRI_TO1_resnet_orig[0, cka_biased, resnet_idx], sub3_fMRI_TO1_resnet_orig[0, cka_biased, resnet_idx]])
fMRI_TO1_CKA_biased_orig_m, fMRI_TO1_CKA_biased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_TO1_CKA_biased_orig_h = fMRI_TO1_CKA_biased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_TO1_resnet_rand[:, cka_biased, resnet_idx], sub2_fMRI_TO1_resnet_rand[:, cka_biased, resnet_idx], sub3_fMRI_TO1_resnet_rand[:, cka_biased, resnet_idx]])
fMRI_TO1_CKA_biased_rand_m, fMRI_TO1_CKA_biased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_TO1_CKA_biased_rand_h = fMRI_TO1_CKA_biased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_TO1_resnet_shuf[:, cka_biased, resnet_idx], sub2_fMRI_TO1_resnet_shuf[:, cka_biased, resnet_idx], sub3_fMRI_TO1_resnet_shuf[:, cka_biased, resnet_idx]])
fMRI_TO1_CKA_biased_shuf_m, fMRI_TO1_CKA_biased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_TO1_CKA_biased_shuf_h = fMRI_TO1_CKA_biased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# TO1 - CKA debiased
cka_biased = 1 # selects correct index, ignore semantics
tmp = np.hstack([sub1_fMRI_TO1_resnet_orig[0, cka_biased, resnet_idx], sub2_fMRI_TO1_resnet_orig[0, cka_biased, resnet_idx], sub3_fMRI_TO1_resnet_orig[0, cka_biased, resnet_idx]])
fMRI_TO1_CKA_debiased_orig_m, fMRI_TO1_CKA_debiased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_TO1_CKA_debiased_orig_h = fMRI_TO1_CKA_debiased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_TO1_resnet_rand[:, cka_biased, resnet_idx], sub2_fMRI_TO1_resnet_rand[:, cka_biased, resnet_idx], sub3_fMRI_TO1_resnet_rand[:, cka_biased, resnet_idx]])
fMRI_TO1_CKA_debiased_rand_m, fMRI_TO1_CKA_debiased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_TO1_CKA_debiased_rand_h = fMRI_TO1_CKA_debiased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_TO1_resnet_shuf[:, cka_biased, resnet_idx], sub2_fMRI_TO1_resnet_shuf[:, cka_biased, resnet_idx], sub3_fMRI_TO1_resnet_shuf[:, cka_biased, resnet_idx]])
fMRI_TO1_CKA_debiased_shuf_m, fMRI_TO1_CKA_debiased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_TO1_CKA_debiased_shuf_h = fMRI_TO1_CKA_debiased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1) 

# ---------------------

# rFFA -  CKA biased
cka_biased = 0 # selects correct index, ignore semantics
tmp = np.hstack([sub1_fMRI_rFFA_resnet_orig[0, cka_biased, resnet_idx], sub2_fMRI_rFFA_resnet_orig[0, cka_biased, resnet_idx], sub3_fMRI_rFFA_resnet_orig[0, cka_biased, resnet_idx]])
fMRI_rFFA_CKA_biased_orig_m, fMRI_rFFA_CKA_biased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_rFFA_CKA_biased_orig_h = fMRI_rFFA_CKA_biased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_rFFA_resnet_rand[:, cka_biased, resnet_idx], sub2_fMRI_rFFA_resnet_rand[:, cka_biased, resnet_idx], sub3_fMRI_rFFA_resnet_rand[:, cka_biased, resnet_idx]])
fMRI_rFFA_CKA_biased_rand_m, fMRI_rFFA_CKA_biased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_rFFA_CKA_biased_rand_h = fMRI_rFFA_CKA_biased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_rFFA_resnet_shuf[:, cka_biased, resnet_idx], sub2_fMRI_rFFA_resnet_shuf[:, cka_biased, resnet_idx], sub3_fMRI_rFFA_resnet_shuf[:, cka_biased, resnet_idx]])
fMRI_rFFA_CKA_biased_shuf_m, fMRI_rFFA_CKA_biased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_rFFA_CKA_biased_shuf_h = fMRI_rFFA_CKA_biased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# rFFA - CKA debiased
cka_biased = 1 # selects correct index, ignore semantics
tmp = np.hstack([sub1_fMRI_rFFA_resnet_orig[0, cka_biased, resnet_idx], sub2_fMRI_rFFA_resnet_orig[0, cka_biased, resnet_idx], sub3_fMRI_rFFA_resnet_orig[0, cka_biased, resnet_idx]])
fMRI_rFFA_CKA_debiased_orig_m, fMRI_rFFA_CKA_debiased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_rFFA_CKA_debiased_orig_h = fMRI_rFFA_CKA_debiased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_rFFA_resnet_rand[:, cka_biased, resnet_idx], sub2_fMRI_rFFA_resnet_rand[:, cka_biased, resnet_idx], sub3_fMRI_rFFA_resnet_rand[:, cka_biased, resnet_idx]])
fMRI_rFFA_CKA_debiased_rand_m, fMRI_rFFA_CKA_debiased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_rFFA_CKA_debiased_rand_h = fMRI_rFFA_CKA_debiased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_rFFA_resnet_shuf[:, cka_biased, resnet_idx], sub2_fMRI_rFFA_resnet_shuf[:, cka_biased, resnet_idx], sub3_fMRI_rFFA_resnet_shuf[:, cka_biased, resnet_idx]])
fMRI_rFFA_CKA_debiased_shuf_m, fMRI_rFFA_CKA_debiased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_rFFA_CKA_debiased_shuf_h = fMRI_rFFA_CKA_debiased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1) 

# ---------------------

# lFFA -  CKA biased
cka_biased = 0 # selects correct index, ignore semantics
tmp = np.hstack([sub1_fMRI_lFFA_resnet_orig[0, cka_biased, resnet_idx], sub2_fMRI_lFFA_resnet_orig[0, cka_biased, resnet_idx], sub3_fMRI_lFFA_resnet_orig[0, cka_biased, resnet_idx]])
fMRI_lFFA_CKA_biased_orig_m, fMRI_lFFA_CKA_biased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_lFFA_CKA_biased_orig_h = fMRI_lFFA_CKA_biased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_lFFA_resnet_rand[:, cka_biased, resnet_idx], sub2_fMRI_lFFA_resnet_rand[:, cka_biased, resnet_idx], sub3_fMRI_lFFA_resnet_rand[:, cka_biased, resnet_idx]])
fMRI_lFFA_CKA_biased_rand_m, fMRI_lFFA_CKA_biased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_lFFA_CKA_biased_rand_h = fMRI_lFFA_CKA_biased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_lFFA_resnet_shuf[:, cka_biased, resnet_idx], sub2_fMRI_lFFA_resnet_shuf[:, cka_biased, resnet_idx], sub3_fMRI_lFFA_resnet_shuf[:, cka_biased, resnet_idx]])
fMRI_lFFA_CKA_biased_shuf_m, fMRI_lFFA_CKA_biased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_lFFA_CKA_biased_shuf_h = fMRI_lFFA_CKA_biased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# lFFA - CKA debiased
cka_biased = 1 # selects correct index, ignore semantics
tmp = np.hstack([sub1_fMRI_lFFA_resnet_orig[0, cka_biased, resnet_idx], sub2_fMRI_lFFA_resnet_orig[0, cka_biased, resnet_idx], sub3_fMRI_lFFA_resnet_orig[0, cka_biased, resnet_idx]])
fMRI_lFFA_CKA_debiased_orig_m, fMRI_lFFA_CKA_debiased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_lFFA_CKA_debiased_orig_h = fMRI_lFFA_CKA_debiased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_lFFA_resnet_rand[:, cka_biased, resnet_idx], sub2_fMRI_lFFA_resnet_rand[:, cka_biased, resnet_idx], sub3_fMRI_lFFA_resnet_rand[:, cka_biased, resnet_idx]])
fMRI_lFFA_CKA_debiased_rand_m, fMRI_lFFA_CKA_debiased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_lFFA_CKA_debiased_rand_h = fMRI_lFFA_CKA_debiased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_lFFA_resnet_shuf[:, cka_biased, resnet_idx], sub2_fMRI_lFFA_resnet_shuf[:, cka_biased, resnet_idx], sub3_fMRI_lFFA_resnet_shuf[:, cka_biased, resnet_idx]])
fMRI_lFFA_CKA_debiased_shuf_m, fMRI_lFFA_CKA_debiased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_lFFA_CKA_debiased_shuf_h = fMRI_lFFA_CKA_debiased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1) 

# ---------------------

# rPPA -  CKA biased
cka_biased = 0 # selects correct index, ignore semantics
tmp = np.hstack([sub1_fMRI_rPPA_resnet_orig[0, cka_biased, resnet_idx], sub2_fMRI_rPPA_resnet_orig[0, cka_biased, resnet_idx], sub3_fMRI_rPPA_resnet_orig[0, cka_biased, resnet_idx]])
fMRI_rPPA_CKA_biased_orig_m, fMRI_rPPA_CKA_biased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_rPPA_CKA_biased_orig_h = fMRI_rPPA_CKA_biased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_rPPA_resnet_rand[:, cka_biased, resnet_idx], sub2_fMRI_rPPA_resnet_rand[:, cka_biased, resnet_idx], sub3_fMRI_rPPA_resnet_rand[:, cka_biased, resnet_idx]])
fMRI_rPPA_CKA_biased_rand_m, fMRI_rPPA_CKA_biased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_rPPA_CKA_biased_rand_h = fMRI_rPPA_CKA_biased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_rPPA_resnet_shuf[:, cka_biased, resnet_idx], sub2_fMRI_rPPA_resnet_shuf[:, cka_biased, resnet_idx], sub3_fMRI_rPPA_resnet_shuf[:, cka_biased, resnet_idx]])
fMRI_rPPA_CKA_biased_shuf_m, fMRI_rPPA_CKA_biased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_rPPA_CKA_biased_shuf_h = fMRI_rPPA_CKA_biased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# rPPA - CKA debiased
cka_biased = 1 # selects correct index, ignore semantics
tmp = np.hstack([sub1_fMRI_rPPA_resnet_orig[0, cka_biased, resnet_idx], sub2_fMRI_rPPA_resnet_orig[0, cka_biased, resnet_idx], sub3_fMRI_rPPA_resnet_orig[0, cka_biased, resnet_idx]])
fMRI_rPPA_CKA_debiased_orig_m, fMRI_rPPA_CKA_debiased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_rPPA_CKA_debiased_orig_h = fMRI_rPPA_CKA_debiased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_rPPA_resnet_rand[:, cka_biased, resnet_idx], sub2_fMRI_rPPA_resnet_rand[:, cka_biased, resnet_idx], sub3_fMRI_rPPA_resnet_rand[:, cka_biased, resnet_idx]])
fMRI_rPPA_CKA_debiased_rand_m, fMRI_rPPA_CKA_debiased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_rPPA_CKA_debiased_rand_h = fMRI_rPPA_CKA_debiased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_rPPA_resnet_shuf[:, cka_biased, resnet_idx], sub2_fMRI_rPPA_resnet_shuf[:, cka_biased, resnet_idx], sub3_fMRI_rPPA_resnet_shuf[:, cka_biased, resnet_idx]])
fMRI_rPPA_CKA_debiased_shuf_m, fMRI_rPPA_CKA_debiased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_rPPA_CKA_debiased_shuf_h = fMRI_rPPA_CKA_debiased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1) 

# ---------------------

# lPPA -  CKA biased
cka_biased = 0 # selects correct index, ignore semantics
tmp = np.hstack([sub1_fMRI_lPPA_resnet_orig[0, cka_biased, resnet_idx], sub2_fMRI_lPPA_resnet_orig[0, cka_biased, resnet_idx], sub3_fMRI_lPPA_resnet_orig[0, cka_biased, resnet_idx]])
fMRI_lPPA_CKA_biased_orig_m, fMRI_lPPA_CKA_biased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_lPPA_CKA_biased_orig_h = fMRI_lPPA_CKA_biased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., 3-1)

tmp = np.hstack([sub1_fMRI_lPPA_resnet_rand[:, cka_biased, resnet_idx], sub2_fMRI_lPPA_resnet_rand[:, cka_biased, resnet_idx], sub3_fMRI_lPPA_resnet_rand[:, cka_biased, resnet_idx]])
fMRI_lPPA_CKA_biased_rand_m, fMRI_lPPA_CKA_biased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_lPPA_CKA_biased_rand_h = fMRI_lPPA_CKA_biased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_lPPA_resnet_shuf[:, cka_biased, resnet_idx], sub2_fMRI_lPPA_resnet_shuf[:, cka_biased, resnet_idx], sub3_fMRI_lPPA_resnet_shuf[:, cka_biased, resnet_idx]])
fMRI_lPPA_CKA_biased_shuf_m, fMRI_lPPA_CKA_biased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_lPPA_CKA_biased_shuf_h = fMRI_lPPA_CKA_biased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# lPPA - CKA debiased
cka_biased = 1 # selects correct index, ignore semantics
tmp = np.hstack([sub1_fMRI_lPPA_resnet_orig[0, cka_biased, resnet_idx], sub2_fMRI_lPPA_resnet_orig[0, cka_biased, resnet_idx], sub3_fMRI_lPPA_resnet_orig[0, cka_biased, resnet_idx]])
fMRI_lPPA_CKA_debiased_orig_m, fMRI_lPPA_CKA_debiased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_lPPA_CKA_debiased_orig_h = fMRI_lPPA_CKA_debiased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., 3-1)

tmp = np.hstack([sub1_fMRI_lPPA_resnet_rand[:, cka_biased, resnet_idx], sub2_fMRI_lPPA_resnet_rand[:, cka_biased, resnet_idx], sub3_fMRI_lPPA_resnet_rand[:, cka_biased, resnet_idx]])
fMRI_lPPA_CKA_debiased_rand_m, fMRI_lPPA_CKA_debiased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_lPPA_CKA_debiased_rand_h = fMRI_lPPA_CKA_debiased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_lPPA_resnet_shuf[:, cka_biased, resnet_idx], sub2_fMRI_lPPA_resnet_shuf[:, cka_biased, resnet_idx], sub3_fMRI_lPPA_resnet_shuf[:, cka_biased, resnet_idx]])
fMRI_lPPA_CKA_debiased_shuf_m, fMRI_lPPA_CKA_debiased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_lPPA_CKA_debiased_shuf_h = fMRI_lPPA_CKA_debiased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1) 

# ---------------------


# rEBA -  CKA biased
cka_biased = 0 # selects correct index, ignore semantics
tmp = np.hstack([sub1_fMRI_rEBA_resnet_orig[0, cka_biased, resnet_idx], sub2_fMRI_rEBA_resnet_orig[0, cka_biased, resnet_idx], sub3_fMRI_rEBA_resnet_orig[0, cka_biased, resnet_idx]])
fMRI_rEBA_CKA_biased_orig_m, fMRI_rEBA_CKA_biased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_rEBA_CKA_biased_orig_h = fMRI_rEBA_CKA_biased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., 3-1)

tmp = np.hstack([sub1_fMRI_rEBA_resnet_rand[:, cka_biased, resnet_idx], sub2_fMRI_rEBA_resnet_rand[:, cka_biased, resnet_idx], sub3_fMRI_rEBA_resnet_rand[:, cka_biased, resnet_idx]])
fMRI_rEBA_CKA_biased_rand_m, fMRI_rEBA_CKA_biased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_rEBA_CKA_biased_rand_h = fMRI_rEBA_CKA_biased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_rEBA_resnet_shuf[:, cka_biased, resnet_idx], sub2_fMRI_rEBA_resnet_shuf[:, cka_biased, resnet_idx], sub3_fMRI_rEBA_resnet_shuf[:, cka_biased, resnet_idx]])
fMRI_rEBA_CKA_biased_shuf_m, fMRI_rEBA_CKA_biased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_rEBA_CKA_biased_shuf_h = fMRI_rEBA_CKA_biased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# rEBA - CKA debiased
cka_biased = 1 # selects correct index, ignore semantics
tmp = np.hstack([sub1_fMRI_rEBA_resnet_orig[0, cka_biased, resnet_idx], sub2_fMRI_rEBA_resnet_orig[0, cka_biased, resnet_idx], sub3_fMRI_rEBA_resnet_orig[0, cka_biased, resnet_idx]])
fMRI_rEBA_CKA_debiased_orig_m, fMRI_rEBA_CKA_debiased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_rEBA_CKA_debiased_orig_h = fMRI_rEBA_CKA_debiased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_rEBA_resnet_rand[:, cka_biased, resnet_idx], sub2_fMRI_rEBA_resnet_rand[:, cka_biased, resnet_idx], sub3_fMRI_rEBA_resnet_rand[:, cka_biased, resnet_idx]])
fMRI_rEBA_CKA_debiased_rand_m, fMRI_rEBA_CKA_debiased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_rEBA_CKA_debiased_rand_h = fMRI_rEBA_CKA_debiased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_rEBA_resnet_shuf[:, cka_biased, resnet_idx], sub2_fMRI_rEBA_resnet_shuf[:, cka_biased, resnet_idx], sub3_fMRI_rEBA_resnet_shuf[:, cka_biased, resnet_idx]])
fMRI_rEBA_CKA_debiased_shuf_m, fMRI_rEBA_CKA_debiased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_rEBA_CKA_debiased_shuf_h = fMRI_rEBA_CKA_debiased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1) 

# ---------------------

# lEBA -  CKA biased
cka_biased = 0 # selects correct index, ignore semantics
tmp = np.hstack([sub1_fMRI_lEBA_resnet_orig[0, cka_biased, resnet_idx], sub2_fMRI_lEBA_resnet_orig[0, cka_biased, resnet_idx], sub3_fMRI_lEBA_resnet_orig[0, cka_biased, resnet_idx]])
fMRI_lEBA_CKA_biased_orig_m, fMRI_lEBA_CKA_biased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_lEBA_CKA_biased_orig_h = fMRI_lEBA_CKA_biased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_lEBA_resnet_rand[:, cka_biased, resnet_idx], sub2_fMRI_lEBA_resnet_rand[:, cka_biased, resnet_idx], sub3_fMRI_lEBA_resnet_rand[:, cka_biased, resnet_idx]])
fMRI_lEBA_CKA_biased_rand_m, fMRI_lEBA_CKA_biased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_lEBA_CKA_biased_rand_h = fMRI_lEBA_CKA_biased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_lEBA_resnet_shuf[:, cka_biased, resnet_idx], sub2_fMRI_lEBA_resnet_shuf[:, cka_biased, resnet_idx], sub3_fMRI_lEBA_resnet_shuf[:, cka_biased, resnet_idx]])
fMRI_lEBA_CKA_biased_shuf_m, fMRI_lEBA_CKA_biased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_lEBA_CKA_biased_shuf_h = fMRI_lEBA_CKA_biased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# lEBA - CKA debiased
cka_biased = 1 # selects correct index, ignore semantics
tmp = np.hstack([sub1_fMRI_lEBA_resnet_orig[0, cka_biased, resnet_idx], sub2_fMRI_lEBA_resnet_orig[0, cka_biased, resnet_idx], sub3_fMRI_lEBA_resnet_orig[0, cka_biased, resnet_idx]])
fMRI_lEBA_CKA_debiased_orig_m, fMRI_lEBA_CKA_debiased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_lEBA_CKA_debiased_orig_h = fMRI_lEBA_CKA_debiased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_lEBA_resnet_rand[:, cka_biased, resnet_idx], sub2_fMRI_lEBA_resnet_rand[:, cka_biased, resnet_idx], sub3_fMRI_lEBA_resnet_rand[:, cka_biased, resnet_idx]])
fMRI_lEBA_CKA_debiased_rand_m, fMRI_lEBA_CKA_debiased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_lEBA_CKA_debiased_rand_h = fMRI_lEBA_CKA_debiased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_lEBA_resnet_shuf[:, cka_biased, resnet_idx], sub2_fMRI_lEBA_resnet_shuf[:, cka_biased, resnet_idx], sub3_fMRI_lEBA_resnet_shuf[:, cka_biased, resnet_idx]])
fMRI_lEBA_CKA_debiased_shuf_m, fMRI_lEBA_CKA_debiased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_lEBA_CKA_debiased_shuf_h = fMRI_lEBA_CKA_debiased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1) 

# ---------------------

# %%
fig, axis = plt.subplots(figsize=(10,5))
axis = np.ravel(axis)

#rois = ['V1', 'V2', 'V3', 'hV4', 'VO1', 'TO1', 'lEBA', 'rEBA', 'lFFA', 'rFFA', 'lPPA', 'rPPA']
rois = ['lFFA', 'VO1', 'rFFA', 'TO1', 'lPPA', 'rPPA', 'lEBA', 'hV4', 'rEBA', 'V3', 'V2', 'V1']

# ORIG
resnet_cka_biased_orig_m = np.array([fMRI_lFFA_CKA_biased_orig_m, fMRI_VO1_CKA_biased_orig_m, fMRI_rFFA_CKA_biased_orig_m, fMRI_TO1_CKA_biased_orig_m, fMRI_lPPA_CKA_biased_orig_m,
                         fMRI_rPPA_CKA_biased_orig_m, fMRI_lEBA_CKA_biased_orig_m, fMRI_hV4_CKA_biased_orig_m, fMRI_rEBA_CKA_biased_orig_m, fMRI_V3_CKA_biased_orig_m,
                         fMRI_V2_CKA_biased_orig_m, fMRI_V1_CKA_biased_orig_m])

resnet_cka_biased_orig_h = np.array([fMRI_lFFA_CKA_biased_orig_h, fMRI_VO1_CKA_biased_orig_h, fMRI_rFFA_CKA_biased_orig_h, fMRI_TO1_CKA_biased_orig_h, fMRI_lPPA_CKA_biased_orig_h,
                         fMRI_rPPA_CKA_biased_orig_h, fMRI_lEBA_CKA_biased_orig_h, fMRI_hV4_CKA_biased_orig_h, fMRI_rEBA_CKA_biased_orig_h, fMRI_V3_CKA_biased_orig_h,
                         fMRI_V2_CKA_biased_orig_h, fMRI_V1_CKA_biased_orig_h])

m = resnet_cka_biased_orig_m
h = resnet_cka_biased_orig_h

axis[0].plot(rois, m, color='blue', label='Original', linestyle='-')
axis[0].fill_between(rois, m-h, m+h, color='blue', alpha=0.3)

resnet_cka_debiased_orig_m = np.array([fMRI_lFFA_CKA_debiased_orig_m, fMRI_VO1_CKA_debiased_orig_m, fMRI_rFFA_CKA_debiased_orig_m, fMRI_TO1_CKA_debiased_orig_m, fMRI_lPPA_CKA_debiased_orig_m,
                         fMRI_rPPA_CKA_debiased_orig_m, fMRI_lEBA_CKA_debiased_orig_m, fMRI_hV4_CKA_debiased_orig_m, fMRI_rEBA_CKA_debiased_orig_m, fMRI_V3_CKA_debiased_orig_m,
                         fMRI_V2_CKA_debiased_orig_m, fMRI_V1_CKA_debiased_orig_m])

resnet_cka_debiased_orig_h = np.array([fMRI_lFFA_CKA_debiased_orig_h, fMRI_VO1_CKA_debiased_orig_h, fMRI_rFFA_CKA_debiased_orig_h, fMRI_TO1_CKA_debiased_orig_h, fMRI_lPPA_CKA_debiased_orig_h,
                         fMRI_rPPA_CKA_debiased_orig_h, fMRI_lEBA_CKA_debiased_orig_h, fMRI_hV4_CKA_debiased_orig_h, fMRI_rEBA_CKA_debiased_orig_h, fMRI_V3_CKA_debiased_orig_h,
                         fMRI_V2_CKA_debiased_orig_h, fMRI_V1_CKA_debiased_orig_h])

m = resnet_cka_debiased_orig_m
h = resnet_cka_debiased_orig_h
axis[0].plot(rois, m, color='blue', label='Original', linestyle='--')
axis[0].fill_between(rois, m-h, m+h, color='blue', alpha=0.3)


# RAND
resnet_cka_biased_rand_m = np.array([fMRI_lFFA_CKA_biased_rand_m, fMRI_VO1_CKA_biased_rand_m, fMRI_rFFA_CKA_biased_rand_m, fMRI_TO1_CKA_biased_rand_m, fMRI_lPPA_CKA_biased_rand_m,
                         fMRI_rPPA_CKA_biased_rand_m, fMRI_lEBA_CKA_biased_rand_m, fMRI_hV4_CKA_biased_rand_m, fMRI_rEBA_CKA_biased_rand_m, fMRI_V3_CKA_biased_rand_m,
                         fMRI_V2_CKA_biased_rand_m, fMRI_V1_CKA_biased_rand_m])

resnet_cka_biased_rand_h = np.array([fMRI_lFFA_CKA_biased_rand_h, fMRI_VO1_CKA_biased_rand_h, fMRI_rFFA_CKA_biased_rand_h, fMRI_TO1_CKA_biased_rand_h, fMRI_lPPA_CKA_biased_rand_h,
                         fMRI_rPPA_CKA_biased_rand_h, fMRI_lEBA_CKA_biased_rand_h, fMRI_hV4_CKA_biased_rand_h, fMRI_rEBA_CKA_biased_rand_h, fMRI_V3_CKA_biased_rand_h,
                         fMRI_V2_CKA_biased_rand_h, fMRI_V1_CKA_biased_rand_h])

m = resnet_cka_biased_rand_m
h = resnet_cka_biased_rand_h

axis[0].plot(rois, m, color='red', label='Random', linestyle='-')
axis[0].fill_between(rois, m-h, m+h, color='red', alpha=0.3)

resnet_cka_debiased_rand_m = np.array([fMRI_lFFA_CKA_debiased_rand_m, fMRI_VO1_CKA_debiased_rand_m, fMRI_rFFA_CKA_debiased_rand_m, fMRI_TO1_CKA_debiased_rand_m, fMRI_lPPA_CKA_debiased_rand_m,
                         fMRI_rPPA_CKA_debiased_rand_m, fMRI_lEBA_CKA_debiased_rand_m, fMRI_hV4_CKA_debiased_rand_m, fMRI_rEBA_CKA_debiased_rand_m, fMRI_V3_CKA_debiased_rand_m,
                         fMRI_V2_CKA_debiased_rand_m, fMRI_V1_CKA_debiased_rand_m])

resnet_cka_debiased_rand_h = np.array([fMRI_lFFA_CKA_debiased_rand_h, fMRI_VO1_CKA_debiased_rand_h, fMRI_rFFA_CKA_debiased_rand_h, fMRI_TO1_CKA_debiased_rand_h, fMRI_lPPA_CKA_debiased_rand_h,
                         fMRI_rPPA_CKA_debiased_rand_h, fMRI_lEBA_CKA_debiased_rand_h, fMRI_hV4_CKA_debiased_rand_h, fMRI_rEBA_CKA_debiased_rand_h, fMRI_V3_CKA_debiased_rand_h,
                         fMRI_V2_CKA_debiased_rand_h, fMRI_V1_CKA_debiased_rand_h])

m = resnet_cka_debiased_rand_m
h = resnet_cka_debiased_rand_h

axis[0].plot(rois, m, color='red', label='Random', linestyle='--')
axis[0].fill_between(rois, m-h, m+h, color='red', alpha=0.3)

# SHUFFLED 
# RAND
resnet_cka_biased_shuf_m = np.array([fMRI_lFFA_CKA_biased_shuf_m, fMRI_VO1_CKA_biased_shuf_m, fMRI_rFFA_CKA_biased_shuf_m, fMRI_TO1_CKA_biased_shuf_m, fMRI_lPPA_CKA_biased_shuf_m,
                         fMRI_rPPA_CKA_biased_shuf_m, fMRI_lEBA_CKA_biased_shuf_m, fMRI_hV4_CKA_biased_shuf_m, fMRI_rEBA_CKA_biased_shuf_m, fMRI_V3_CKA_biased_shuf_m,
                         fMRI_V2_CKA_biased_shuf_m, fMRI_V1_CKA_biased_shuf_m])

resnet_cka_biased_shuf_h = np.array([fMRI_lFFA_CKA_biased_shuf_h, fMRI_VO1_CKA_biased_shuf_h, fMRI_rFFA_CKA_biased_shuf_h, fMRI_TO1_CKA_biased_shuf_h, fMRI_lPPA_CKA_biased_shuf_h,
                         fMRI_rPPA_CKA_biased_shuf_h, fMRI_lEBA_CKA_biased_shuf_h, fMRI_hV4_CKA_biased_shuf_h, fMRI_rEBA_CKA_biased_shuf_h, fMRI_V3_CKA_biased_shuf_h,
                         fMRI_V2_CKA_biased_shuf_h, fMRI_V1_CKA_biased_shuf_h])

m = resnet_cka_biased_shuf_m
h = resnet_cka_biased_shuf_h

axis[0].plot(rois, m, color='green', label='Shuffled', linestyle='-')
axis[0].fill_between(rois, m-h, m+h, color='green', alpha=0.3)

resnet_cka_debiased_shuf_m = np.array([fMRI_lFFA_CKA_debiased_shuf_m, fMRI_VO1_CKA_debiased_shuf_m, fMRI_rFFA_CKA_debiased_shuf_m, fMRI_TO1_CKA_debiased_shuf_m, fMRI_lPPA_CKA_debiased_shuf_m,
                         fMRI_rPPA_CKA_debiased_shuf_m, fMRI_lEBA_CKA_debiased_shuf_m, fMRI_hV4_CKA_debiased_shuf_m, fMRI_rEBA_CKA_debiased_shuf_m, fMRI_V3_CKA_debiased_shuf_m,
                         fMRI_V2_CKA_debiased_shuf_m, fMRI_V1_CKA_debiased_shuf_m])

resnet_cka_debiased_shuf_h = np.array([fMRI_lFFA_CKA_debiased_shuf_h, fMRI_VO1_CKA_debiased_shuf_h, fMRI_rFFA_CKA_debiased_shuf_h, fMRI_TO1_CKA_debiased_shuf_h, fMRI_lPPA_CKA_debiased_shuf_h,
                         fMRI_rPPA_CKA_debiased_shuf_h, fMRI_lEBA_CKA_debiased_shuf_h, fMRI_hV4_CKA_debiased_shuf_h, fMRI_rEBA_CKA_debiased_shuf_h, fMRI_V3_CKA_debiased_shuf_h,
                         fMRI_V2_CKA_debiased_shuf_h, fMRI_V1_CKA_debiased_shuf_h])

m = resnet_cka_debiased_shuf_m
h = resnet_cka_debiased_shuf_h

axis[0].plot(rois, m, color='green', label='Shuffled', linestyle='--')
axis[0].fill_between(rois, m-h, m+h, color='green', alpha=0.3)


plt.legend()
plt.savefig('fMRI_resnet_ROIs_fixed_ANN_layer.svg', format='svg')

# %% [markdown]
# [('lFFA', 112),
#  ('VO1', 243),
#  ('rFFA', 287),
#  ('TO1', 350),
#  ('lPPA', 412),
#  ('rPPA', 467),
#  ('lEBA', 492),
#  ('hV4', 554),
#  ('rEBA', 683),
#  ('V3', 751),
#  ('V2', 807),
#  ('V1', 997)]

# %%
model_name = 'cornet-s'

# V1
sub1_fMRI_V1_resnet_orig = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub01_V1_alignments_original_order.npy')
sub1_fMRI_V1_resnet_rand = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub01_V1_alignments_random_data.npy')
sub1_fMRI_V1_resnet_shuf = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub01_V1_alignments_shuffled_order.npy')

sub2_fMRI_V1_resnet_orig = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub02_V1_alignments_original_order.npy')
sub2_fMRI_V1_resnet_rand = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub02_V1_alignments_random_data.npy')
sub2_fMRI_V1_resnet_shuf = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub02_V1_alignments_shuffled_order.npy')

sub3_fMRI_V1_resnet_orig = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub03_V1_alignments_original_order.npy')
sub3_fMRI_V1_resnet_rand = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub03_V1_alignments_random_data.npy')
sub3_fMRI_V1_resnet_shuf = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub03_V1_alignments_shuffled_order.npy')

# V2
sub1_fMRI_V2_resnet_orig = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub01_V2_alignments_original_order.npy')
sub1_fMRI_V2_resnet_rand = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub01_V2_alignments_random_data.npy')
sub1_fMRI_V2_resnet_shuf = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub01_V2_alignments_shuffled_order.npy')

sub2_fMRI_V2_resnet_orig = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub02_V2_alignments_original_order.npy')
sub2_fMRI_V2_resnet_rand = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub02_V2_alignments_random_data.npy')
sub2_fMRI_V2_resnet_shuf = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub02_V2_alignments_shuffled_order.npy')

sub3_fMRI_V2_resnet_orig = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub03_V2_alignments_original_order.npy')
sub3_fMRI_V2_resnet_rand = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub03_V2_alignments_random_data.npy')
sub3_fMRI_V2_resnet_shuf = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub03_V2_alignments_shuffled_order.npy')

# V3
sub1_fMRI_V3_resnet_orig = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub01_V3_alignments_original_order.npy')
sub1_fMRI_V3_resnet_rand = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub01_V3_alignments_random_data.npy')
sub1_fMRI_V3_resnet_shuf = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub01_V3_alignments_shuffled_order.npy')

sub2_fMRI_V3_resnet_orig = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub02_V3_alignments_original_order.npy')
sub2_fMRI_V3_resnet_rand = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub02_V3_alignments_random_data.npy')
sub2_fMRI_V3_resnet_shuf = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub02_V3_alignments_shuffled_order.npy')

sub3_fMRI_V3_resnet_orig = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub03_V3_alignments_original_order.npy')
sub3_fMRI_V3_resnet_rand = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub03_V3_alignments_random_data.npy')
sub3_fMRI_V3_resnet_shuf = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub03_V3_alignments_shuffled_order.npy')

# hV4
sub1_fMRI_hV4_resnet_orig = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub01_hV4_alignments_original_order.npy')
sub1_fMRI_hV4_resnet_rand = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub01_hV4_alignments_random_data.npy')
sub1_fMRI_hV4_resnet_shuf = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub01_hV4_alignments_shuffled_order.npy')

sub2_fMRI_hV4_resnet_orig = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub02_hV4_alignments_original_order.npy')
sub2_fMRI_hV4_resnet_rand = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub02_hV4_alignments_random_data.npy')
sub2_fMRI_hV4_resnet_shuf = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub02_hV4_alignments_shuffled_order.npy')

sub3_fMRI_hV4_resnet_orig = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub03_hV4_alignments_original_order.npy')
sub3_fMRI_hV4_resnet_rand = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub03_hV4_alignments_random_data.npy')
sub3_fMRI_hV4_resnet_shuf = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub03_hV4_alignments_shuffled_order.npy')

# VO1
sub1_fMRI_VO1_resnet_orig = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub01_VO1_alignments_original_order.npy')
sub1_fMRI_VO1_resnet_rand = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub01_VO1_alignments_random_data.npy')
sub1_fMRI_VO1_resnet_shuf = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub01_VO1_alignments_shuffled_order.npy')

sub2_fMRI_VO1_resnet_orig = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub02_VO1_alignments_original_order.npy')
sub2_fMRI_VO1_resnet_rand = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub02_VO1_alignments_random_data.npy')
sub2_fMRI_VO1_resnet_shuf = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub02_VO1_alignments_shuffled_order.npy')

sub3_fMRI_VO1_resnet_orig = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub03_VO1_alignments_original_order.npy')
sub3_fMRI_VO1_resnet_rand = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub03_VO1_alignments_random_data.npy')
sub3_fMRI_VO1_resnet_shuf = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub03_VO1_alignments_shuffled_order.npy')

# TO1
sub1_fMRI_TO1_resnet_orig = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub01_TO1_alignments_original_order.npy')
sub1_fMRI_TO1_resnet_rand = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub01_TO1_alignments_random_data.npy')
sub1_fMRI_TO1_resnet_shuf = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub01_TO1_alignments_shuffled_order.npy')

sub2_fMRI_TO1_resnet_orig = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub02_TO1_alignments_original_order.npy')
sub2_fMRI_TO1_resnet_rand = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub02_TO1_alignments_random_data.npy')
sub2_fMRI_TO1_resnet_shuf = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub02_TO1_alignments_shuffled_order.npy')

sub3_fMRI_TO1_resnet_orig = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub03_TO1_alignments_original_order.npy')
sub3_fMRI_TO1_resnet_rand = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub03_TO1_alignments_random_data.npy')
sub3_fMRI_TO1_resnet_shuf = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub03_TO1_alignments_shuffled_order.npy')

# rFFA
sub1_fMRI_rFFA_resnet_orig = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub01_rFFA_alignments_original_order.npy')
sub1_fMRI_rFFA_resnet_rand = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub01_rFFA_alignments_random_data.npy')
sub1_fMRI_rFFA_resnet_shuf = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub01_rFFA_alignments_shuffled_order.npy')

sub2_fMRI_rFFA_resnet_orig = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub02_rFFA_alignments_original_order.npy')
sub2_fMRI_rFFA_resnet_rand = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub02_rFFA_alignments_random_data.npy')
sub2_fMRI_rFFA_resnet_shuf = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub02_rFFA_alignments_shuffled_order.npy')

sub3_fMRI_rFFA_resnet_orig = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub03_rFFA_alignments_original_order.npy')
sub3_fMRI_rFFA_resnet_rand = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub03_rFFA_alignments_random_data.npy')
sub3_fMRI_rFFA_resnet_shuf = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub03_rFFA_alignments_shuffled_order.npy')

# lFFA
sub1_fMRI_lFFA_resnet_orig = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub01_lFFA_alignments_original_order.npy')
sub1_fMRI_lFFA_resnet_rand = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub01_lFFA_alignments_random_data.npy')
sub1_fMRI_lFFA_resnet_shuf = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub01_lFFA_alignments_shuffled_order.npy')

sub2_fMRI_lFFA_resnet_orig = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub02_lFFA_alignments_original_order.npy')
sub2_fMRI_lFFA_resnet_rand = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub02_lFFA_alignments_random_data.npy')
sub2_fMRI_lFFA_resnet_shuf = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub02_lFFA_alignments_shuffled_order.npy')

sub3_fMRI_lFFA_resnet_orig = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub03_lFFA_alignments_original_order.npy')
sub3_fMRI_lFFA_resnet_rand = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub03_lFFA_alignments_random_data.npy')
sub3_fMRI_lFFA_resnet_shuf = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub03_lFFA_alignments_shuffled_order.npy')

# rEBA
sub1_fMRI_rEBA_resnet_orig = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub01_rEBA_alignments_original_order.npy')
sub1_fMRI_rEBA_resnet_rand = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub01_rEBA_alignments_random_data.npy')
sub1_fMRI_rEBA_resnet_shuf = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub01_rEBA_alignments_shuffled_order.npy')

sub2_fMRI_rEBA_resnet_orig = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub02_rEBA_alignments_original_order.npy')
sub2_fMRI_rEBA_resnet_rand = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub02_rEBA_alignments_random_data.npy')
sub2_fMRI_rEBA_resnet_shuf = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub02_rEBA_alignments_shuffled_order.npy')

sub3_fMRI_rEBA_resnet_orig = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub03_rEBA_alignments_original_order.npy')
sub3_fMRI_rEBA_resnet_rand = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub03_rEBA_alignments_random_data.npy')
sub3_fMRI_rEBA_resnet_shuf = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub03_rEBA_alignments_shuffled_order.npy')

# lEBA
sub1_fMRI_lEBA_resnet_orig = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub01_lEBA_alignments_original_order.npy')
sub1_fMRI_lEBA_resnet_rand = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub01_lEBA_alignments_random_data.npy')
sub1_fMRI_lEBA_resnet_shuf = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub01_lEBA_alignments_shuffled_order.npy')

sub2_fMRI_lEBA_resnet_orig = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub02_lEBA_alignments_original_order.npy')
sub2_fMRI_lEBA_resnet_rand = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub02_lEBA_alignments_random_data.npy')
sub2_fMRI_lEBA_resnet_shuf = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub02_lEBA_alignments_shuffled_order.npy')

sub3_fMRI_lEBA_resnet_orig = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub03_lEBA_alignments_original_order.npy')
sub3_fMRI_lEBA_resnet_rand = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub03_lEBA_alignments_random_data.npy')
sub3_fMRI_lEBA_resnet_shuf = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub03_lEBA_alignments_shuffled_order.npy')

# rPPA
sub1_fMRI_rPPA_resnet_orig = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub01_rPPA_alignments_original_order.npy')
sub1_fMRI_rPPA_resnet_rand = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub01_rPPA_alignments_random_data.npy')
sub1_fMRI_rPPA_resnet_shuf = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub01_rPPA_alignments_shuffled_order.npy')

sub2_fMRI_rPPA_resnet_orig = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub02_rPPA_alignments_original_order.npy')
sub2_fMRI_rPPA_resnet_rand = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub02_rPPA_alignments_random_data.npy')
sub2_fMRI_rPPA_resnet_shuf = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub02_rPPA_alignments_shuffled_order.npy')

sub3_fMRI_rPPA_resnet_orig = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub03_rPPA_alignments_original_order.npy')
sub3_fMRI_rPPA_resnet_rand = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub03_rPPA_alignments_random_data.npy')
sub3_fMRI_rPPA_resnet_shuf = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub03_rPPA_alignments_shuffled_order.npy')

# lPPA
sub1_fMRI_lPPA_resnet_orig = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub01_lPPA_alignments_original_order.npy')
sub1_fMRI_lPPA_resnet_rand = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub01_lPPA_alignments_random_data.npy')
sub1_fMRI_lPPA_resnet_shuf = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub01_lPPA_alignments_shuffled_order.npy')

sub2_fMRI_lPPA_resnet_orig = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub02_lPPA_alignments_original_order.npy')
sub2_fMRI_lPPA_resnet_rand = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub02_lPPA_alignments_random_data.npy')
sub2_fMRI_lPPA_resnet_shuf = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub02_lPPA_alignments_shuffled_order.npy')

sub3_fMRI_lPPA_resnet_orig = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub03_lPPA_alignments_original_order.npy')
sub3_fMRI_lPPA_resnet_rand = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub03_lPPA_alignments_random_data.npy')
sub3_fMRI_lPPA_resnet_shuf = np.load(data_dir / 'fMRI_results' / f'{model_name}_sub03_lPPA_alignments_shuffled_order.npy')

# %%
n = 15
resnet_idx = 4

# V1 - CKA biased
cka_biased = 0 # selects correct index, ignore semantics
tmp = np.hstack([sub1_fMRI_v1_resnet_orig[0, cka_biased, resnet_idx], sub2_fMRI_v1_resnet_orig[0, cka_biased, resnet_idx], sub3_fMRI_v1_resnet_orig[0, cka_biased, resnet_idx]])
fMRI_V1_CKA_biased_orig_m, fMRI_V1_CKA_biased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_V1_CKA_biased_orig_h = fMRI_V1_CKA_biased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_v1_resnet_rand[:, cka_biased, resnet_idx], sub2_fMRI_v1_resnet_rand[:, cka_biased, resnet_idx], sub3_fMRI_v1_resnet_rand[:, cka_biased, resnet_idx]])
fMRI_V1_CKA_biased_rand_m, fMRI_V1_CKA_biased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_V1_CKA_biased_rand_h = fMRI_V1_CKA_biased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_v1_resnet_shuf[:, cka_biased, resnet_idx], sub2_fMRI_v1_resnet_shuf[:, cka_biased, resnet_idx], sub3_fMRI_v1_resnet_shuf[:, cka_biased, resnet_idx]])
fMRI_V1_CKA_biased_shuf_m, fMRI_V1_CKA_biased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_V1_CKA_biased_shuf_h = fMRI_V1_CKA_biased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# V1 - CKA debiased
cka_biased = 1 # selects correct index, ignore semantics
tmp = np.hstack([sub1_fMRI_v1_resnet_orig[0, cka_biased, resnet_idx], sub2_fMRI_v1_resnet_orig[0, cka_biased, resnet_idx], sub3_fMRI_v1_resnet_orig[0, cka_biased, resnet_idx]])
fMRI_V1_CKA_debiased_orig_m, fMRI_V1_CKA_debiased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_V1_CKA_debiased_orig_h = fMRI_V1_CKA_debiased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_v1_resnet_rand[:, cka_biased, resnet_idx], sub2_fMRI_v1_resnet_rand[:, cka_biased, resnet_idx], sub3_fMRI_v1_resnet_rand[:, cka_biased, resnet_idx]])
fMRI_V1_CKA_debiased_rand_m, fMRI_V1_CKA_debiased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_V1_CKA_debiased_rand_h = fMRI_V1_CKA_debiased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_v1_resnet_shuf[:, cka_biased, resnet_idx], sub2_fMRI_v1_resnet_shuf[:, cka_biased, resnet_idx], sub3_fMRI_v1_resnet_shuf[:, cka_biased, resnet_idx]])
fMRI_V1_CKA_debiased_shuf_m, fMRI_V1_CKA_debiased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_V1_CKA_debiased_shuf_h = fMRI_V1_CKA_debiased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# -----------------------

# V2-  CKA biased
cka_biased = 0 # selects correct index, ignore semantics
tmp = np.hstack([sub1_fMRI_V2_resnet_orig[0, cka_biased, resnet_idx], sub2_fMRI_V2_resnet_orig[0, cka_biased, resnet_idx], sub3_fMRI_V2_resnet_orig[0, cka_biased, resnet_idx]])
fMRI_V2_CKA_biased_orig_m, fMRI_V2_CKA_biased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_V2_CKA_biased_orig_h = fMRI_V2_CKA_biased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_V2_resnet_rand[:, cka_biased, resnet_idx], sub2_fMRI_V2_resnet_rand[:, cka_biased, resnet_idx], sub3_fMRI_V2_resnet_rand[:, cka_biased, resnet_idx]])
fMRI_V2_CKA_biased_rand_m, fMRI_V2_CKA_biased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_V2_CKA_biased_rand_h = fMRI_V2_CKA_biased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_V2_resnet_shuf[:, cka_biased, resnet_idx], sub2_fMRI_V2_resnet_shuf[:, cka_biased, resnet_idx], sub3_fMRI_V2_resnet_shuf[:, cka_biased, resnet_idx]])
fMRI_V2_CKA_biased_shuf_m, fMRI_V2_CKA_biased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_V2_CKA_biased_shuf_h = fMRI_V2_CKA_biased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# V2 - CKA debiased
cka_biased = 1 # selects correct index, ignore semantics
tmp = np.hstack([sub1_fMRI_V2_resnet_orig[0, cka_biased, resnet_idx], sub2_fMRI_V2_resnet_orig[0, cka_biased, resnet_idx], sub3_fMRI_V2_resnet_orig[0, cka_biased, resnet_idx]])
fMRI_V2_CKA_debiased_orig_m, fMRI_V2_CKA_debiased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_V2_CKA_debiased_orig_h = fMRI_V2_CKA_debiased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_V2_resnet_rand[:, cka_biased, resnet_idx], sub2_fMRI_V2_resnet_rand[:, cka_biased, resnet_idx], sub3_fMRI_V2_resnet_rand[:, cka_biased, resnet_idx]])
fMRI_V2_CKA_debiased_rand_m, fMRI_V2_CKA_debiased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_V2_CKA_debiased_rand_h = fMRI_V2_CKA_debiased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_V2_resnet_shuf[:, cka_biased, resnet_idx], sub2_fMRI_V2_resnet_shuf[:, cka_biased, resnet_idx], sub3_fMRI_V2_resnet_shuf[:, cka_biased, resnet_idx]])
fMRI_V2_CKA_debiased_shuf_m, fMRI_V2_CKA_debiased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_V2_CKA_debiased_shuf_h = fMRI_V2_CKA_debiased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1) 

# -----------------

# V3 -  CKA biased
cka_biased = 0 # selects correct index, ignore semantics
tmp = np.hstack([sub1_fMRI_V3_resnet_orig[0, cka_biased, resnet_idx], sub2_fMRI_V3_resnet_orig[0, cka_biased, resnet_idx], sub3_fMRI_V3_resnet_orig[0, cka_biased, resnet_idx]])
fMRI_V3_CKA_biased_orig_m, fMRI_V3_CKA_biased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_V3_CKA_biased_orig_h = fMRI_V3_CKA_biased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_V3_resnet_rand[:, cka_biased, resnet_idx], sub2_fMRI_V3_resnet_rand[:, cka_biased, resnet_idx], sub3_fMRI_V3_resnet_rand[:, cka_biased, resnet_idx]])
fMRI_V3_CKA_biased_rand_m, fMRI_V3_CKA_biased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_V3_CKA_biased_rand_h = fMRI_V3_CKA_biased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_V3_resnet_shuf[:, cka_biased, resnet_idx], sub2_fMRI_V3_resnet_shuf[:, cka_biased, resnet_idx], sub3_fMRI_V3_resnet_shuf[:, cka_biased, resnet_idx]])
fMRI_V3_CKA_biased_shuf_m, fMRI_V3_CKA_biased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_V3_CKA_biased_shuf_h = fMRI_V3_CKA_biased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# V3 - CKA debiased
cka_biased = 1 # selects correct index, ignore semantics
tmp = np.hstack([sub1_fMRI_V3_resnet_orig[0, cka_biased, resnet_idx], sub2_fMRI_V3_resnet_orig[0, cka_biased, resnet_idx], sub3_fMRI_V3_resnet_orig[0, cka_biased, resnet_idx]])
fMRI_V3_CKA_debiased_orig_m, fMRI_V3_CKA_debiased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_V3_CKA_debiased_orig_h = fMRI_V3_CKA_debiased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_V3_resnet_rand[:, cka_biased, resnet_idx], sub2_fMRI_V3_resnet_rand[:, cka_biased, resnet_idx], sub3_fMRI_V3_resnet_rand[:, cka_biased, resnet_idx]])
fMRI_V3_CKA_debiased_rand_m, fMRI_V3_CKA_debiased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_V3_CKA_debiased_rand_h = fMRI_V3_CKA_debiased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_V3_resnet_shuf[:, cka_biased, resnet_idx], sub2_fMRI_V3_resnet_shuf[:, cka_biased, resnet_idx], sub3_fMRI_V3_resnet_shuf[:, cka_biased, resnet_idx]])
fMRI_V3_CKA_debiased_shuf_m, fMRI_V3_CKA_debiased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_V3_CKA_debiased_shuf_h = fMRI_V3_CKA_debiased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1) 

# -------------

# hV4 -  CKA biased
cka_biased = 0 # selects correct index, ignore semantics
tmp = np.hstack([sub1_fMRI_hV4_resnet_orig[0, cka_biased, resnet_idx], sub2_fMRI_hV4_resnet_orig[0, cka_biased, resnet_idx], sub3_fMRI_hV4_resnet_orig[0, cka_biased, resnet_idx]])
fMRI_hV4_CKA_biased_orig_m, fMRI_hV4_CKA_biased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_hV4_CKA_biased_orig_h = fMRI_hV4_CKA_biased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_hV4_resnet_rand[:, cka_biased, resnet_idx], sub2_fMRI_hV4_resnet_rand[:, cka_biased, resnet_idx], sub3_fMRI_hV4_resnet_rand[:, cka_biased, resnet_idx]])
fMRI_hV4_CKA_biased_rand_m, fMRI_hV4_CKA_biased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_hV4_CKA_biased_rand_h = fMRI_hV4_CKA_biased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_hV4_resnet_shuf[:, cka_biased, resnet_idx], sub2_fMRI_hV4_resnet_shuf[:, cka_biased, resnet_idx], sub3_fMRI_hV4_resnet_shuf[:, cka_biased, resnet_idx]])
fMRI_hV4_CKA_biased_shuf_m, fMRI_hV4_CKA_biased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_hV4_CKA_biased_shuf_h = fMRI_hV4_CKA_biased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# hV4 - CKA debiased
cka_biased = 1 # selects correct index, ignore semantics
tmp = np.hstack([sub1_fMRI_hV4_resnet_orig[0, cka_biased, resnet_idx], sub2_fMRI_hV4_resnet_orig[0, cka_biased, resnet_idx], sub3_fMRI_hV4_resnet_orig[0, cka_biased, resnet_idx]])
fMRI_hV4_CKA_debiased_orig_m, fMRI_hV4_CKA_debiased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_hV4_CKA_debiased_orig_h = fMRI_hV4_CKA_debiased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_hV4_resnet_rand[:, cka_biased, resnet_idx], sub2_fMRI_hV4_resnet_rand[:, cka_biased, resnet_idx], sub3_fMRI_hV4_resnet_rand[:, cka_biased, resnet_idx]])
fMRI_hV4_CKA_debiased_rand_m, fMRI_hV4_CKA_debiased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_hV4_CKA_debiased_rand_h = fMRI_hV4_CKA_debiased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_hV4_resnet_shuf[:, cka_biased, resnet_idx], sub2_fMRI_hV4_resnet_shuf[:, cka_biased, resnet_idx], sub3_fMRI_hV4_resnet_shuf[:, cka_biased, resnet_idx]])
fMRI_hV4_CKA_debiased_shuf_m, fMRI_hV4_CKA_debiased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_hV4_CKA_debiased_shuf_h = fMRI_hV4_CKA_debiased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1) 

# ----------------

# VO1 -  CKA biased
cka_biased = 0 # selects correct index, ignore semantics
tmp = np.hstack([sub1_fMRI_VO1_resnet_orig[0, cka_biased, resnet_idx], sub2_fMRI_VO1_resnet_orig[0, cka_biased, resnet_idx], sub3_fMRI_VO1_resnet_orig[0, cka_biased, resnet_idx]])
fMRI_VO1_CKA_biased_orig_m, fMRI_VO1_CKA_biased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_VO1_CKA_biased_orig_h = fMRI_VO1_CKA_biased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_VO1_resnet_rand[:, cka_biased, resnet_idx], sub2_fMRI_VO1_resnet_rand[:, cka_biased, resnet_idx], sub3_fMRI_VO1_resnet_rand[:, cka_biased, resnet_idx]])
fMRI_VO1_CKA_biased_rand_m, fMRI_VO1_CKA_biased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_VO1_CKA_biased_rand_h = fMRI_VO1_CKA_biased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_VO1_resnet_shuf[:, cka_biased, resnet_idx], sub2_fMRI_VO1_resnet_shuf[:, cka_biased, resnet_idx], sub3_fMRI_VO1_resnet_shuf[:, cka_biased, resnet_idx]])
fMRI_VO1_CKA_biased_shuf_m, fMRI_VO1_CKA_biased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_VO1_CKA_biased_shuf_h = fMRI_VO1_CKA_biased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# VO1 - CKA debiased
cka_biased = 1 # selects correct index, ignore semantics
tmp = np.hstack([sub1_fMRI_VO1_resnet_orig[0, cka_biased, resnet_idx], sub2_fMRI_VO1_resnet_orig[0, cka_biased, resnet_idx], sub3_fMRI_VO1_resnet_orig[0, cka_biased, resnet_idx]])
fMRI_VO1_CKA_debiased_orig_m, fMRI_VO1_CKA_debiased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_VO1_CKA_debiased_orig_h = fMRI_VO1_CKA_debiased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_VO1_resnet_rand[:, cka_biased, resnet_idx], sub2_fMRI_VO1_resnet_rand[:, cka_biased, resnet_idx], sub3_fMRI_VO1_resnet_rand[:, cka_biased, resnet_idx]])
fMRI_VO1_CKA_debiased_rand_m, fMRI_VO1_CKA_debiased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_VO1_CKA_debiased_rand_h = fMRI_VO1_CKA_debiased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_VO1_resnet_shuf[:, cka_biased, resnet_idx], sub2_fMRI_VO1_resnet_shuf[:, cka_biased, resnet_idx], sub3_fMRI_VO1_resnet_shuf[:, cka_biased, resnet_idx]])
fMRI_VO1_CKA_debiased_shuf_m, fMRI_VO1_CKA_debiased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_VO1_CKA_debiased_shuf_h = fMRI_VO1_CKA_debiased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1) 

# --------------------


# TO1 -  CKA biased
cka_biased = 0 # selects correct index, ignore semantics
tmp = np.hstack([sub1_fMRI_TO1_resnet_orig[0, cka_biased, resnet_idx], sub2_fMRI_TO1_resnet_orig[0, cka_biased, resnet_idx], sub3_fMRI_TO1_resnet_orig[0, cka_biased, resnet_idx]])
fMRI_TO1_CKA_biased_orig_m, fMRI_TO1_CKA_biased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_TO1_CKA_biased_orig_h = fMRI_TO1_CKA_biased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_TO1_resnet_rand[:, cka_biased, resnet_idx], sub2_fMRI_TO1_resnet_rand[:, cka_biased, resnet_idx], sub3_fMRI_TO1_resnet_rand[:, cka_biased, resnet_idx]])
fMRI_TO1_CKA_biased_rand_m, fMRI_TO1_CKA_biased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_TO1_CKA_biased_rand_h = fMRI_TO1_CKA_biased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_TO1_resnet_shuf[:, cka_biased, resnet_idx], sub2_fMRI_TO1_resnet_shuf[:, cka_biased, resnet_idx], sub3_fMRI_TO1_resnet_shuf[:, cka_biased, resnet_idx]])
fMRI_TO1_CKA_biased_shuf_m, fMRI_TO1_CKA_biased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_TO1_CKA_biased_shuf_h = fMRI_TO1_CKA_biased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# TO1 - CKA debiased
cka_biased = 1 # selects correct index, ignore semantics
tmp = np.hstack([sub1_fMRI_TO1_resnet_orig[0, cka_biased, resnet_idx], sub2_fMRI_TO1_resnet_orig[0, cka_biased, resnet_idx], sub3_fMRI_TO1_resnet_orig[0, cka_biased, resnet_idx]])
fMRI_TO1_CKA_debiased_orig_m, fMRI_TO1_CKA_debiased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_TO1_CKA_debiased_orig_h = fMRI_TO1_CKA_debiased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_TO1_resnet_rand[:, cka_biased, resnet_idx], sub2_fMRI_TO1_resnet_rand[:, cka_biased, resnet_idx], sub3_fMRI_TO1_resnet_rand[:, cka_biased, resnet_idx]])
fMRI_TO1_CKA_debiased_rand_m, fMRI_TO1_CKA_debiased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_TO1_CKA_debiased_rand_h = fMRI_TO1_CKA_debiased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_TO1_resnet_shuf[:, cka_biased, resnet_idx], sub2_fMRI_TO1_resnet_shuf[:, cka_biased, resnet_idx], sub3_fMRI_TO1_resnet_shuf[:, cka_biased, resnet_idx]])
fMRI_TO1_CKA_debiased_shuf_m, fMRI_TO1_CKA_debiased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_TO1_CKA_debiased_shuf_h = fMRI_TO1_CKA_debiased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1) 

# ---------------------

# rFFA -  CKA biased
cka_biased = 0 # selects correct index, ignore semantics
tmp = np.hstack([sub1_fMRI_rFFA_resnet_orig[0, cka_biased, resnet_idx], sub2_fMRI_rFFA_resnet_orig[0, cka_biased, resnet_idx], sub3_fMRI_rFFA_resnet_orig[0, cka_biased, resnet_idx]])
fMRI_rFFA_CKA_biased_orig_m, fMRI_rFFA_CKA_biased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_rFFA_CKA_biased_orig_h = fMRI_rFFA_CKA_biased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_rFFA_resnet_rand[:, cka_biased, resnet_idx], sub2_fMRI_rFFA_resnet_rand[:, cka_biased, resnet_idx], sub3_fMRI_rFFA_resnet_rand[:, cka_biased, resnet_idx]])
fMRI_rFFA_CKA_biased_rand_m, fMRI_rFFA_CKA_biased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_rFFA_CKA_biased_rand_h = fMRI_rFFA_CKA_biased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_rFFA_resnet_shuf[:, cka_biased, resnet_idx], sub2_fMRI_rFFA_resnet_shuf[:, cka_biased, resnet_idx], sub3_fMRI_rFFA_resnet_shuf[:, cka_biased, resnet_idx]])
fMRI_rFFA_CKA_biased_shuf_m, fMRI_rFFA_CKA_biased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_rFFA_CKA_biased_shuf_h = fMRI_rFFA_CKA_biased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# rFFA - CKA debiased
cka_biased = 1 # selects correct index, ignore semantics
tmp = np.hstack([sub1_fMRI_rFFA_resnet_orig[0, cka_biased, resnet_idx], sub2_fMRI_rFFA_resnet_orig[0, cka_biased, resnet_idx], sub3_fMRI_rFFA_resnet_orig[0, cka_biased, resnet_idx]])
fMRI_rFFA_CKA_debiased_orig_m, fMRI_rFFA_CKA_debiased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_rFFA_CKA_debiased_orig_h = fMRI_rFFA_CKA_debiased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_rFFA_resnet_rand[:, cka_biased, resnet_idx], sub2_fMRI_rFFA_resnet_rand[:, cka_biased, resnet_idx], sub3_fMRI_rFFA_resnet_rand[:, cka_biased, resnet_idx]])
fMRI_rFFA_CKA_debiased_rand_m, fMRI_rFFA_CKA_debiased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_rFFA_CKA_debiased_rand_h = fMRI_rFFA_CKA_debiased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_rFFA_resnet_shuf[:, cka_biased, resnet_idx], sub2_fMRI_rFFA_resnet_shuf[:, cka_biased, resnet_idx], sub3_fMRI_rFFA_resnet_shuf[:, cka_biased, resnet_idx]])
fMRI_rFFA_CKA_debiased_shuf_m, fMRI_rFFA_CKA_debiased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_rFFA_CKA_debiased_shuf_h = fMRI_rFFA_CKA_debiased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1) 

# ---------------------

# lFFA -  CKA biased
cka_biased = 0 # selects correct index, ignore semantics
tmp = np.hstack([sub1_fMRI_lFFA_resnet_orig[0, cka_biased, resnet_idx], sub2_fMRI_lFFA_resnet_orig[0, cka_biased, resnet_idx], sub3_fMRI_lFFA_resnet_orig[0, cka_biased, resnet_idx]])
fMRI_lFFA_CKA_biased_orig_m, fMRI_lFFA_CKA_biased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_lFFA_CKA_biased_orig_h = fMRI_lFFA_CKA_biased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_lFFA_resnet_rand[:, cka_biased, resnet_idx], sub2_fMRI_lFFA_resnet_rand[:, cka_biased, resnet_idx], sub3_fMRI_lFFA_resnet_rand[:, cka_biased, resnet_idx]])
fMRI_lFFA_CKA_biased_rand_m, fMRI_lFFA_CKA_biased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_lFFA_CKA_biased_rand_h = fMRI_lFFA_CKA_biased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_lFFA_resnet_shuf[:, cka_biased, resnet_idx], sub2_fMRI_lFFA_resnet_shuf[:, cka_biased, resnet_idx], sub3_fMRI_lFFA_resnet_shuf[:, cka_biased, resnet_idx]])
fMRI_lFFA_CKA_biased_shuf_m, fMRI_lFFA_CKA_biased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_lFFA_CKA_biased_shuf_h = fMRI_lFFA_CKA_biased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# lFFA - CKA debiased
cka_biased = 1 # selects correct index, ignore semantics
tmp = np.hstack([sub1_fMRI_lFFA_resnet_orig[0, cka_biased, resnet_idx], sub2_fMRI_lFFA_resnet_orig[0, cka_biased, resnet_idx], sub3_fMRI_lFFA_resnet_orig[0, cka_biased, resnet_idx]])
fMRI_lFFA_CKA_debiased_orig_m, fMRI_lFFA_CKA_debiased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_lFFA_CKA_debiased_orig_h = fMRI_lFFA_CKA_debiased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_lFFA_resnet_rand[:, cka_biased, resnet_idx], sub2_fMRI_lFFA_resnet_rand[:, cka_biased, resnet_idx], sub3_fMRI_lFFA_resnet_rand[:, cka_biased, resnet_idx]])
fMRI_lFFA_CKA_debiased_rand_m, fMRI_lFFA_CKA_debiased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_lFFA_CKA_debiased_rand_h = fMRI_lFFA_CKA_debiased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_lFFA_resnet_shuf[:, cka_biased, resnet_idx], sub2_fMRI_lFFA_resnet_shuf[:, cka_biased, resnet_idx], sub3_fMRI_lFFA_resnet_shuf[:, cka_biased, resnet_idx]])
fMRI_lFFA_CKA_debiased_shuf_m, fMRI_lFFA_CKA_debiased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_lFFA_CKA_debiased_shuf_h = fMRI_lFFA_CKA_debiased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1) 

# ---------------------

# rPPA -  CKA biased
cka_biased = 0 # selects correct index, ignore semantics
tmp = np.hstack([sub1_fMRI_rPPA_resnet_orig[0, cka_biased, resnet_idx], sub2_fMRI_rPPA_resnet_orig[0, cka_biased, resnet_idx], sub3_fMRI_rPPA_resnet_orig[0, cka_biased, resnet_idx]])
fMRI_rPPA_CKA_biased_orig_m, fMRI_rPPA_CKA_biased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_rPPA_CKA_biased_orig_h = fMRI_rPPA_CKA_biased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_rPPA_resnet_rand[:, cka_biased, resnet_idx], sub2_fMRI_rPPA_resnet_rand[:, cka_biased, resnet_idx], sub3_fMRI_rPPA_resnet_rand[:, cka_biased, resnet_idx]])
fMRI_rPPA_CKA_biased_rand_m, fMRI_rPPA_CKA_biased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_rPPA_CKA_biased_rand_h = fMRI_rPPA_CKA_biased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_rPPA_resnet_shuf[:, cka_biased, resnet_idx], sub2_fMRI_rPPA_resnet_shuf[:, cka_biased, resnet_idx], sub3_fMRI_rPPA_resnet_shuf[:, cka_biased, resnet_idx]])
fMRI_rPPA_CKA_biased_shuf_m, fMRI_rPPA_CKA_biased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_rPPA_CKA_biased_shuf_h = fMRI_rPPA_CKA_biased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# rPPA - CKA debiased
cka_biased = 1 # selects correct index, ignore semantics
tmp = np.hstack([sub1_fMRI_rPPA_resnet_orig[0, cka_biased, resnet_idx], sub2_fMRI_rPPA_resnet_orig[0, cka_biased, resnet_idx], sub3_fMRI_rPPA_resnet_orig[0, cka_biased, resnet_idx]])
fMRI_rPPA_CKA_debiased_orig_m, fMRI_rPPA_CKA_debiased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_rPPA_CKA_debiased_orig_h = fMRI_rPPA_CKA_debiased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_rPPA_resnet_rand[:, cka_biased, resnet_idx], sub2_fMRI_rPPA_resnet_rand[:, cka_biased, resnet_idx], sub3_fMRI_rPPA_resnet_rand[:, cka_biased, resnet_idx]])
fMRI_rPPA_CKA_debiased_rand_m, fMRI_rPPA_CKA_debiased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_rPPA_CKA_debiased_rand_h = fMRI_rPPA_CKA_debiased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_rPPA_resnet_shuf[:, cka_biased, resnet_idx], sub2_fMRI_rPPA_resnet_shuf[:, cka_biased, resnet_idx], sub3_fMRI_rPPA_resnet_shuf[:, cka_biased, resnet_idx]])
fMRI_rPPA_CKA_debiased_shuf_m, fMRI_rPPA_CKA_debiased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_rPPA_CKA_debiased_shuf_h = fMRI_rPPA_CKA_debiased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1) 

# ---------------------

# lPPA -  CKA biased
cka_biased = 0 # selects correct index, ignore semantics
tmp = np.hstack([sub1_fMRI_lPPA_resnet_orig[0, cka_biased, resnet_idx], sub2_fMRI_lPPA_resnet_orig[0, cka_biased, resnet_idx], sub3_fMRI_lPPA_resnet_orig[0, cka_biased, resnet_idx]])
fMRI_lPPA_CKA_biased_orig_m, fMRI_lPPA_CKA_biased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_lPPA_CKA_biased_orig_h = fMRI_lPPA_CKA_biased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., 3-1)

tmp = np.hstack([sub1_fMRI_lPPA_resnet_rand[:, cka_biased, resnet_idx], sub2_fMRI_lPPA_resnet_rand[:, cka_biased, resnet_idx], sub3_fMRI_lPPA_resnet_rand[:, cka_biased, resnet_idx]])
fMRI_lPPA_CKA_biased_rand_m, fMRI_lPPA_CKA_biased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_lPPA_CKA_biased_rand_h = fMRI_lPPA_CKA_biased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_lPPA_resnet_shuf[:, cka_biased, resnet_idx], sub2_fMRI_lPPA_resnet_shuf[:, cka_biased, resnet_idx], sub3_fMRI_lPPA_resnet_shuf[:, cka_biased, resnet_idx]])
fMRI_lPPA_CKA_biased_shuf_m, fMRI_lPPA_CKA_biased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_lPPA_CKA_biased_shuf_h = fMRI_lPPA_CKA_biased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# lPPA - CKA debiased
cka_biased = 1 # selects correct index, ignore semantics
tmp = np.hstack([sub1_fMRI_lPPA_resnet_orig[0, cka_biased, resnet_idx], sub2_fMRI_lPPA_resnet_orig[0, cka_biased, resnet_idx], sub3_fMRI_lPPA_resnet_orig[0, cka_biased, resnet_idx]])
fMRI_lPPA_CKA_debiased_orig_m, fMRI_lPPA_CKA_debiased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_lPPA_CKA_debiased_orig_h = fMRI_lPPA_CKA_debiased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., 3-1)

tmp = np.hstack([sub1_fMRI_lPPA_resnet_rand[:, cka_biased, resnet_idx], sub2_fMRI_lPPA_resnet_rand[:, cka_biased, resnet_idx], sub3_fMRI_lPPA_resnet_rand[:, cka_biased, resnet_idx]])
fMRI_lPPA_CKA_debiased_rand_m, fMRI_lPPA_CKA_debiased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_lPPA_CKA_debiased_rand_h = fMRI_lPPA_CKA_debiased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_lPPA_resnet_shuf[:, cka_biased, resnet_idx], sub2_fMRI_lPPA_resnet_shuf[:, cka_biased, resnet_idx], sub3_fMRI_lPPA_resnet_shuf[:, cka_biased, resnet_idx]])
fMRI_lPPA_CKA_debiased_shuf_m, fMRI_lPPA_CKA_debiased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_lPPA_CKA_debiased_shuf_h = fMRI_lPPA_CKA_debiased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1) 

# ---------------------


# rEBA -  CKA biased
cka_biased = 0 # selects correct index, ignore semantics
tmp = np.hstack([sub1_fMRI_rEBA_resnet_orig[0, cka_biased, resnet_idx], sub2_fMRI_rEBA_resnet_orig[0, cka_biased, resnet_idx], sub3_fMRI_rEBA_resnet_orig[0, cka_biased, resnet_idx]])
fMRI_rEBA_CKA_biased_orig_m, fMRI_rEBA_CKA_biased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_rEBA_CKA_biased_orig_h = fMRI_rEBA_CKA_biased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., 3-1)

tmp = np.hstack([sub1_fMRI_rEBA_resnet_rand[:, cka_biased, resnet_idx], sub2_fMRI_rEBA_resnet_rand[:, cka_biased, resnet_idx], sub3_fMRI_rEBA_resnet_rand[:, cka_biased, resnet_idx]])
fMRI_rEBA_CKA_biased_rand_m, fMRI_rEBA_CKA_biased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_rEBA_CKA_biased_rand_h = fMRI_rEBA_CKA_biased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_rEBA_resnet_shuf[:, cka_biased, resnet_idx], sub2_fMRI_rEBA_resnet_shuf[:, cka_biased, resnet_idx], sub3_fMRI_rEBA_resnet_shuf[:, cka_biased, resnet_idx]])
fMRI_rEBA_CKA_biased_shuf_m, fMRI_rEBA_CKA_biased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_rEBA_CKA_biased_shuf_h = fMRI_rEBA_CKA_biased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# rEBA - CKA debiased
cka_biased = 1 # selects correct index, ignore semantics
tmp = np.hstack([sub1_fMRI_rEBA_resnet_orig[0, cka_biased, resnet_idx], sub2_fMRI_rEBA_resnet_orig[0, cka_biased, resnet_idx], sub3_fMRI_rEBA_resnet_orig[0, cka_biased, resnet_idx]])
fMRI_rEBA_CKA_debiased_orig_m, fMRI_rEBA_CKA_debiased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_rEBA_CKA_debiased_orig_h = fMRI_rEBA_CKA_debiased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_rEBA_resnet_rand[:, cka_biased, resnet_idx], sub2_fMRI_rEBA_resnet_rand[:, cka_biased, resnet_idx], sub3_fMRI_rEBA_resnet_rand[:, cka_biased, resnet_idx]])
fMRI_rEBA_CKA_debiased_rand_m, fMRI_rEBA_CKA_debiased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_rEBA_CKA_debiased_rand_h = fMRI_rEBA_CKA_debiased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_rEBA_resnet_shuf[:, cka_biased, resnet_idx], sub2_fMRI_rEBA_resnet_shuf[:, cka_biased, resnet_idx], sub3_fMRI_rEBA_resnet_shuf[:, cka_biased, resnet_idx]])
fMRI_rEBA_CKA_debiased_shuf_m, fMRI_rEBA_CKA_debiased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_rEBA_CKA_debiased_shuf_h = fMRI_rEBA_CKA_debiased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1) 

# ---------------------

# lEBA -  CKA biased
cka_biased = 0 # selects correct index, ignore semantics
tmp = np.hstack([sub1_fMRI_lEBA_resnet_orig[0, cka_biased, resnet_idx], sub2_fMRI_lEBA_resnet_orig[0, cka_biased, resnet_idx], sub3_fMRI_lEBA_resnet_orig[0, cka_biased, resnet_idx]])
fMRI_lEBA_CKA_biased_orig_m, fMRI_lEBA_CKA_biased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_lEBA_CKA_biased_orig_h = fMRI_lEBA_CKA_biased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_lEBA_resnet_rand[:, cka_biased, resnet_idx], sub2_fMRI_lEBA_resnet_rand[:, cka_biased, resnet_idx], sub3_fMRI_lEBA_resnet_rand[:, cka_biased, resnet_idx]])
fMRI_lEBA_CKA_biased_rand_m, fMRI_lEBA_CKA_biased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_lEBA_CKA_biased_rand_h = fMRI_lEBA_CKA_biased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_lEBA_resnet_shuf[:, cka_biased, resnet_idx], sub2_fMRI_lEBA_resnet_shuf[:, cka_biased, resnet_idx], sub3_fMRI_lEBA_resnet_shuf[:, cka_biased, resnet_idx]])
fMRI_lEBA_CKA_biased_shuf_m, fMRI_lEBA_CKA_biased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_lEBA_CKA_biased_shuf_h = fMRI_lEBA_CKA_biased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# lEBA - CKA debiased
cka_biased = 1 # selects correct index, ignore semantics
tmp = np.hstack([sub1_fMRI_lEBA_resnet_orig[0, cka_biased, resnet_idx], sub2_fMRI_lEBA_resnet_orig[0, cka_biased, resnet_idx], sub3_fMRI_lEBA_resnet_orig[0, cka_biased, resnet_idx]])
fMRI_lEBA_CKA_debiased_orig_m, fMRI_lEBA_CKA_debiased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_lEBA_CKA_debiased_orig_h = fMRI_lEBA_CKA_debiased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_lEBA_resnet_rand[:, cka_biased, resnet_idx], sub2_fMRI_lEBA_resnet_rand[:, cka_biased, resnet_idx], sub3_fMRI_lEBA_resnet_rand[:, cka_biased, resnet_idx]])
fMRI_lEBA_CKA_debiased_rand_m, fMRI_lEBA_CKA_debiased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_lEBA_CKA_debiased_rand_h = fMRI_lEBA_CKA_debiased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_fMRI_lEBA_resnet_shuf[:, cka_biased, resnet_idx], sub2_fMRI_lEBA_resnet_shuf[:, cka_biased, resnet_idx], sub3_fMRI_lEBA_resnet_shuf[:, cka_biased, resnet_idx]])
fMRI_lEBA_CKA_debiased_shuf_m, fMRI_lEBA_CKA_debiased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
fMRI_lEBA_CKA_debiased_shuf_h = fMRI_lEBA_CKA_debiased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1) 

# ---------------------

# %%
fig, axis = plt.subplots(figsize=(10,5))
axis = np.ravel(axis)

#rois = ['V1', 'V2', 'V3', 'hV4', 'VO1', 'TO1', 'lEBA', 'rEBA', 'lFFA', 'rFFA', 'lPPA', 'rPPA']
rois = ['lFFA', 'VO1', 'rFFA', 'TO1', 'lPPA', 'rPPA', 'lEBA', 'hV4', 'rEBA', 'V3', 'V2', 'V1']

# ORIG
resnet_cka_biased_orig_m = np.array([fMRI_lFFA_CKA_biased_orig_m, fMRI_VO1_CKA_biased_orig_m, fMRI_rFFA_CKA_biased_orig_m, fMRI_TO1_CKA_biased_orig_m, fMRI_lPPA_CKA_biased_orig_m,
                         fMRI_rPPA_CKA_biased_orig_m, fMRI_lEBA_CKA_biased_orig_m, fMRI_hV4_CKA_biased_orig_m, fMRI_rEBA_CKA_biased_orig_m, fMRI_V3_CKA_biased_orig_m,
                         fMRI_V2_CKA_biased_orig_m, fMRI_V1_CKA_biased_orig_m])

resnet_cka_biased_orig_h = np.array([fMRI_lFFA_CKA_biased_orig_h, fMRI_VO1_CKA_biased_orig_h, fMRI_rFFA_CKA_biased_orig_h, fMRI_TO1_CKA_biased_orig_h, fMRI_lPPA_CKA_biased_orig_h,
                         fMRI_rPPA_CKA_biased_orig_h, fMRI_lEBA_CKA_biased_orig_h, fMRI_hV4_CKA_biased_orig_h, fMRI_rEBA_CKA_biased_orig_h, fMRI_V3_CKA_biased_orig_h,
                         fMRI_V2_CKA_biased_orig_h, fMRI_V1_CKA_biased_orig_h])

m = resnet_cka_biased_orig_m
h = resnet_cka_biased_orig_h

axis[0].plot(rois, m, color='blue', label='Original', linestyle='-')
axis[0].fill_between(rois, m-h, m+h, color='blue', alpha=0.3)

resnet_cka_debiased_orig_m = np.array([fMRI_lFFA_CKA_debiased_orig_m, fMRI_VO1_CKA_debiased_orig_m, fMRI_rFFA_CKA_debiased_orig_m, fMRI_TO1_CKA_debiased_orig_m, fMRI_lPPA_CKA_debiased_orig_m,
                         fMRI_rPPA_CKA_debiased_orig_m, fMRI_lEBA_CKA_debiased_orig_m, fMRI_hV4_CKA_debiased_orig_m, fMRI_rEBA_CKA_debiased_orig_m, fMRI_V3_CKA_debiased_orig_m,
                         fMRI_V2_CKA_debiased_orig_m, fMRI_V1_CKA_debiased_orig_m])

resnet_cka_debiased_orig_h = np.array([fMRI_lFFA_CKA_debiased_orig_h, fMRI_VO1_CKA_debiased_orig_h, fMRI_rFFA_CKA_debiased_orig_h, fMRI_TO1_CKA_debiased_orig_h, fMRI_lPPA_CKA_debiased_orig_h,
                         fMRI_rPPA_CKA_debiased_orig_h, fMRI_lEBA_CKA_debiased_orig_h, fMRI_hV4_CKA_debiased_orig_h, fMRI_rEBA_CKA_debiased_orig_h, fMRI_V3_CKA_debiased_orig_h,
                         fMRI_V2_CKA_debiased_orig_h, fMRI_V1_CKA_debiased_orig_h])

m = resnet_cka_debiased_orig_m
h = resnet_cka_debiased_orig_h
axis[0].plot(rois, m, color='blue', label='Original', linestyle='--')
axis[0].fill_between(rois, m-h, m+h, color='blue', alpha=0.3)


# RAND
resnet_cka_biased_rand_m = np.array([fMRI_lFFA_CKA_biased_rand_m, fMRI_VO1_CKA_biased_rand_m, fMRI_rFFA_CKA_biased_rand_m, fMRI_TO1_CKA_biased_rand_m, fMRI_lPPA_CKA_biased_rand_m,
                         fMRI_rPPA_CKA_biased_rand_m, fMRI_lEBA_CKA_biased_rand_m, fMRI_hV4_CKA_biased_rand_m, fMRI_rEBA_CKA_biased_rand_m, fMRI_V3_CKA_biased_rand_m,
                         fMRI_V2_CKA_biased_rand_m, fMRI_V1_CKA_biased_rand_m])

resnet_cka_biased_rand_h = np.array([fMRI_lFFA_CKA_biased_rand_h, fMRI_VO1_CKA_biased_rand_h, fMRI_rFFA_CKA_biased_rand_h, fMRI_TO1_CKA_biased_rand_h, fMRI_lPPA_CKA_biased_rand_h,
                         fMRI_rPPA_CKA_biased_rand_h, fMRI_lEBA_CKA_biased_rand_h, fMRI_hV4_CKA_biased_rand_h, fMRI_rEBA_CKA_biased_rand_h, fMRI_V3_CKA_biased_rand_h,
                         fMRI_V2_CKA_biased_rand_h, fMRI_V1_CKA_biased_rand_h])

m = resnet_cka_biased_rand_m
h = resnet_cka_biased_rand_h

axis[0].plot(rois, m, color='red', label='Random', linestyle='-')
axis[0].fill_between(rois, m-h, m+h, color='red', alpha=0.3)

resnet_cka_debiased_rand_m = np.array([fMRI_lFFA_CKA_debiased_rand_m, fMRI_VO1_CKA_debiased_rand_m, fMRI_rFFA_CKA_debiased_rand_m, fMRI_TO1_CKA_debiased_rand_m, fMRI_lPPA_CKA_debiased_rand_m,
                         fMRI_rPPA_CKA_debiased_rand_m, fMRI_lEBA_CKA_debiased_rand_m, fMRI_hV4_CKA_debiased_rand_m, fMRI_rEBA_CKA_debiased_rand_m, fMRI_V3_CKA_debiased_rand_m,
                         fMRI_V2_CKA_debiased_rand_m, fMRI_V1_CKA_debiased_rand_m])

resnet_cka_debiased_rand_h = np.array([fMRI_lFFA_CKA_debiased_rand_h, fMRI_VO1_CKA_debiased_rand_h, fMRI_rFFA_CKA_debiased_rand_h, fMRI_TO1_CKA_debiased_rand_h, fMRI_lPPA_CKA_debiased_rand_h,
                         fMRI_rPPA_CKA_debiased_rand_h, fMRI_lEBA_CKA_debiased_rand_h, fMRI_hV4_CKA_debiased_rand_h, fMRI_rEBA_CKA_debiased_rand_h, fMRI_V3_CKA_debiased_rand_h,
                         fMRI_V2_CKA_debiased_rand_h, fMRI_V1_CKA_debiased_rand_h])

m = resnet_cka_debiased_rand_m
h = resnet_cka_debiased_rand_h

axis[0].plot(rois, m, color='red', label='Random', linestyle='--')
axis[0].fill_between(rois, m-h, m+h, color='red', alpha=0.3)

# SHUFFLED 
# RAND
resnet_cka_biased_shuf_m = np.array([fMRI_lFFA_CKA_biased_shuf_m, fMRI_VO1_CKA_biased_shuf_m, fMRI_rFFA_CKA_biased_shuf_m, fMRI_TO1_CKA_biased_shuf_m, fMRI_lPPA_CKA_biased_shuf_m,
                         fMRI_rPPA_CKA_biased_shuf_m, fMRI_lEBA_CKA_biased_shuf_m, fMRI_hV4_CKA_biased_shuf_m, fMRI_rEBA_CKA_biased_shuf_m, fMRI_V3_CKA_biased_shuf_m,
                         fMRI_V2_CKA_biased_shuf_m, fMRI_V1_CKA_biased_shuf_m])

resnet_cka_biased_shuf_h = np.array([fMRI_lFFA_CKA_biased_shuf_h, fMRI_VO1_CKA_biased_shuf_h, fMRI_rFFA_CKA_biased_shuf_h, fMRI_TO1_CKA_biased_shuf_h, fMRI_lPPA_CKA_biased_shuf_h,
                         fMRI_rPPA_CKA_biased_shuf_h, fMRI_lEBA_CKA_biased_shuf_h, fMRI_hV4_CKA_biased_shuf_h, fMRI_rEBA_CKA_biased_shuf_h, fMRI_V3_CKA_biased_shuf_h,
                         fMRI_V2_CKA_biased_shuf_h, fMRI_V1_CKA_biased_shuf_h])

m = resnet_cka_biased_shuf_m
h = resnet_cka_biased_shuf_h

axis[0].plot(rois, m, color='green', label='Shuffled', linestyle='-')
axis[0].fill_between(rois, m-h, m+h, color='green', alpha=0.3)

resnet_cka_debiased_shuf_m = np.array([fMRI_lFFA_CKA_debiased_shuf_m, fMRI_VO1_CKA_debiased_shuf_m, fMRI_rFFA_CKA_debiased_shuf_m, fMRI_TO1_CKA_debiased_shuf_m, fMRI_lPPA_CKA_debiased_shuf_m,
                         fMRI_rPPA_CKA_debiased_shuf_m, fMRI_lEBA_CKA_debiased_shuf_m, fMRI_hV4_CKA_debiased_shuf_m, fMRI_rEBA_CKA_debiased_shuf_m, fMRI_V3_CKA_debiased_shuf_m,
                         fMRI_V2_CKA_debiased_shuf_m, fMRI_V1_CKA_debiased_shuf_m])

resnet_cka_debiased_shuf_h = np.array([fMRI_lFFA_CKA_debiased_shuf_h, fMRI_VO1_CKA_debiased_shuf_h, fMRI_rFFA_CKA_debiased_shuf_h, fMRI_TO1_CKA_debiased_shuf_h, fMRI_lPPA_CKA_debiased_shuf_h,
                         fMRI_rPPA_CKA_debiased_shuf_h, fMRI_lEBA_CKA_debiased_shuf_h, fMRI_hV4_CKA_debiased_shuf_h, fMRI_rEBA_CKA_debiased_shuf_h, fMRI_V3_CKA_debiased_shuf_h,
                         fMRI_V2_CKA_debiased_shuf_h, fMRI_V1_CKA_debiased_shuf_h])

m = resnet_cka_debiased_shuf_m
h = resnet_cka_debiased_shuf_h

axis[0].plot(rois, m, color='green', label='Shuffled', linestyle='--')
axis[0].fill_between(rois, m-h, m+h, color='green', alpha=0.3)


plt.legend()
plt.savefig('fMRI_CORnet-s_ROIs_fixed_ANN_layer.svg', format='svg')

# %% [markdown]
# # MEG Figure
#
# * CORnet-S
# * Ever increasing temporal increments
# * Report alignment for one layer (conv in V2)

# %%
model_name = 'cornet_s'

# 50_100
sub1_MEG_50_100_cornet_orig = np.load(data_dir / 'meg_results' / f'{model_name}_sub1_50_100_alignments_original_order_occipital_notaveraged.npy')
sub1_MEG_50_100_cornet_rand = np.load(data_dir / 'meg_results' / f'{model_name}_sub1_50_100_alignments_random_data_occipital_notaveraged.npy')
sub1_MEG_50_100_cornet_shuf = np.load(data_dir / 'meg_results' / f'{model_name}_sub1_50_100_alignments_shuffled_order_occipital_notaveraged.npy')

sub3_MEG_50_100_cornet_orig = np.load(data_dir / 'meg_results' / f'{model_name}_sub3_50_100_alignments_original_order_occipital_notaveraged.npy')
sub3_MEG_50_100_cornet_rand = np.load(data_dir / 'meg_results' / f'{model_name}_sub3_50_100_alignments_random_data_occipital_notaveraged.npy')
sub3_MEG_50_100_cornet_shuf = np.load(data_dir / 'meg_results' / f'{model_name}_sub3_50_100_alignments_shuffled_order_occipital_notaveraged.npy')

sub4_MEG_50_100_cornet_orig = np.load(data_dir / 'meg_results' / f'{model_name}_sub4_50_100_alignments_original_order_occipital_notaveraged.npy')
sub4_MEG_50_100_cornet_rand = np.load(data_dir / 'meg_results' / f'{model_name}_sub4_50_100_alignments_random_data_occipital_notaveraged.npy')
sub4_MEG_50_100_cornet_shuf = np.load(data_dir / 'meg_results' / f'{model_name}_sub4_50_100_alignments_shuffled_order_occipital_notaveraged.npy')

# 50_150
sub1_MEG_50_150_cornet_orig = np.load(data_dir / 'meg_results' / f'{model_name}_sub1_50_150_alignments_original_order_occipital_notaveraged.npy')
sub1_MEG_50_150_cornet_rand = np.load(data_dir / 'meg_results' / f'{model_name}_sub1_50_150_alignments_random_data_occipital_notaveraged.npy')
sub1_MEG_50_150_cornet_shuf = np.load(data_dir / 'meg_results' / f'{model_name}_sub1_50_150_alignments_shuffled_order_occipital_notaveraged.npy')

sub3_MEG_50_150_cornet_orig = np.load(data_dir / 'meg_results' / f'{model_name}_sub3_50_150_alignments_original_order_occipital_notaveraged.npy')
sub3_MEG_50_150_cornet_rand = np.load(data_dir / 'meg_results' / f'{model_name}_sub3_50_150_alignments_random_data_occipital_notaveraged.npy')
sub3_MEG_50_150_cornet_shuf = np.load(data_dir / 'meg_results' / f'{model_name}_sub3_50_150_alignments_shuffled_order_occipital_notaveraged.npy')

sub4_MEG_50_150_cornet_orig = np.load(data_dir / 'meg_results' / f'{model_name}_sub4_50_150_alignments_original_order_occipital_notaveraged.npy')
sub4_MEG_50_150_cornet_rand = np.load(data_dir / 'meg_results' / f'{model_name}_sub4_50_150_alignments_random_data_occipital_notaveraged.npy')
sub4_MEG_50_150_cornet_shuf = np.load(data_dir / 'meg_results' / f'{model_name}_sub4_50_150_alignments_shuffled_order_occipital_notaveraged.npy')

# 50_200
sub1_MEG_50_200_cornet_orig = np.load(data_dir / 'meg_results' / f'{model_name}_sub1_50_200_alignments_original_order_occipital_notaveraged.npy')
sub1_MEG_50_200_cornet_rand = np.load(data_dir / 'meg_results' / f'{model_name}_sub1_50_200_alignments_random_data_occipital_notaveraged.npy')
sub1_MEG_50_200_cornet_shuf = np.load(data_dir / 'meg_results' / f'{model_name}_sub1_50_200_alignments_shuffled_order_occipital_notaveraged.npy')

sub3_MEG_50_200_cornet_orig = np.load(data_dir / 'meg_results' / f'{model_name}_sub3_50_200_alignments_original_order_occipital_notaveraged.npy')
sub3_MEG_50_200_cornet_rand = np.load(data_dir / 'meg_results' / f'{model_name}_sub3_50_200_alignments_random_data_occipital_notaveraged.npy')
sub3_MEG_50_200_cornet_shuf = np.load(data_dir / 'meg_results' / f'{model_name}_sub3_50_200_alignments_shuffled_order_occipital_notaveraged.npy')

sub4_MEG_50_200_cornet_orig = np.load(data_dir / 'meg_results' / f'{model_name}_sub4_50_200_alignments_original_order_occipital_notaveraged.npy')
sub4_MEG_50_200_cornet_rand = np.load(data_dir / 'meg_results' / f'{model_name}_sub4_50_200_alignments_random_data_occipital_notaveraged.npy')
sub4_MEG_50_200_cornet_shuf = np.load(data_dir / 'meg_results' / f'{model_name}_sub4_50_200_alignments_shuffled_order_occipital_notaveraged.npy')

# 50_250
sub1_MEG_50_250_cornet_orig = np.load(data_dir / 'meg_results' / f'{model_name}_sub1_50_250_alignments_original_order_occipital_notaveraged.npy')
sub1_MEG_50_250_cornet_rand = np.load(data_dir / 'meg_results' / f'{model_name}_sub1_50_250_alignments_random_data_occipital_notaveraged.npy')
sub1_MEG_50_250_cornet_shuf = np.load(data_dir / 'meg_results' / f'{model_name}_sub1_50_250_alignments_shuffled_order_occipital_notaveraged.npy')

sub3_MEG_50_250_cornet_orig = np.load(data_dir / 'meg_results' / f'{model_name}_sub3_50_250_alignments_original_order_occipital_notaveraged.npy')
sub3_MEG_50_250_cornet_rand = np.load(data_dir / 'meg_results' / f'{model_name}_sub3_50_250_alignments_random_data_occipital_notaveraged.npy')
sub3_MEG_50_250_cornet_shuf = np.load(data_dir / 'meg_results' / f'{model_name}_sub3_50_250_alignments_shuffled_order_occipital_notaveraged.npy')

sub4_MEG_50_250_cornet_orig = np.load(data_dir / 'meg_results' / f'{model_name}_sub4_50_250_alignments_original_order_occipital_notaveraged.npy')
sub4_MEG_50_250_cornet_rand = np.load(data_dir / 'meg_results' / f'{model_name}_sub4_50_250_alignments_random_data_occipital_notaveraged.npy')
sub4_MEG_50_250_cornet_shuf = np.load(data_dir / 'meg_results' / f'{model_name}_sub4_50_250_alignments_shuffled_order_occipital_notaveraged.npy')

# 50_300
sub1_MEG_50_300_cornet_orig = np.load(data_dir / 'meg_results' / f'{model_name}_sub1_50_300_alignments_original_order_occipital_notaveraged.npy')
sub1_MEG_50_300_cornet_rand = np.load(data_dir / 'meg_results' / f'{model_name}_sub1_50_300_alignments_random_data_occipital_notaveraged.npy')
sub1_MEG_50_300_cornet_shuf = np.load(data_dir / 'meg_results' / f'{model_name}_sub1_50_300_alignments_shuffled_order_occipital_notaveraged.npy')

sub3_MEG_50_300_cornet_orig = np.load(data_dir / 'meg_results' / f'{model_name}_sub3_50_300_alignments_original_order_occipital_notaveraged.npy')
sub3_MEG_50_300_cornet_rand = np.load(data_dir / 'meg_results' / f'{model_name}_sub3_50_300_alignments_random_data_occipital_notaveraged.npy')
sub3_MEG_50_300_cornet_shuf = np.load(data_dir / 'meg_results' / f'{model_name}_sub3_50_300_alignments_shuffled_order_occipital_notaveraged.npy')

sub4_MEG_50_300_cornet_orig = np.load(data_dir / 'meg_results' / f'{model_name}_sub4_50_300_alignments_original_order_occipital_notaveraged.npy')
sub4_MEG_50_300_cornet_rand = np.load(data_dir / 'meg_results' / f'{model_name}_sub4_50_300_alignments_random_data_occipital_notaveraged.npy')
sub4_MEG_50_300_cornet_shuf = np.load(data_dir / 'meg_results' / f'{model_name}_sub4_50_300_alignments_shuffled_order_occipital_notaveraged.npy')

# 50_350
sub1_MEG_50_350_cornet_orig = np.load(data_dir / 'meg_results' / f'{model_name}_sub1_50_350_alignments_original_order_occipital_notaveraged.npy')
sub1_MEG_50_350_cornet_rand = np.load(data_dir / 'meg_results' / f'{model_name}_sub1_50_350_alignments_random_data_occipital_notaveraged.npy')
sub1_MEG_50_350_cornet_shuf = np.load(data_dir / 'meg_results' / f'{model_name}_sub1_50_350_alignments_shuffled_order_occipital_notaveraged.npy')

sub3_MEG_50_350_cornet_orig = np.load(data_dir / 'meg_results' / f'{model_name}_sub3_50_350_alignments_original_order_occipital_notaveraged.npy')
sub3_MEG_50_350_cornet_rand = np.load(data_dir / 'meg_results' / f'{model_name}_sub3_50_350_alignments_random_data_occipital_notaveraged.npy')
sub3_MEG_50_350_cornet_shuf = np.load(data_dir / 'meg_results' / f'{model_name}_sub3_50_350_alignments_shuffled_order_occipital_notaveraged.npy')

sub4_MEG_50_350_cornet_orig = np.load(data_dir / 'meg_results' / f'{model_name}_sub4_50_350_alignments_original_order_occipital_notaveraged.npy')
sub4_MEG_50_350_cornet_rand = np.load(data_dir / 'meg_results' / f'{model_name}_sub4_50_350_alignments_random_data_occipital_notaveraged.npy')
sub4_MEG_50_350_cornet_shuf = np.load(data_dir / 'meg_results' / f'{model_name}_sub4_50_350_alignments_shuffled_order_occipital_notaveraged.npy')

# 50_400
sub1_MEG_50_400_cornet_orig = np.load(data_dir / 'meg_results' / f'{model_name}_sub1_50_400_alignments_original_order_occipital_notaveraged.npy')
sub1_MEG_50_400_cornet_rand = np.load(data_dir / 'meg_results' / f'{model_name}_sub1_50_400_alignments_random_data_occipital_notaveraged.npy')
sub1_MEG_50_400_cornet_shuf = np.load(data_dir / 'meg_results' / f'{model_name}_sub1_50_400_alignments_shuffled_order_occipital_notaveraged.npy')

sub3_MEG_50_400_cornet_orig = np.load(data_dir / 'meg_results' / f'{model_name}_sub3_50_400_alignments_original_order_occipital_notaveraged.npy')
sub3_MEG_50_400_cornet_rand = np.load(data_dir / 'meg_results' / f'{model_name}_sub3_50_400_alignments_random_data_occipital_notaveraged.npy')
sub3_MEG_50_400_cornet_shuf = np.load(data_dir / 'meg_results' / f'{model_name}_sub3_50_400_alignments_shuffled_order_occipital_notaveraged.npy')

sub4_MEG_50_400_cornet_orig = np.load(data_dir / 'meg_results' / f'{model_name}_sub4_50_400_alignments_original_order_occipital_notaveraged.npy')
sub4_MEG_50_400_cornet_rand = np.load(data_dir / 'meg_results' / f'{model_name}_sub4_50_400_alignments_random_data_occipital_notaveraged.npy')
sub4_MEG_50_400_cornet_shuf = np.load(data_dir / 'meg_results' / f'{model_name}_sub4_50_400_alignments_shuffled_order_occipital_notaveraged.npy')

# 50_450
sub1_MEG_50_450_cornet_orig = np.load(data_dir / 'meg_results' / f'{model_name}_sub1_50_450_alignments_original_order_occipital_notaveraged.npy')
sub1_MEG_50_450_cornet_rand = np.load(data_dir / 'meg_results' / f'{model_name}_sub1_50_450_alignments_random_data_occipital_notaveraged.npy')
sub1_MEG_50_450_cornet_shuf = np.load(data_dir / 'meg_results' / f'{model_name}_sub1_50_450_alignments_shuffled_order_occipital_notaveraged.npy')

sub3_MEG_50_450_cornet_orig = np.load(data_dir / 'meg_results' / f'{model_name}_sub3_50_450_alignments_original_order_occipital_notaveraged.npy')
sub3_MEG_50_450_cornet_rand = np.load(data_dir / 'meg_results' / f'{model_name}_sub3_50_450_alignments_random_data_occipital_notaveraged.npy')
sub3_MEG_50_450_cornet_shuf = np.load(data_dir / 'meg_results' / f'{model_name}_sub3_50_450_alignments_shuffled_order_occipital_notaveraged.npy')

sub4_MEG_50_450_cornet_orig = np.load(data_dir / 'meg_results' / f'{model_name}_sub4_50_450_alignments_original_order_occipital_notaveraged.npy')
sub4_MEG_50_450_cornet_rand = np.load(data_dir / 'meg_results' / f'{model_name}_sub4_50_450_alignments_random_data_occipital_notaveraged.npy')
sub4_MEG_50_450_cornet_shuf = np.load(data_dir / 'meg_results' / f'{model_name}_sub4_50_450_alignments_shuffled_order_occipital_notaveraged.npy')

# 50_500
sub1_MEG_50_500_cornet_orig = np.load(data_dir / 'meg_results' / f'{model_name}_sub1_50_500_alignments_original_order_occipital_notaveraged.npy')
sub1_MEG_50_500_cornet_rand = np.load(data_dir / 'meg_results' / f'{model_name}_sub1_50_500_alignments_random_data_occipital_notaveraged.npy')
sub1_MEG_50_500_cornet_shuf = np.load(data_dir / 'meg_results' / f'{model_name}_sub1_50_500_alignments_shuffled_order_occipital_notaveraged.npy')

sub3_MEG_50_500_cornet_orig = np.load(data_dir / 'meg_results' / f'{model_name}_sub3_50_500_alignments_original_order_occipital_notaveraged.npy')
sub3_MEG_50_500_cornet_rand = np.load(data_dir / 'meg_results' / f'{model_name}_sub3_50_500_alignments_random_data_occipital_notaveraged.npy')
sub3_MEG_50_500_cornet_shuf = np.load(data_dir / 'meg_results' / f'{model_name}_sub3_50_500_alignments_shuffled_order_occipital_notaveraged.npy')

sub4_MEG_50_500_cornet_orig = np.load(data_dir / 'meg_results' / f'{model_name}_sub4_50_500_alignments_original_order_occipital_notaveraged.npy')
sub4_MEG_50_500_cornet_rand = np.load(data_dir / 'meg_results' / f'{model_name}_sub4_50_500_alignments_random_data_occipital_notaveraged.npy')
sub4_MEG_50_500_cornet_shuf = np.load(data_dir / 'meg_results' / f'{model_name}_sub4_50_500_alignments_shuffled_order_occipital_notaveraged.npy')

# %%
# Load MEG results dictionary

import pickle

r = pickle.load(open('meg_results_dict.pkl', 'rb'))

# %%
r['MEG_sub1_50-100-orig'][0, 0, 3]

# %%
n = 15
cornet_idx = 3

# 50_100 - CKA biased
cka_biased = 0 # selects correct index, ignore semantics
tmp = np.hstack([r['MEG_sub1_50-100-orig'][0, cka_biased, cornet_idx], r['MEG_sub2_50-100-orig'][0, cka_biased, cornet_idx], r['MEG_sub4_50-100-orig'][0, cka_biased, cornet_idx]])
MEG_50_100_CKA_biased_orig_m, MEG_50_100_CKA_biased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_100_CKA_biased_orig_h = MEG_50_100_CKA_biased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([r['MEG_sub1_50-100-rand'][:, cka_biased, cornet_idx], r['MEG_sub2_50-100-rand'][:, cka_biased, cornet_idx], r['MEG_sub4_50-100-rand'][:, cka_biased, cornet_idx]])
MEG_50_100_CKA_biased_rand_m, MEG_50_100_CKA_biased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_100_CKA_biased_rand_h = MEG_50_100_CKA_biased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([r['MEG_sub1_50-100-shuf'][:, cka_biased, cornet_idx], r['MEG_sub2_50-100-shuf'][:, cka_biased, cornet_idx], r['MEG_sub4_50-100-shuf'][:, cka_biased, cornet_idx]])
MEG_50_100_CKA_biased_shuf_m, MEG_50_100_CKA_biased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_100_CKA_biased_shuf_h = MEG_50_100_CKA_biased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# 50_100 - CKA debiased
cka_biased = 1 # selects correct index, ignore semantics
tmp = np.hstack([r['MEG_sub1_50-100-orig'][0, cka_biased, cornet_idx], r['MEG_sub2_50-100-orig'][0, cka_biased, cornet_idx], r['MEG_sub4_50-100-orig'][0, cka_biased, cornet_idx]])
MEG_50_100_CKA_debiased_orig_m, MEG_50_100_CKA_debiased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_100_CKA_debiased_orig_h = MEG_50_100_CKA_debiased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([r['MEG_sub1_50-100-rand'][:, cka_biased, cornet_idx], r['MEG_sub2_50-100-rand'][:, cka_biased, cornet_idx], r['MEG_sub4_50-100-rand'][:, cka_biased, cornet_idx]])
MEG_50_100_CKA_debiased_rand_m, MEG_50_100_CKA_debiased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_100_CKA_debiased_rand_h = MEG_50_100_CKA_debiased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([r['MEG_sub1_50-100-shuf'][:, cka_biased, cornet_idx], r['MEG_sub2_50-100-shuf'][:, cka_biased, cornet_idx], r['MEG_sub4_50-100-shuf'][:, cka_biased, cornet_idx]])
MEG_50_100_CKA_debiased_shuf_m, MEG_50_100_CKA_debiased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_100_CKA_debiased_shuf_h = MEG_50_100_CKA_debiased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# -----------------------

# 50_150 - CKA biased
cka_biased = 0 # selects correct index, ignore semantics
tmp = np.hstack([r['MEG_sub1_50-150-orig'][0, cka_biased, cornet_idx], r['MEG_sub2_50-150-orig'][0, cka_biased, cornet_idx], r['MEG_sub4_50-150-orig'][0, cka_biased, cornet_idx]])
MEG_50_150_CKA_biased_orig_m, MEG_50_150_CKA_biased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_150_CKA_biased_orig_h = MEG_50_150_CKA_biased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([r['MEG_sub1_50-150-rand'][:, cka_biased, cornet_idx], r['MEG_sub2_50-150-rand'][:, cka_biased, cornet_idx], r['MEG_sub4_50-150-rand'][:, cka_biased, cornet_idx]])
MEG_50_150_CKA_biased_rand_m, MEG_50_150_CKA_biased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_150_CKA_biased_rand_h = MEG_50_150_CKA_biased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([r['MEG_sub1_50-150-shuf'][:, cka_biased, cornet_idx], r['MEG_sub2_50-150-shuf'][:, cka_biased, cornet_idx], r['MEG_sub4_50-150-shuf'][:, cka_biased, cornet_idx]])
MEG_50_150_CKA_biased_shuf_m, MEG_50_150_CKA_biased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_150_CKA_biased_shuf_h = MEG_50_150_CKA_biased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# 50_150 - CKA debiased
cka_biased = 1 # selects correct index, ignore semantics
tmp = np.hstack([r['MEG_sub1_50-150-orig'][0, cka_biased, cornet_idx], r['MEG_sub2_50-150-orig'][0, cka_biased, cornet_idx], r['MEG_sub4_50-150-orig'][0, cka_biased, cornet_idx]])
MEG_50_150_CKA_debiased_orig_m, MEG_50_150_CKA_debiased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_150_CKA_debiased_orig_h = MEG_50_150_CKA_debiased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([r['MEG_sub1_50-150-rand'][:, cka_biased, cornet_idx], r['MEG_sub2_50-150-rand'][:, cka_biased, cornet_idx], r['MEG_sub4_50-150-rand'][:, cka_biased, cornet_idx]])
MEG_50_150_CKA_debiased_rand_m, MEG_50_150_CKA_debiased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_150_CKA_debiased_rand_h = MEG_50_150_CKA_debiased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([r['MEG_sub1_50-150-shuf'][:, cka_biased, cornet_idx], r['MEG_sub2_50-150-shuf'][:, cka_biased, cornet_idx], r['MEG_sub4_50-150-shuf'][:, cka_biased, cornet_idx]])
MEG_50_150_CKA_debiased_shuf_m, MEG_50_150_CKA_debiased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_150_CKA_debiased_shuf_h = MEG_50_150_CKA_debiased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# -----------------

# 50_200 - CKA biased
cka_biased = 0 # selects correct index, ignore semantics
tmp = np.hstack([r['MEG_sub1_50-200-orig'][0, cka_biased, cornet_idx], r['MEG_sub2_50-200-orig'][0, cka_biased, cornet_idx], r['MEG_sub4_50-200-orig'][0, cka_biased, cornet_idx]])
MEG_50_200_CKA_biased_orig_m, MEG_50_200_CKA_biased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_200_CKA_biased_orig_h = MEG_50_200_CKA_biased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([r['MEG_sub1_50-200-rand'][:, cka_biased, cornet_idx], r['MEG_sub2_50-200-rand'][:, cka_biased, cornet_idx], r['MEG_sub4_50-200-rand'][:, cka_biased, cornet_idx]])
MEG_50_200_CKA_biased_rand_m, MEG_50_200_CKA_biased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_200_CKA_biased_rand_h = MEG_50_200_CKA_biased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([r['MEG_sub1_50-200-shuf'][:, cka_biased, cornet_idx], r['MEG_sub2_50-200-shuf'][:, cka_biased, cornet_idx], r['MEG_sub4_50-200-shuf'][:, cka_biased, cornet_idx]])
MEG_50_200_CKA_biased_shuf_m, MEG_50_200_CKA_biased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_200_CKA_biased_shuf_h = MEG_50_200_CKA_biased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# 50_200 - CKA debiased
cka_biased = 1 # selects correct index, ignore semantics
tmp = np.hstack([r['MEG_sub1_50-200-orig'][0, cka_biased, cornet_idx], r['MEG_sub2_50-200-orig'][0, cka_biased, cornet_idx], r['MEG_sub4_50-200-orig'][0, cka_biased, cornet_idx]])
MEG_50_200_CKA_debiased_orig_m, MEG_50_200_CKA_debiased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_200_CKA_debiased_orig_h = MEG_50_200_CKA_debiased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([r['MEG_sub1_50-200-rand'][:, cka_biased, cornet_idx], r['MEG_sub2_50-200-rand'][:, cka_biased, cornet_idx], r['MEG_sub4_50-200-rand'][:, cka_biased, cornet_idx]])
MEG_50_200_CKA_debiased_rand_m, MEG_50_200_CKA_debiased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_200_CKA_debiased_rand_h = MEG_50_200_CKA_debiased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([r['MEG_sub1_50-200-shuf'][:, cka_biased, cornet_idx], r['MEG_sub2_50-200-shuf'][:, cka_biased, cornet_idx], r['MEG_sub4_50-200-shuf'][:, cka_biased, cornet_idx]])
MEG_50_200_CKA_debiased_shuf_m, MEG_50_200_CKA_debiased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_200_CKA_debiased_shuf_h = MEG_50_200_CKA_debiased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# -------------

# 50_250 - CKA biased
cka_biased = 0 # selects correct index, ignore semantics
tmp = np.hstack([r['MEG_sub1_50-250-orig'][0, cka_biased, cornet_idx], r['MEG_sub2_50-250-orig'][0, cka_biased, cornet_idx], r['MEG_sub4_50-250-orig'][0, cka_biased, cornet_idx]])
MEG_50_250_CKA_biased_orig_m, MEG_50_250_CKA_biased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_250_CKA_biased_orig_h = MEG_50_250_CKA_biased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([r['MEG_sub1_50-250-rand'][:, cka_biased, cornet_idx], r['MEG_sub2_50-250-rand'][:, cka_biased, cornet_idx], r['MEG_sub4_50-250-rand'][:, cka_biased, cornet_idx]])
MEG_50_250_CKA_biased_rand_m, MEG_50_250_CKA_biased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_250_CKA_biased_rand_h = MEG_50_250_CKA_biased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([r['MEG_sub1_50-250-shuf'][:, cka_biased, cornet_idx], r['MEG_sub2_50-250-shuf'][:, cka_biased, cornet_idx], r['MEG_sub4_50-250-shuf'][:, cka_biased, cornet_idx]])
MEG_50_250_CKA_biased_shuf_m, MEG_50_250_CKA_biased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_250_CKA_biased_shuf_h = MEG_50_250_CKA_biased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# 50_250 - CKA debiased
cka_biased = 1 # selects correct index, ignore semantics
tmp = np.hstack([r['MEG_sub1_50-250-orig'][0, cka_biased, cornet_idx], r['MEG_sub2_50-250-orig'][0, cka_biased, cornet_idx], r['MEG_sub4_50-250-orig'][0, cka_biased, cornet_idx]])
MEG_50_250_CKA_debiased_orig_m, MEG_50_250_CKA_debiased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_250_CKA_debiased_orig_h = MEG_50_250_CKA_debiased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([r['MEG_sub1_50-250-rand'][:, cka_biased, cornet_idx], r['MEG_sub2_50-250-rand'][:, cka_biased, cornet_idx], r['MEG_sub4_50-250-rand'][:, cka_biased, cornet_idx]])
MEG_50_250_CKA_debiased_rand_m, MEG_50_250_CKA_debiased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_250_CKA_debiased_rand_h = MEG_50_250_CKA_debiased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([r['MEG_sub1_50-250-shuf'][:, cka_biased, cornet_idx], r['MEG_sub2_50-250-shuf'][:, cka_biased, cornet_idx], r['MEG_sub4_50-250-shuf'][:, cka_biased, cornet_idx]])
MEG_50_250_CKA_debiased_shuf_m, MEG_50_250_CKA_debiased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_250_CKA_debiased_shuf_h = MEG_50_250_CKA_debiased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# ----------------

# 50_300 - CKA biased
cka_biased = 0 # selects correct index, ignore semantics
tmp = np.hstack([r['MEG_sub1_50-300-orig'][0, cka_biased, cornet_idx], r['MEG_sub2_50-300-orig'][0, cka_biased, cornet_idx], r['MEG_sub4_50-300-orig'][0, cka_biased, cornet_idx]])
MEG_50_300_CKA_biased_orig_m, MEG_50_300_CKA_biased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_300_CKA_biased_orig_h = MEG_50_300_CKA_biased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([r['MEG_sub1_50-300-rand'][:, cka_biased, cornet_idx], r['MEG_sub2_50-300-rand'][:, cka_biased, cornet_idx], r['MEG_sub4_50-300-rand'][:, cka_biased, cornet_idx]])
MEG_50_300_CKA_biased_rand_m, MEG_50_300_CKA_biased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_300_CKA_biased_rand_h = MEG_50_300_CKA_biased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([r['MEG_sub1_50-300-shuf'][:, cka_biased, cornet_idx], r['MEG_sub2_50-300-shuf'][:, cka_biased, cornet_idx], r['MEG_sub4_50-300-shuf'][:, cka_biased, cornet_idx]])
MEG_50_300_CKA_biased_shuf_m, MEG_50_300_CKA_biased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_300_CKA_biased_shuf_h = MEG_50_300_CKA_biased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# 50_300 - CKA debiased
cka_biased = 1 # selects correct index, ignore semantics
tmp = np.hstack([r['MEG_sub1_50-300-orig'][0, cka_biased, cornet_idx], r['MEG_sub2_50-300-orig'][0, cka_biased, cornet_idx], r['MEG_sub4_50-300-orig'][0, cka_biased, cornet_idx]])
MEG_50_300_CKA_debiased_orig_m, MEG_50_300_CKA_debiased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_300_CKA_debiased_orig_h = MEG_50_300_CKA_debiased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([r['MEG_sub1_50-300-rand'][:, cka_biased, cornet_idx], r['MEG_sub2_50-300-rand'][:, cka_biased, cornet_idx], r['MEG_sub4_50-300-rand'][:, cka_biased, cornet_idx]])
MEG_50_300_CKA_debiased_rand_m, MEG_50_300_CKA_debiased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_300_CKA_debiased_rand_h = MEG_50_300_CKA_debiased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([r['MEG_sub1_50-300-shuf'][:, cka_biased, cornet_idx], r['MEG_sub2_50-300-shuf'][:, cka_biased, cornet_idx], r['MEG_sub4_50-300-shuf'][:, cka_biased, cornet_idx]])
MEG_50_300_CKA_debiased_shuf_m, MEG_50_300_CKA_debiased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_300_CKA_debiased_shuf_h = MEG_50_300_CKA_debiased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# --------------------


# 50_350 - CKA biased
cka_biased = 0 # selects correct index, ignore semantics
tmp = np.hstack([r['MEG_sub1_50-350-orig'][0, cka_biased, cornet_idx], r['MEG_sub2_50-350-orig'][0, cka_biased, cornet_idx], r['MEG_sub4_50-350-orig'][0, cka_biased, cornet_idx]])
MEG_50_350_CKA_biased_orig_m, MEG_50_350_CKA_biased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_350_CKA_biased_orig_h = MEG_50_350_CKA_biased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([r['MEG_sub1_50-350-rand'][:, cka_biased, cornet_idx], r['MEG_sub2_50-350-rand'][:, cka_biased, cornet_idx], r['MEG_sub4_50-350-rand'][:, cka_biased, cornet_idx]])
MEG_50_350_CKA_biased_rand_m, MEG_50_350_CKA_biased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_350_CKA_biased_rand_h = MEG_50_350_CKA_biased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([r['MEG_sub1_50-350-shuf'][:, cka_biased, cornet_idx], r['MEG_sub2_50-350-shuf'][:, cka_biased, cornet_idx], r['MEG_sub4_50-350-shuf'][:, cka_biased, cornet_idx]])
MEG_50_350_CKA_biased_shuf_m, MEG_50_350_CKA_biased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_350_CKA_biased_shuf_h = MEG_50_350_CKA_biased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# 50_350 - CKA debiased
cka_biased = 1 # selects correct index, ignore semantics
tmp = np.hstack([r['MEG_sub1_50-350-orig'][0, cka_biased, cornet_idx], r['MEG_sub2_50-350-orig'][0, cka_biased, cornet_idx], r['MEG_sub4_50-350-orig'][0, cka_biased, cornet_idx]])
MEG_50_350_CKA_debiased_orig_m, MEG_50_350_CKA_debiased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_350_CKA_debiased_orig_h = MEG_50_350_CKA_debiased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([r['MEG_sub1_50-350-rand'][:, cka_biased, cornet_idx], r['MEG_sub2_50-350-rand'][:, cka_biased, cornet_idx], r['MEG_sub4_50-350-rand'][:, cka_biased, cornet_idx]])
MEG_50_350_CKA_debiased_rand_m, MEG_50_350_CKA_debiased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_350_CKA_debiased_rand_h = MEG_50_350_CKA_debiased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([r['MEG_sub1_50-350-shuf'][:, cka_biased, cornet_idx], r['MEG_sub2_50-350-shuf'][:, cka_biased, cornet_idx], r['MEG_sub4_50-350-shuf'][:, cka_biased, cornet_idx]])
MEG_50_350_CKA_debiased_shuf_m, MEG_50_350_CKA_debiased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_350_CKA_debiased_shuf_h = MEG_50_350_CKA_debiased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# ---------------------

# 50_400 - CKA biased
cka_biased = 0 # selects correct index, ignore semantics
tmp = np.hstack([r['MEG_sub1_50-400-orig'][0, cka_biased, cornet_idx], r['MEG_sub2_50-400-orig'][0, cka_biased, cornet_idx], r['MEG_sub4_50-400-orig'][0, cka_biased, cornet_idx]])
MEG_50_400_CKA_biased_orig_m, MEG_50_400_CKA_biased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_400_CKA_biased_orig_h = MEG_50_400_CKA_biased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([r['MEG_sub1_50-400-rand'][:, cka_biased, cornet_idx], r['MEG_sub2_50-400-rand'][:, cka_biased, cornet_idx], r['MEG_sub4_50-400-rand'][:, cka_biased, cornet_idx]])
MEG_50_400_CKA_biased_rand_m, MEG_50_400_CKA_biased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_400_CKA_biased_rand_h = MEG_50_400_CKA_biased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([r['MEG_sub1_50-400-shuf'][:, cka_biased, cornet_idx], r['MEG_sub2_50-400-shuf'][:, cka_biased, cornet_idx], r['MEG_sub4_50-400-shuf'][:, cka_biased, cornet_idx]])
MEG_50_400_CKA_biased_shuf_m, MEG_50_400_CKA_biased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_400_CKA_biased_shuf_h = MEG_50_400_CKA_biased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# 50_400 - CKA debiased
cka_biased = 1 # selects correct index, ignore semantics
tmp = np.hstack([r['MEG_sub1_50-400-orig'][0, cka_biased, cornet_idx], r['MEG_sub2_50-400-orig'][0, cka_biased, cornet_idx], r['MEG_sub4_50-400-orig'][0, cka_biased, cornet_idx]])
MEG_50_400_CKA_debiased_orig_m, MEG_50_400_CKA_debiased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_400_CKA_debiased_orig_h = MEG_50_400_CKA_debiased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([r['MEG_sub1_50-400-rand'][:, cka_biased, cornet_idx], r['MEG_sub2_50-400-rand'][:, cka_biased, cornet_idx], r['MEG_sub4_50-400-rand'][:, cka_biased, cornet_idx]])
MEG_50_400_CKA_debiased_rand_m, MEG_50_400_CKA_debiased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_400_CKA_debiased_rand_h = MEG_50_400_CKA_debiased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([r['MEG_sub1_50-400-shuf'][:, cka_biased, cornet_idx], r['MEG_sub2_50-400-shuf'][:, cka_biased, cornet_idx], r['MEG_sub4_50-400-shuf'][:, cka_biased, cornet_idx]])
MEG_50_400_CKA_debiased_shuf_m, MEG_50_400_CKA_debiased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_400_CKA_debiased_shuf_h = MEG_50_400_CKA_debiased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# ---------------------

# 50_450 - CKA biased
cka_biased = 0 # selects correct index, ignore semantics
tmp = np.hstack([r['MEG_sub1_50-450-orig'][0, cka_biased, cornet_idx], r['MEG_sub2_50-450-orig'][0, cka_biased, cornet_idx], r['MEG_sub4_50-450-orig'][0, cka_biased, cornet_idx]])
MEG_50_450_CKA_biased_orig_m, MEG_50_450_CKA_biased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_450_CKA_biased_orig_h = MEG_50_450_CKA_biased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([r['MEG_sub1_50-450-rand'][:, cka_biased, cornet_idx], r['MEG_sub2_50-450-rand'][:, cka_biased, cornet_idx], r['MEG_sub4_50-450-rand'][:, cka_biased, cornet_idx]])
MEG_50_450_CKA_biased_rand_m, MEG_50_450_CKA_biased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_450_CKA_biased_rand_h = MEG_50_450_CKA_biased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([r['MEG_sub1_50-450-shuf'][:, cka_biased, cornet_idx], r['MEG_sub2_50-450-shuf'][:, cka_biased, cornet_idx], r['MEG_sub4_50-450-shuf'][:, cka_biased, cornet_idx]])
MEG_50_450_CKA_biased_shuf_m, MEG_50_450_CKA_biased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_450_CKA_biased_shuf_h = MEG_50_450_CKA_biased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# 50_450 - CKA debiased
cka_biased = 1 # selects correct index, ignore semantics
tmp = np.hstack([r['MEG_sub1_50-450-orig'][0, cka_biased, cornet_idx], r['MEG_sub2_50-450-orig'][0, cka_biased, cornet_idx], r['MEG_sub4_50-450-orig'][0, cka_biased, cornet_idx]])
MEG_50_450_CKA_debiased_orig_m, MEG_50_450_CKA_debiased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_450_CKA_debiased_orig_h = MEG_50_450_CKA_debiased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([r['MEG_sub1_50-450-rand'][:, cka_biased, cornet_idx], r['MEG_sub2_50-450-rand'][:, cka_biased, cornet_idx], r['MEG_sub4_50-450-rand'][:, cka_biased, cornet_idx]])
MEG_50_450_CKA_debiased_rand_m, MEG_50_450_CKA_debiased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_450_CKA_debiased_rand_h = MEG_50_450_CKA_debiased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([r['MEG_sub1_50-450-shuf'][:, cka_biased, cornet_idx], r['MEG_sub2_50-450-shuf'][:, cka_biased, cornet_idx], r['MEG_sub4_50-450-shuf'][:, cka_biased, cornet_idx]])
MEG_50_450_CKA_debiased_shuf_m, MEG_50_450_CKA_debiased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_450_CKA_debiased_shuf_h = MEG_50_450_CKA_debiased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# ---------------------

# 50_500 - CKA biased
cka_biased = 0 # selects correct index, ignore semantics
tmp = np.hstack([r['MEG_sub1_50-500-orig'][0, cka_biased, cornet_idx], r['MEG_sub2_50-500-orig'][0, cka_biased, cornet_idx], r['MEG_sub4_50-500-orig'][0, cka_biased, cornet_idx]])
MEG_50_500_CKA_biased_orig_m, MEG_50_500_CKA_biased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_500_CKA_biased_orig_h = MEG_50_500_CKA_biased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([r['MEG_sub1_50-500-rand'][:, cka_biased, cornet_idx], r['MEG_sub2_50-500-rand'][:, cka_biased, cornet_idx], r['MEG_sub4_50-500-rand'][:, cka_biased, cornet_idx]])
MEG_50_500_CKA_biased_rand_m, MEG_50_500_CKA_biased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_500_CKA_biased_rand_h = MEG_50_500_CKA_biased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([r['MEG_sub1_50-500-shuf'][:, cka_biased, cornet_idx], r['MEG_sub2_50-500-shuf'][:, cka_biased, cornet_idx], r['MEG_sub4_50-500-shuf'][:, cka_biased, cornet_idx]])
MEG_50_500_CKA_biased_shuf_m, MEG_50_500_CKA_biased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_500_CKA_biased_shuf_h = MEG_50_500_CKA_biased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# 50_500 - CKA debiased
cka_biased = 1 # selects correct index, ignore semantics
tmp = np.hstack([r['MEG_sub1_50-500-orig'][0, cka_biased, cornet_idx], r['MEG_sub2_50-500-orig'][0, cka_biased, cornet_idx], r['MEG_sub4_50-500-orig'][0, cka_biased, cornet_idx]])
MEG_50_500_CKA_debiased_orig_m, MEG_50_500_CKA_debiased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_500_CKA_debiased_orig_h = MEG_50_500_CKA_debiased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([r['MEG_sub1_50-500-rand'][:, cka_biased, cornet_idx], r['MEG_sub2_50-500-rand'][:, cka_biased, cornet_idx], r['MEG_sub4_50-500-rand'][:, cka_biased, cornet_idx]])
MEG_50_500_CKA_debiased_rand_m, MEG_50_500_CKA_debiased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_500_CKA_debiased_rand_h = MEG_50_500_CKA_debiased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([r['MEG_sub1_50-500-shuf'][:, cka_biased, cornet_idx], r['MEG_sub2_50-500-shuf'][:, cka_biased, cornet_idx], r['MEG_sub4_50-500-shuf'][:, cka_biased, cornet_idx]])
MEG_50_500_CKA_debiased_shuf_m, MEG_50_500_CKA_debiased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_500_CKA_debiased_shuf_h = MEG_50_500_CKA_debiased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# ---------------------

# %%
fig, axis = plt.subplots(figsize=(10,5))
axis = np.ravel(axis)

#temp_windows = ['V1', 'V2', 'V3', '50_450', '50_150', '50_250', '50_400', '50_500', '50_100', '50_200', '50_300', '50_350']
temp_windows = ['50-100 ms', '50-150 ms', '50-200 ms', '50-250 ms', '50-300 ms', '50-350 ms', '50-400 ms', '50-450 ms', '50-500 ms']

# ORIG
cornet_cka_biased_orig_m = np.array([MEG_50_100_CKA_biased_orig_m, MEG_50_150_CKA_biased_orig_m, MEG_50_200_CKA_biased_orig_m, MEG_50_250_CKA_biased_orig_m, MEG_50_300_CKA_biased_orig_m,
                         MEG_50_350_CKA_biased_orig_m, MEG_50_400_CKA_biased_orig_m, MEG_50_450_CKA_biased_orig_m, MEG_50_500_CKA_biased_orig_m])

cornet_cka_biased_orig_h = np.array([MEG_50_100_CKA_biased_orig_h, MEG_50_150_CKA_biased_orig_h, MEG_50_200_CKA_biased_orig_h, MEG_50_250_CKA_biased_orig_h, MEG_50_300_CKA_biased_orig_h,
                         MEG_50_350_CKA_biased_orig_h, MEG_50_400_CKA_biased_orig_h, MEG_50_450_CKA_biased_orig_h, MEG_50_500_CKA_biased_orig_h])

m = cornet_cka_biased_orig_m
h = cornet_cka_biased_orig_h

axis[0].plot(temp_windows, m, color='blue', label='Original', linestyle='-')
axis[0].fill_between(temp_windows, m-h, m+h, color='blue', alpha=0.3)

cornet_cka_debiased_orig_m = np.array([MEG_50_100_CKA_debiased_orig_m, MEG_50_150_CKA_debiased_orig_m, MEG_50_200_CKA_debiased_orig_m, MEG_50_250_CKA_debiased_orig_m, MEG_50_300_CKA_debiased_orig_m,
                         MEG_50_350_CKA_debiased_orig_m, MEG_50_400_CKA_debiased_orig_m, MEG_50_450_CKA_debiased_orig_m, MEG_50_500_CKA_debiased_orig_m])

cornet_cka_debiased_orig_h = np.array([MEG_50_100_CKA_debiased_orig_h, MEG_50_150_CKA_debiased_orig_h, MEG_50_200_CKA_debiased_orig_h, MEG_50_250_CKA_debiased_orig_h, MEG_50_300_CKA_debiased_orig_h,
                         MEG_50_350_CKA_debiased_orig_h, MEG_50_400_CKA_debiased_orig_h, MEG_50_450_CKA_debiased_orig_h, MEG_50_500_CKA_debiased_orig_h])

m = cornet_cka_debiased_orig_m
h = cornet_cka_debiased_orig_h
axis[0].plot(temp_windows, m, color='blue', label='Original', linestyle='--')
axis[0].fill_between(temp_windows, m-h, m+h, color='blue', alpha=0.3)


# RAND
cornet_cka_biased_rand_m = np.array([MEG_50_100_CKA_biased_rand_m, MEG_50_150_CKA_biased_rand_m, MEG_50_200_CKA_biased_rand_m, MEG_50_250_CKA_biased_rand_m, MEG_50_300_CKA_biased_rand_m,
                         MEG_50_350_CKA_biased_rand_m, MEG_50_400_CKA_biased_rand_m, MEG_50_450_CKA_biased_rand_m, MEG_50_500_CKA_biased_rand_m])

cornet_cka_biased_rand_h = np.array([MEG_50_100_CKA_biased_rand_h, MEG_50_150_CKA_biased_rand_h, MEG_50_200_CKA_biased_rand_h, MEG_50_250_CKA_biased_rand_h, MEG_50_300_CKA_biased_rand_h,
                         MEG_50_350_CKA_biased_rand_h, MEG_50_400_CKA_biased_rand_h, MEG_50_450_CKA_biased_rand_h, MEG_50_500_CKA_biased_rand_h])

m = cornet_cka_biased_rand_m
h = cornet_cka_biased_rand_h

axis[0].plot(temp_windows, m, color='red', label='Random', linestyle='-')
axis[0].fill_between(temp_windows, m-h, m+h, color='red', alpha=0.3)

cornet_cka_debiased_rand_m = np.array([MEG_50_100_CKA_debiased_rand_m, MEG_50_150_CKA_debiased_rand_m, MEG_50_200_CKA_debiased_rand_m, MEG_50_250_CKA_debiased_rand_m, MEG_50_300_CKA_debiased_rand_m,
                         MEG_50_350_CKA_debiased_rand_m, MEG_50_400_CKA_debiased_rand_m, MEG_50_450_CKA_debiased_rand_m, MEG_50_500_CKA_debiased_rand_m])

cornet_cka_debiased_rand_h = np.array([MEG_50_100_CKA_debiased_rand_h, MEG_50_150_CKA_debiased_rand_h, MEG_50_200_CKA_debiased_rand_h, MEG_50_250_CKA_debiased_rand_h, MEG_50_300_CKA_debiased_rand_h,
                         MEG_50_350_CKA_debiased_rand_h, MEG_50_400_CKA_debiased_rand_h, MEG_50_450_CKA_debiased_rand_h, MEG_50_500_CKA_debiased_rand_h])

m = cornet_cka_debiased_rand_m
h = cornet_cka_debiased_rand_h

axis[0].plot(temp_windows, m, color='red', label='Random', linestyle='--')
axis[0].fill_between(temp_windows, m-h, m+h, color='red', alpha=0.3)

# SHUFFLED 
# RAND
cornet_cka_biased_shuf_m = np.array([MEG_50_100_CKA_biased_shuf_m, MEG_50_150_CKA_biased_shuf_m, MEG_50_200_CKA_biased_shuf_m, MEG_50_250_CKA_biased_shuf_m, MEG_50_300_CKA_biased_shuf_m,
                         MEG_50_350_CKA_biased_shuf_m, MEG_50_400_CKA_biased_shuf_m, MEG_50_450_CKA_biased_shuf_m, MEG_50_500_CKA_biased_shuf_m])

cornet_cka_biased_shuf_h = np.array([MEG_50_100_CKA_biased_shuf_h, MEG_50_150_CKA_biased_shuf_h, MEG_50_200_CKA_biased_shuf_h, MEG_50_250_CKA_biased_shuf_h, MEG_50_300_CKA_biased_shuf_h,
                         MEG_50_350_CKA_biased_shuf_h, MEG_50_400_CKA_biased_shuf_h, MEG_50_450_CKA_biased_shuf_h, MEG_50_500_CKA_biased_shuf_h])

m = cornet_cka_biased_shuf_m
h = cornet_cka_biased_shuf_h

axis[0].plot(temp_windows, m, color='green', label='Shuffled', linestyle='-')
axis[0].fill_between(temp_windows, m-h, m+h, color='green', alpha=0.3)

cornet_cka_debiased_shuf_m = np.array([MEG_50_100_CKA_debiased_shuf_m, MEG_50_150_CKA_debiased_shuf_m, MEG_50_200_CKA_debiased_shuf_m, MEG_50_250_CKA_debiased_shuf_m, MEG_50_300_CKA_debiased_shuf_m,
                         MEG_50_350_CKA_debiased_shuf_m, MEG_50_400_CKA_debiased_shuf_m, MEG_50_450_CKA_debiased_shuf_m, MEG_50_500_CKA_debiased_shuf_m])

cornet_cka_debiased_shuf_h = np.array([MEG_50_100_CKA_debiased_shuf_h, MEG_50_150_CKA_debiased_shuf_h, MEG_50_200_CKA_debiased_shuf_h, MEG_50_250_CKA_debiased_shuf_h, MEG_50_300_CKA_debiased_shuf_h,
                         MEG_50_350_CKA_debiased_shuf_h, MEG_50_400_CKA_debiased_shuf_h, MEG_50_450_CKA_debiased_shuf_h, MEG_50_500_CKA_debiased_shuf_h])

m = cornet_cka_debiased_shuf_m
h = cornet_cka_debiased_shuf_h

axis[0].plot(temp_windows, m, color='green', label='Shuffled', linestyle='--')
axis[0].fill_between(temp_windows, m-h, m+h, color='green', alpha=0.3)


plt.legend()
plt.savefig('MEG_CORnet-s_temp_windows_fixed_ANN_layer.svg', format='svg')

# %% [markdown]
# # MEG (V1 & Occpital 100-150 ms)
#
# * Sub-parts of Figure 2 A and B

# %%
import scipy.stats

# %%
x = pickle.load(open('meg_results_dict.pkl', 'rb'))
x.keys()

# %%
tmp = np.vstack([r1['MEG_sub1_100-150_orig'][:,0,], r1['MEG_sub2_100-150_orig'][:,0,], r1['MEG_sub4_100-150_orig'][:,0,]])
m, std = np.mean(tmp, axis=0), scipy.stats.sem(tmp, axis=0)

# %%
import pickle

r2 = pickle.load(open('MEG_100-150_cornet_results.pkl', 'rb'))
r1 = pickle.load(open('MEG_100-150_resnet_results.pkl', 'rb'))

# CKA biased
tmp = np.vstack([r1['MEG_sub1_100-150_orig'][:,0,:], r1['MEG_sub2_100-150_orig'][:,0,:], r1['MEG_sub4_100-150_orig'][:,0,:]])
MEG_CKA_biased_orig_m, MEG_CKA_biased_orig_se = m, std = np.mean(tmp, axis=0), scipy.stats.sem(tmp, axis=0)
MEG_CKA_biased_orig_h = MEG_CKA_biased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.vstack([r1['MEG_sub1_100-150_rand'][:,0,:], r1['MEG_sub2_100-150_rand'][:,0,:], r1['MEG_sub4_100-150_rand'][:,0,:]])
MEG_CKA_biased_rand_m, MEG_CKA_biased_rand_se = m, std = np.mean(tmp, axis=0), scipy.stats.sem(tmp, axis=0)
MEG_CKA_biased_rand_h = MEG_CKA_biased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.vstack([r1['MEG_sub1_100-150_shuf'][:,0,:], r1['MEG_sub2_100-150_shuf'][:,0,:], r1['MEG_sub4_100-150_shuf'][:,0,:]])
MEG_CKA_biased_shuf_m, MEG_CKA_biased_shuf_se = m, std = np.mean(tmp, axis=0), scipy.stats.sem(tmp, axis=0)
MEG_CKA_biased_shuf_h = MEG_CKA_biased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# CKA debiased
tmp = np.vstack([r1['MEG_sub1_100-150_orig'][:,1,:], r1['MEG_sub2_100-150_orig'][:,1,:], r1['MEG_sub4_100-150_orig'][:,1,:]])
MEG_CKA_debiased_orig_m, MEG_CKA_debiased_orig_se = m, std = np.mean(tmp, axis=0), scipy.stats.sem(tmp, axis=0)
MEG_CKA_debiased_orig_h = MEG_CKA_debiased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.vstack([r1['MEG_sub1_100-150_rand'][:,1,:], r1['MEG_sub2_100-150_rand'][:,1,:], r1['MEG_sub4_100-150_rand'][:,1,:]])
MEG_CKA_debiased_rand_m, MEG_CKA_debiased_rand_se = m, std = np.mean(tmp, axis=0), scipy.stats.sem(tmp, axis=0)
MEG_CKA_debiased_rand_h = MEG_CKA_debiased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.vstack([r1['MEG_sub1_100-150_shuf'][:,1,:], r1['MEG_sub2_100-150_shuf'][:,1,:], r1['MEG_sub4_100-150_shuf'][:,1,:]])
MEG_CKA_debiased_shuf_m, MEG_CKA_debiased_shuf_se = m, std = np.mean(tmp, axis=0), scipy.stats.sem(tmp, axis=0)
MEG_CKA_debiased_shuf_h = MEG_CKA_debiased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# %%
# CKA biased
tmp = np.vstack([r2['MEG_sub1_100-150_orig'][:,0,:], r2['MEG_sub2_100-150_orig'][:,0,:], r2['MEG_sub4_100-150_orig'][:,0,:]])
MEG_CKA_biased_orig_m, MEG_CKA_biased_orig_se = m, std = np.mean(tmp, axis=0), scipy.stats.sem(tmp, axis=0)
MEG_CKA_biased_orig_h = MEG_CKA_biased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.vstack([r2['MEG_sub1_100-150_rand'][:,0,:], r2['MEG_sub2_100-150_rand'][:,0,:], r2['MEG_sub4_100-150_rand'][:,0,:]])
MEG_CKA_biased_rand_m, MEG_CKA_biased_rand_se = m, std = np.mean(tmp, axis=0), scipy.stats.sem(tmp, axis=0)
MEG_CKA_biased_rand_h = MEG_CKA_biased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.vstack([r2['MEG_sub1_100-150_shuf'][:,0,:], r2['MEG_sub2_100-150_shuf'][:,0,:], r2['MEG_sub4_100-150_shuf'][:,0,:]])
MEG_CKA_biased_shuf_m, MEG_CKA_biased_shuf_se = m, std = np.mean(tmp, axis=0), scipy.stats.sem(tmp, axis=0)
MEG_CKA_biased_shuf_h = MEG_CKA_biased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# CKA debiased
tmp = np.vstack([r2['MEG_sub1_100-150_orig'][:,1,:], r2['MEG_sub2_100-150_orig'][:,1,:], r2['MEG_sub4_100-150_orig'][:,1,:]])
MEG_CKA_debiased_orig_m, MEG_CKA_debiased_orig_se = m, std = np.mean(tmp, axis=0), scipy.stats.sem(tmp, axis=0)
MEG_CKA_debiased_orig_h = MEG_CKA_debiased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.vstack([r2['MEG_sub1_100-150_rand'][:,1,:], r2['MEG_sub2_100-150_rand'][:,1,:], r2['MEG_sub4_100-150_rand'][:,1,:]])
MEG_CKA_debiased_rand_m, MEG_CKA_debiased_rand_se = m, std = np.mean(tmp, axis=0), scipy.stats.sem(tmp, axis=0)
MEG_CKA_debiased_rand_h = MEG_CKA_debiased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.vstack([r2['MEG_sub1_100-150_shuf'][:,1,:], r2['MEG_sub2_100-150_shuf'][:,1,:], r2['MEG_sub4_100-150_shuf'][:,1,:]])
MEG_CKA_debiased_shuf_m, MEG_CKA_debiased_shuf_se = m, std = np.mean(tmp, axis=0), scipy.stats.sem(tmp, axis=0)
MEG_CKA_debiased_shuf_h = MEG_CKA_debiased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# %% [markdown]
# # Save below in case error later

# %%
n = 15
cornet_idx = 3

# 50_100 - CKA biased
cka_biased = 0 # selects correct index, ignore semantics
tmp = np.hstack([r['MEG_sub1_50-100-orig'][0, cka_biased, cornet_idx], r['MEG_sub2_50-100-orig'][0, cka_biased, cornet_idx], r['MEG_sub4_50-100-orig'][0, cka_biased, cornet_idx]])
MEG_50_100_CKA_biased_orig_m, MEG_50_100_CKA_biased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_100_CKA_biased_orig_h = MEG_50_100_CKA_biased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_MEG_50_100_cornet_rand[:, cka_biased, cornet_idx], sub3_MEG_50_100_cornet_rand[:, cka_biased, cornet_idx], sub4_MEG_50_100_cornet_rand[:, cka_biased, cornet_idx]])
MEG_50_100_CKA_biased_rand_m, MEG_50_100_CKA_biased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_100_CKA_biased_rand_h = MEG_50_100_CKA_biased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_MEG_50_100_cornet_shuf[:, cka_biased, cornet_idx], sub3_MEG_50_100_cornet_shuf[:, cka_biased, cornet_idx], sub4_MEG_50_100_cornet_shuf[:, cka_biased, cornet_idx]])
MEG_50_100_CKA_biased_shuf_m, MEG_50_100_CKA_biased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_100_CKA_biased_shuf_h = MEG_50_100_CKA_biased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# 50_100 - CKA debiased
cka_biased = 1 # selects correct index, ignore semantics
tmp = np.hstack([sub1_MEG_50_100_cornet_orig[0, cka_biased, cornet_idx], sub3_MEG_50_100_cornet_orig[0, cka_biased, cornet_idx], sub4_MEG_50_100_cornet_orig[0, cka_biased, cornet_idx]])
MEG_50_100_CKA_debiased_orig_m, MEG_50_100_CKA_debiased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_100_CKA_debiased_orig_h = MEG_50_100_CKA_debiased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_MEG_50_100_cornet_rand[:, cka_biased, cornet_idx], sub3_MEG_50_100_cornet_rand[:, cka_biased, cornet_idx], sub4_MEG_50_100_cornet_rand[:, cka_biased, cornet_idx]])
MEG_50_100_CKA_debiased_rand_m, MEG_50_100_CKA_debiased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_100_CKA_debiased_rand_h = MEG_50_100_CKA_debiased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_MEG_50_100_cornet_shuf[:, cka_biased, cornet_idx], sub3_MEG_50_100_cornet_shuf[:, cka_biased, cornet_idx], sub4_MEG_50_100_cornet_shuf[:, cka_biased, cornet_idx]])
MEG_50_100_CKA_debiased_shuf_m, MEG_50_100_CKA_debiased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_100_CKA_debiased_shuf_h = MEG_50_100_CKA_debiased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# -----------------------

# 50_150 -  CKA biased
cka_biased = 0 # selects correct index, ignore semantics
tmp = np.hstack([sub1_MEG_50_150_cornet_orig[0, cka_biased, cornet_idx], sub3_MEG_50_150_cornet_orig[0, cka_biased, cornet_idx], sub4_MEG_50_150_cornet_orig[0, cka_biased, cornet_idx]])
MEG_50_150_CKA_biased_orig_m, MEG_50_150_CKA_biased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_150_CKA_biased_orig_h = MEG_50_150_CKA_biased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_MEG_50_150_cornet_rand[:, cka_biased, cornet_idx], sub3_MEG_50_150_cornet_rand[:, cka_biased, cornet_idx], sub4_MEG_50_150_cornet_rand[:, cka_biased, cornet_idx]])
MEG_50_150_CKA_biased_rand_m, MEG_50_150_CKA_biased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_150_CKA_biased_rand_h = MEG_50_150_CKA_biased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_MEG_50_150_cornet_shuf[:, cka_biased, cornet_idx], sub3_MEG_50_150_cornet_shuf[:, cka_biased, cornet_idx], sub4_MEG_50_150_cornet_shuf[:, cka_biased, cornet_idx]])
MEG_50_150_CKA_biased_shuf_m, MEG_50_150_CKA_biased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_150_CKA_biased_shuf_h = MEG_50_150_CKA_biased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# 50_150 - CKA debiased
cka_biased = 1 # selects correct index, ignore semantics
tmp = np.hstack([sub1_MEG_50_150_cornet_orig[0, cka_biased, cornet_idx], sub3_MEG_50_150_cornet_orig[0, cka_biased, cornet_idx], sub4_MEG_50_150_cornet_orig[0, cka_biased, cornet_idx]])
MEG_50_150_CKA_debiased_orig_m, MEG_50_150_CKA_debiased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_150_CKA_debiased_orig_h = MEG_50_150_CKA_debiased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_MEG_50_150_cornet_rand[:, cka_biased, cornet_idx], sub3_MEG_50_150_cornet_rand[:, cka_biased, cornet_idx], sub4_MEG_50_150_cornet_rand[:, cka_biased, cornet_idx]])
MEG_50_150_CKA_debiased_rand_m, MEG_50_150_CKA_debiased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_150_CKA_debiased_rand_h = MEG_50_150_CKA_debiased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_MEG_50_150_cornet_shuf[:, cka_biased, cornet_idx], sub3_MEG_50_150_cornet_shuf[:, cka_biased, cornet_idx], sub4_MEG_50_150_cornet_shuf[:, cka_biased, cornet_idx]])
MEG_50_150_CKA_debiased_shuf_m, MEG_50_150_CKA_debiased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_150_CKA_debiased_shuf_h = MEG_50_150_CKA_debiased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1) 

# -----------------

# 50_200 -  CKA biased
cka_biased = 0 # selects correct index, ignore semantics
tmp = np.hstack([sub1_MEG_50_200_cornet_orig[0, cka_biased, cornet_idx], sub3_MEG_50_200_cornet_orig[0, cka_biased, cornet_idx], sub4_MEG_50_200_cornet_orig[0, cka_biased, cornet_idx]])
MEG_50_200_CKA_biased_orig_m, MEG_50_200_CKA_biased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_200_CKA_biased_orig_h = MEG_50_200_CKA_biased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_MEG_50_200_cornet_rand[:, cka_biased, cornet_idx], sub3_MEG_50_200_cornet_rand[:, cka_biased, cornet_idx], sub4_MEG_50_200_cornet_rand[:, cka_biased, cornet_idx]])
MEG_50_200_CKA_biased_rand_m, MEG_50_200_CKA_biased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_200_CKA_biased_rand_h = MEG_50_200_CKA_biased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_MEG_50_200_cornet_shuf[:, cka_biased, cornet_idx], sub3_MEG_50_200_cornet_shuf[:, cka_biased, cornet_idx], sub4_MEG_50_200_cornet_shuf[:, cka_biased, cornet_idx]])
MEG_50_200_CKA_biased_shuf_m, MEG_50_200_CKA_biased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_200_CKA_biased_shuf_h = MEG_50_200_CKA_biased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# 50_200 - CKA debiased
cka_biased = 1 # selects correct index, ignore semantics
tmp = np.hstack([sub1_MEG_50_200_cornet_orig[0, cka_biased, cornet_idx], sub3_MEG_50_200_cornet_orig[0, cka_biased, cornet_idx], sub4_MEG_50_200_cornet_orig[0, cka_biased, cornet_idx]])
MEG_50_200_CKA_debiased_orig_m, MEG_50_200_CKA_debiased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_200_CKA_debiased_orig_h = MEG_50_200_CKA_debiased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_MEG_50_200_cornet_rand[:, cka_biased, cornet_idx], sub3_MEG_50_200_cornet_rand[:, cka_biased, cornet_idx], sub4_MEG_50_200_cornet_rand[:, cka_biased, cornet_idx]])
MEG_50_200_CKA_debiased_rand_m, MEG_50_200_CKA_debiased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_200_CKA_debiased_rand_h = MEG_50_200_CKA_debiased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_MEG_50_200_cornet_shuf[:, cka_biased, cornet_idx], sub3_MEG_50_200_cornet_shuf[:, cka_biased, cornet_idx], sub4_MEG_50_200_cornet_shuf[:, cka_biased, cornet_idx]])
MEG_50_200_CKA_debiased_shuf_m, MEG_50_200_CKA_debiased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_200_CKA_debiased_shuf_h = MEG_50_200_CKA_debiased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1) 

# -------------

# 50_250 -  CKA biased
cka_biased = 0 # selects correct index, ignore semantics
tmp = np.hstack([sub1_MEG_50_250_cornet_orig[0, cka_biased, cornet_idx], sub3_MEG_50_250_cornet_orig[0, cka_biased, cornet_idx], sub4_MEG_50_250_cornet_orig[0, cka_biased, cornet_idx]])
MEG_50_250_CKA_biased_orig_m, MEG_50_250_CKA_biased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_250_CKA_biased_orig_h = MEG_50_250_CKA_biased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_MEG_50_250_cornet_rand[:, cka_biased, cornet_idx], sub3_MEG_50_250_cornet_rand[:, cka_biased, cornet_idx], sub4_MEG_50_250_cornet_rand[:, cka_biased, cornet_idx]])
MEG_50_250_CKA_biased_rand_m, MEG_50_250_CKA_biased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_250_CKA_biased_rand_h = MEG_50_250_CKA_biased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_MEG_50_250_cornet_shuf[:, cka_biased, cornet_idx], sub3_MEG_50_250_cornet_shuf[:, cka_biased, cornet_idx], sub4_MEG_50_250_cornet_shuf[:, cka_biased, cornet_idx]])
MEG_50_250_CKA_biased_shuf_m, MEG_50_250_CKA_biased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_250_CKA_biased_shuf_h = MEG_50_250_CKA_biased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# 50_250 - CKA debiased
cka_biased = 1 # selects correct index, ignore semantics
tmp = np.hstack([sub1_MEG_50_250_cornet_orig[0, cka_biased, cornet_idx], sub3_MEG_50_250_cornet_orig[0, cka_biased, cornet_idx], sub4_MEG_50_250_cornet_orig[0, cka_biased, cornet_idx]])
MEG_50_250_CKA_debiased_orig_m, MEG_50_250_CKA_debiased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_250_CKA_debiased_orig_h = MEG_50_250_CKA_debiased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_MEG_50_250_cornet_rand[:, cka_biased, cornet_idx], sub3_MEG_50_250_cornet_rand[:, cka_biased, cornet_idx], sub4_MEG_50_250_cornet_rand[:, cka_biased, cornet_idx]])
MEG_50_250_CKA_debiased_rand_m, MEG_50_250_CKA_debiased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_250_CKA_debiased_rand_h = MEG_50_250_CKA_debiased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_MEG_50_250_cornet_shuf[:, cka_biased, cornet_idx], sub3_MEG_50_250_cornet_shuf[:, cka_biased, cornet_idx], sub4_MEG_50_250_cornet_shuf[:, cka_biased, cornet_idx]])
MEG_50_250_CKA_debiased_shuf_m, MEG_50_250_CKA_debiased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_250_CKA_debiased_shuf_h = MEG_50_250_CKA_debiased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1) 

# ----------------

# 50_300 -  CKA biased
cka_biased = 0 # selects correct index, ignore semantics
tmp = np.hstack([sub1_MEG_50_300_cornet_orig[0, cka_biased, cornet_idx], sub3_MEG_50_300_cornet_orig[0, cka_biased, cornet_idx], sub4_MEG_50_300_cornet_orig[0, cka_biased, cornet_idx]])
MEG_50_300_CKA_biased_orig_m, MEG_50_300_CKA_biased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_300_CKA_biased_orig_h = MEG_50_300_CKA_biased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_MEG_50_300_cornet_rand[:, cka_biased, cornet_idx], sub3_MEG_50_300_cornet_rand[:, cka_biased, cornet_idx], sub4_MEG_50_300_cornet_rand[:, cka_biased, cornet_idx]])
MEG_50_300_CKA_biased_rand_m, MEG_50_300_CKA_biased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_300_CKA_biased_rand_h = MEG_50_300_CKA_biased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_MEG_50_300_cornet_shuf[:, cka_biased, cornet_idx], sub3_MEG_50_300_cornet_shuf[:, cka_biased, cornet_idx], sub4_MEG_50_300_cornet_shuf[:, cka_biased, cornet_idx]])
MEG_50_300_CKA_biased_shuf_m, MEG_50_300_CKA_biased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_300_CKA_biased_shuf_h = MEG_50_300_CKA_biased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# 50_300 - CKA debiased
cka_biased = 1 # selects correct index, ignore semantics
tmp = np.hstack([sub1_MEG_50_300_cornet_orig[0, cka_biased, cornet_idx], sub3_MEG_50_300_cornet_orig[0, cka_biased, cornet_idx], sub4_MEG_50_300_cornet_orig[0, cka_biased, cornet_idx]])
MEG_50_300_CKA_debiased_orig_m, MEG_50_300_CKA_debiased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_300_CKA_debiased_orig_h = MEG_50_300_CKA_debiased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_MEG_50_300_cornet_rand[:, cka_biased, cornet_idx], sub3_MEG_50_300_cornet_rand[:, cka_biased, cornet_idx], sub4_MEG_50_300_cornet_rand[:, cka_biased, cornet_idx]])
MEG_50_300_CKA_debiased_rand_m, MEG_50_300_CKA_debiased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_300_CKA_debiased_rand_h = MEG_50_300_CKA_debiased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_MEG_50_300_cornet_shuf[:, cka_biased, cornet_idx], sub3_MEG_50_300_cornet_shuf[:, cka_biased, cornet_idx], sub4_MEG_50_300_cornet_shuf[:, cka_biased, cornet_idx]])
MEG_50_300_CKA_debiased_shuf_m, MEG_50_300_CKA_debiased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_300_CKA_debiased_shuf_h = MEG_50_300_CKA_debiased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1) 

# --------------------


# 50_350 -  CKA biased
cka_biased = 0 # selects correct index, ignore semantics
tmp = np.hstack([sub1_MEG_50_350_cornet_orig[0, cka_biased, cornet_idx], sub3_MEG_50_350_cornet_orig[0, cka_biased, cornet_idx], sub4_MEG_50_350_cornet_orig[0, cka_biased, cornet_idx]])
MEG_50_350_CKA_biased_orig_m, MEG_50_350_CKA_biased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_350_CKA_biased_orig_h = MEG_50_350_CKA_biased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_MEG_50_350_cornet_rand[:, cka_biased, cornet_idx], sub3_MEG_50_350_cornet_rand[:, cka_biased, cornet_idx], sub4_MEG_50_350_cornet_rand[:, cka_biased, cornet_idx]])
MEG_50_350_CKA_biased_rand_m, MEG_50_350_CKA_biased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_350_CKA_biased_rand_h = MEG_50_350_CKA_biased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_MEG_50_350_cornet_shuf[:, cka_biased, cornet_idx], sub3_MEG_50_350_cornet_shuf[:, cka_biased, cornet_idx], sub4_MEG_50_350_cornet_shuf[:, cka_biased, cornet_idx]])
MEG_50_350_CKA_biased_shuf_m, MEG_50_350_CKA_biased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_350_CKA_biased_shuf_h = MEG_50_350_CKA_biased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# 50_350 - CKA debiased
cka_biased = 1 # selects correct index, ignore semantics
tmp = np.hstack([sub1_MEG_50_350_cornet_orig[0, cka_biased, cornet_idx], sub3_MEG_50_350_cornet_orig[0, cka_biased, cornet_idx], sub4_MEG_50_350_cornet_orig[0, cka_biased, cornet_idx]])
MEG_50_350_CKA_debiased_orig_m, MEG_50_350_CKA_debiased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_350_CKA_debiased_orig_h = MEG_50_350_CKA_debiased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_MEG_50_350_cornet_rand[:, cka_biased, cornet_idx], sub3_MEG_50_350_cornet_rand[:, cka_biased, cornet_idx], sub4_MEG_50_350_cornet_rand[:, cka_biased, cornet_idx]])
MEG_50_350_CKA_debiased_rand_m, MEG_50_350_CKA_debiased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_350_CKA_debiased_rand_h = MEG_50_350_CKA_debiased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_MEG_50_350_cornet_shuf[:, cka_biased, cornet_idx], sub3_MEG_50_350_cornet_shuf[:, cka_biased, cornet_idx], sub4_MEG_50_350_cornet_shuf[:, cka_biased, cornet_idx]])
MEG_50_350_CKA_debiased_shuf_m, MEG_50_350_CKA_debiased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_350_CKA_debiased_shuf_h = MEG_50_350_CKA_debiased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1) 

# ---------------------

# 50_400 -  CKA biased
cka_biased = 0 # selects correct index, ignore semantics
tmp = np.hstack([sub1_MEG_50_400_cornet_orig[0, cka_biased, cornet_idx], sub3_MEG_50_400_cornet_orig[0, cka_biased, cornet_idx], sub4_MEG_50_400_cornet_orig[0, cka_biased, cornet_idx]])
MEG_50_400_CKA_biased_orig_m, MEG_50_400_CKA_biased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_400_CKA_biased_orig_h = MEG_50_400_CKA_biased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_MEG_50_400_cornet_rand[:, cka_biased, cornet_idx], sub3_MEG_50_400_cornet_rand[:, cka_biased, cornet_idx], sub4_MEG_50_400_cornet_rand[:, cka_biased, cornet_idx]])
MEG_50_400_CKA_biased_rand_m, MEG_50_400_CKA_biased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_400_CKA_biased_rand_h = MEG_50_400_CKA_biased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_MEG_50_400_cornet_shuf[:, cka_biased, cornet_idx], sub3_MEG_50_400_cornet_shuf[:, cka_biased, cornet_idx], sub4_MEG_50_400_cornet_shuf[:, cka_biased, cornet_idx]])
MEG_50_400_CKA_biased_shuf_m, MEG_50_400_CKA_biased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_400_CKA_biased_shuf_h = MEG_50_400_CKA_biased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# 50_400 - CKA debiased
cka_biased = 1 # selects correct index, ignore semantics
tmp = np.hstack([sub1_MEG_50_400_cornet_orig[0, cka_biased, cornet_idx], sub3_MEG_50_400_cornet_orig[0, cka_biased, cornet_idx], sub4_MEG_50_400_cornet_orig[0, cka_biased, cornet_idx]])
MEG_50_400_CKA_debiased_orig_m, MEG_50_400_CKA_debiased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_400_CKA_debiased_orig_h = MEG_50_400_CKA_debiased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_MEG_50_400_cornet_rand[:, cka_biased, cornet_idx], sub3_MEG_50_400_cornet_rand[:, cka_biased, cornet_idx], sub4_MEG_50_400_cornet_rand[:, cka_biased, cornet_idx]])
MEG_50_400_CKA_debiased_rand_m, MEG_50_400_CKA_debiased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_400_CKA_debiased_rand_h = MEG_50_400_CKA_debiased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_MEG_50_400_cornet_shuf[:, cka_biased, cornet_idx], sub3_MEG_50_400_cornet_shuf[:, cka_biased, cornet_idx], sub4_MEG_50_400_cornet_shuf[:, cka_biased, cornet_idx]])
MEG_50_400_CKA_debiased_shuf_m, MEG_50_400_CKA_debiased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_400_CKA_debiased_shuf_h = MEG_50_400_CKA_debiased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1) 

# ---------------------

# 50_450 -  CKA biased
cka_biased = 0 # selects correct index, ignore semantics
tmp = np.hstack([sub1_MEG_50_450_cornet_orig[0, cka_biased, cornet_idx], sub3_MEG_50_450_cornet_orig[0, cka_biased, cornet_idx], sub4_MEG_50_450_cornet_orig[0, cka_biased, cornet_idx]])
MEG_50_450_CKA_biased_orig_m, MEG_50_450_CKA_biased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_450_CKA_biased_orig_h = MEG_50_450_CKA_biased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_MEG_50_450_cornet_rand[:, cka_biased, cornet_idx], sub3_MEG_50_450_cornet_rand[:, cka_biased, cornet_idx], sub4_MEG_50_450_cornet_rand[:, cka_biased, cornet_idx]])
MEG_50_450_CKA_biased_rand_m, MEG_50_450_CKA_biased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_450_CKA_biased_rand_h = MEG_50_450_CKA_biased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_MEG_50_450_cornet_shuf[:, cka_biased, cornet_idx], sub3_MEG_50_450_cornet_shuf[:, cka_biased, cornet_idx], sub4_MEG_50_450_cornet_shuf[:, cka_biased, cornet_idx]])
MEG_50_450_CKA_biased_shuf_m, MEG_50_450_CKA_biased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_450_CKA_biased_shuf_h = MEG_50_450_CKA_biased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# 50_450 - CKA debiased
cka_biased = 1 # selects correct index, ignore semantics
tmp = np.hstack([sub1_MEG_50_450_cornet_orig[0, cka_biased, cornet_idx], sub3_MEG_50_450_cornet_orig[0, cka_biased, cornet_idx], sub4_MEG_50_450_cornet_orig[0, cka_biased, cornet_idx]])
MEG_50_450_CKA_debiased_orig_m, MEG_50_450_CKA_debiased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_450_CKA_debiased_orig_h = MEG_50_450_CKA_debiased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_MEG_50_450_cornet_rand[:, cka_biased, cornet_idx], sub3_MEG_50_450_cornet_rand[:, cka_biased, cornet_idx], sub4_MEG_50_450_cornet_rand[:, cka_biased, cornet_idx]])
MEG_50_450_CKA_debiased_rand_m, MEG_50_450_CKA_debiased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_450_CKA_debiased_rand_h = MEG_50_450_CKA_debiased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_MEG_50_450_cornet_shuf[:, cka_biased, cornet_idx], sub3_MEG_50_450_cornet_shuf[:, cka_biased, cornet_idx], sub4_MEG_50_450_cornet_shuf[:, cka_biased, cornet_idx]])
MEG_50_450_CKA_debiased_shuf_m, MEG_50_450_CKA_debiased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_450_CKA_debiased_shuf_h = MEG_50_450_CKA_debiased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1) 

# ---------------------

# 50_500 -  CKA biased
cka_biased = 0 # selects correct index, ignore semantics
tmp = np.hstack([sub1_MEG_50_500_cornet_orig[0, cka_biased, cornet_idx], sub3_MEG_50_500_cornet_orig[0, cka_biased, cornet_idx], sub4_MEG_50_500_cornet_orig[0, cka_biased, cornet_idx]])
MEG_50_500_CKA_biased_orig_m, MEG_50_500_CKA_biased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_500_CKA_biased_orig_h = MEG_50_500_CKA_biased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_MEG_50_500_cornet_rand[:, cka_biased, cornet_idx], sub3_MEG_50_500_cornet_rand[:, cka_biased, cornet_idx], sub4_MEG_50_500_cornet_rand[:, cka_biased, cornet_idx]])
MEG_50_500_CKA_biased_rand_m, MEG_50_500_CKA_biased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_500_CKA_biased_rand_h = MEG_50_500_CKA_biased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_MEG_50_500_cornet_shuf[:, cka_biased, cornet_idx], sub3_MEG_50_500_cornet_shuf[:, cka_biased, cornet_idx], sub4_MEG_50_500_cornet_shuf[:, cka_biased, cornet_idx]])
MEG_50_500_CKA_biased_shuf_m, MEG_50_500_CKA_biased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_500_CKA_biased_shuf_h = MEG_50_500_CKA_biased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

# 50_500 - CKA debiased
cka_biased = 1 # selects correct index, ignore semantics
tmp = np.hstack([sub1_MEG_50_500_cornet_orig[0, cka_biased, cornet_idx], sub3_MEG_50_500_cornet_orig[0, cka_biased, cornet_idx], sub4_MEG_50_500_cornet_orig[0, cka_biased, cornet_idx]])
MEG_50_500_CKA_debiased_orig_m, MEG_50_500_CKA_debiased_orig_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_500_CKA_debiased_orig_h = MEG_50_500_CKA_debiased_orig_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_MEG_50_500_cornet_rand[:, cka_biased, cornet_idx], sub3_MEG_50_500_cornet_rand[:, cka_biased, cornet_idx], sub4_MEG_50_500_cornet_rand[:, cka_biased, cornet_idx]])
MEG_50_500_CKA_debiased_rand_m, MEG_50_500_CKA_debiased_rand_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_500_CKA_debiased_rand_h = MEG_50_500_CKA_debiased_rand_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)

tmp = np.hstack([sub1_MEG_50_500_cornet_shuf[:, cka_biased, cornet_idx], sub3_MEG_50_500_cornet_shuf[:, cka_biased, cornet_idx], sub4_MEG_50_500_cornet_shuf[:, cka_biased, cornet_idx]])
MEG_50_500_CKA_debiased_shuf_m, MEG_50_500_CKA_debiased_shuf_se = np.mean(tmp), scipy.stats.sem(tmp)
MEG_50_500_CKA_debiased_shuf_h = MEG_50_500_CKA_debiased_shuf_se * scipy.stats.t.ppf((1 + confidence) / 2., n-1) 

# ---------------------
